# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import matplotlib.patches as mpatches  # For patterns

import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import matplotlib.patches as mpatches  # For patterns

from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import norm
import seaborn as sns
from scipy.stats import chi2_contingency

from scipy.signal import find_peaks

# %%
file_path = '/Users/jesanahammed/Desktop/dataset/faculty_data_raw_3_june.csv'
df = pd.read_csv(file_path, encoding='latin1')
df.columns = df.columns.str.replace(r'[^\x00-\x7F]+', '', regex=True)  # Remove non-ASCII characters
df.columns = df.columns.str.strip()  # Strip any leading/trailing spaces

# %%
response_id = df["Response ID"]

# %%
print(len(response_id))
# Out:
# 142

# %%
df_filtered = df[df["Response Status"] == "Completed"]

# %%
response_id = df_filtered["Response ID"]
print(len(response_id))
# Out:
# 98

# %%
test_response = df_filtered["External Reference"]
test_response.value_counts()
# Out:
# External Reference
# test_response    3
# Name: count, dtype: int64

# %%
df_new = df_filtered[df_filtered["External Reference"] != "test_response"]

# %%
test_response = df_new["External Reference"]
test_response.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
response_id = df_new["Response ID"]
print(len(response_id))
# Out:
# 95

# %%
response_id.isna().sum()
# Out:
# 0

# %%
genai = df_new["Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts"]

# %%
genai.value_counts().sum()
# Out:
# 95

# %%
genai.value_counts()/95*100
# Out:
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts
# Once or Twice                                      35.789474
# Never                                              29.473684
# Regularly (Once or twice a week)                   18.947368
# All the time (daily, or more often)                 9.473684
# Have only used for fun or curiosity, never work     6.315789
# Name: count, dtype: float64

# %%
genai.isna().sum()
# Out:
# 0

# %%
ben_harm = df_new["Please rate your current feelings on whether generative AI will be beneficial or harmful to your field. (1) Extremely harmful to (10) Extremely beneficial Row 1"]

# %%
ben_harm.isna().sum()
# Out:
# 0

# %%
ben_harm.value_counts()
# Out:
# Please rate your current feelings on whether generative AI will be beneficial or harmful to your field. (1) Extremely harmful to (10) Extremely beneficial Row 1
# 5.0     21
# 7.0     15
# 6.0     14
# 9.0     11
# 10.0     9
# 8.0      9
# 3.0      6
# 4.0      5
# 2.0      4
# 1.0      1
# Name: count, dtype: int64

# %%
def kde_plot(data, min, max, title, xlabel, ylabel):
    plt.figure(figsize=(10, 6))
    
    # KDE Plot with Clipping
    sns.kdeplot(data, clip=(min, max))
    plt.xlim(min, max)
    
    # Generate KDE data for finding peaks
    kde_data = sns.kdeplot(data, clip=(min, max)).get_lines()[0].get_data()
    x = kde_data[0]  # X values
    y = kde_data[1]  # Y values (density values)
    
    # Find peaks
    peaks, _ = find_peaks(y)  # Locate peaks in KDE curve
    
    # Plot the peaks on the KDE plot
    plt.plot(x[peaks], y[peaks], "ro")  # Mark peaks with red dots
    for peak in peaks:
        plt.text(x[peak], y[peak] + 0.0001,  # Offset slightly above the peak, 0.0001 for p(doom) estimation
                 f'{x[peak]:.2f}', ha='center', va='bottom', color='red', fontsize=25, fontweight='bold')  # Bigger peak values
    
    # Adjust x and y-axis ticks
    plt.tick_params(axis='both', labelsize=25)  # Make x and y-axis ticks bigger

    # Set x-axis ticks to range from 1 to 10
    ticks = np.linspace(min, max, 10)  # Create 10 evenly spaced ticks # ticks for rating
    #ticks = np.linspace(min, max, 7)  # ticks for p(doom)
    plt.xticks(ticks, labels=[f'{int(tick)}' for tick in ticks], fontsize=20)  # Format as integers and increase font size
    
    
    # Remove x and y labels
    plt.xlabel('')
    plt.ylabel('')

    plt.savefig('/Users/jesanahammed/Desktop/existing_vs_new.png', dpi=300)
    
    # Show the plot
    address = '/Users/jesanahammed/Desktop/' + title
    plt.savefig(address, dpi=300)
    plt.show()
    
    # Print the peak values
    peak_values = x[peaks]
    print(f"Peak values are at: {peak_values}")

# %%
kde_plot(ben_harm, 1, 10, 'A', 'X', 'Y')
# Out:
# Peak values are at: [5.61306533]

# %%
str = "To what extent do you feel GenAI can provide pedagogical benefit to your Fall23 courses? (1) Extremely damaging to (10) Extremely beneficial Row 1"
str
# Out:
# 'To what extent do you feel GenAI can provide pedagogical benefit to your Fall23 courses? (1)\xa0Extremely damaging to (10) Extremely beneficial Row 1'

# %%
import pandas as pd

# Assuming df is your DataFrame
for idx, col in enumerate(df_new.columns):
    print(f"{idx}: {col}")
# Out:
# 0: Response ID
# 1: Response Status
# 2: IP Address
# 3: Timestamp (mm/dd/yyyy)
# 4: Duplicate
# 5: Time Taken to Complete (Seconds)
# 6: Seq. Number
# 7: External Reference
# 8: Custom Variable 1
# 9: Custom Variable 2
# 10: Custom Variable 3
# 11: Custom Variable 4
# 12: Custom Variable 5
# 13: Respondent Email
# 14: Email List
# 15: Country Code
# 16: Region
# 17: TITLE OF PROJECT: Mines Stakeholder Perspectives on the Uses of Generative AI in and out of the Classroom NAME OF PRINCIPAL INVESTIGATOR(S): C. Estelle Smith, PhDCONTACT NAME AND PHONE NUMBER FOR QUESTIONS/PROBLEMS: C. Estelle Smith, PhD, estellesmith@mines.edu, 612.226.7789SURVEY CLOSES at midnight on Wednesday, September 20, 2023. PURPOSE OF THE RESEARCH: At the end of the Spring23 semester, a survey was conducted of the full Mines student body on Generative Artificial Intelligence (GenAI). (Prominent examples of GenAI-based tools include: ChatGPT, Bard, Github Co-Pilot, Midjourney, DALL-E.) These data were used to inform the development of new Mines guidelines from the Office of the Provost and resources from the Trefny Center.In order to continue serving the needs of the Mines community and promoting a culture of excellence in engineering education, and to emerge as a leader among our institutional peers in our thoughtful and effective integration of GenAI, the purpose of this research is to collect faculty and staff data on self-reported uses and opinions of GenAI. These data will be analyzed for a peer-reviewed scientific publication, however the main purpose is to use these data to support the ongoing development and refinement of new Mines policies and programming related to GenAI. This research is being conducted with the approval and support of the faculty senate. EXPLANATION OF PROCEDURES/METHODS TO BE USED: Faculty will complete a brief online survey expected to take no more than 10-15 minutes. RISKS/DISCOMFORTS INHERENT IN THE PROCEDURES: There are no serious risks associated with this survey beyond those associated with any data collection process (e.g., the possibility of a data breach). Faculty are in positions of authority to determine policies and consequences related to GenAI usages in their context, and therefore opinions provided in this survey do not stand to harm their performance or expectations. The survey will collect demographic information such as title, department, and number of years at Mines. Such data may make it possible for student researchers to de-identify some participants, given the relatively small number of faculty per department. All student researchers have completed CITI training and have been provided rigorous additional training on appropriate data protections. Additionally, in all presentations and publications, all demographic information will be reported in aggregate with no identifying details connected to individual quotes or data points. Therefore, it should not be possible to determine which faculty were or were not participants. POTENTIAL BENEFITS: There is no compensation for participation. However, by participating in the survey, faculty will provide their opinions, experiences, and needs related to GenAI, thus enabling Mines administration to refine and revisit policies that account for both student and faculty perspectives rather than omitting this vital stakeholder input. Your input will help Mines to continue providing world-class engineering education, and to position our academic community as a leader in the space of thoughtful integration of Generative AI within and beyond our curriculum. CONFIDENTIALITY: Faculty will be asked to provide their current role title, department, and number of years at Mines and in industry. Beyond this, no identifying information will be collected about you on this survey. At the end of the survey, you may optionally provide your email address if you would like to receive an email update about the results or opt-in to be contacted for future studies. Information obtained about you for this study will be treated as confidential to the extent allowed by law. Research information that identifies you may be shared with the Colorado School of Mines Human Subjects Team and others who are responsible for ensuring compliance with laws and regulations related to research.All data will be stored on a password-protected Mines Network Drive and ...
# 18: To participate, you must answer three questions. By answering Yes for all three of the following questions, and by clicking on the button to proceed to the survey, you agree to participate in this research study as described above
# 19: I am age 18 or older
# 20: I am a current Mines faculty or staff member
# 21: I have read and understand the information about the study, and I agree to participate
# 22: Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts
# 23: Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts.1
# 24: Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts.2
# 25: If you have ever used any genAI-based tool(s) for your classes, research, and/or professional efforts, please tell us about how you have used them, why you used them, and how you feel about your use of these tool(s).
# 26: Please rate your current feelings on whether generative AI will be beneficial or harmful to your field. (1) Extremely harmful to (10) Extremely beneficial Row 1
# 27: Did you teach at least one course during Spring 2023?
# 28: For the course(s) you taught during Spring 2023, to what degree did you provide guidance to students on GenAI?
# 29: How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select "1." If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select "2."
# 30: What do you see as the greatest challenges and opportunities for Mines faculty and staff in thoughtfully responding to the new availability of Generative AI models for our students and colleagues? How might GenAI impact learning outcomes and processes?
# 31: Which of the following resources would you be likely to use in order to integrate generative AI effectively and responsibly in your role at Mines? (Select all that apply)
# 32: Unnamed: 32
# 33: Unnamed: 33
# 34: Unnamed: 34
# 35: Unnamed: 35
# 36: Unnamed: 36
# 37: Unnamed: 37
# 38: Unnamed: 38
# 39: To what degree are you aware of the Mines-wide guidance that was issued by the Office of the Provost over email in August 2023? Please select all that apply:
# 40: Unnamed: 40
# 41: Unnamed: 41
# 42: Unnamed: 42
# 43: Unnamed: 43
# 44: To what extent do you feel GenAI can provide pedagogical benefit to your Fall23 courses? (1)Extremely damaging to (10) Extremely beneficial Row 1
# 45: How prepared do you feel to integrate pedagogical uses of GenAI in your Fall23 courses?(1) Extremely unprepared to (10) Extremely prepared Row 1
# 46: How prepared do you feel to teach students professional skills and usages of GenAI for their future workplaces in your Fall23 course(s)? Row 1
# 47: Please help us understand how each of your Fall23 syllabi respond to the public availability of GenAI tools.These questions refer to recommended syllabus language provided by the Provost's Office.Mines faculty may customize their courses with any of three levels of permissiveness:- General permission: Students may use GenAI without restriction, but with proper citation. - General prohibition: Students are forbidden from using GenAI. - Selective permission: Students may only use GenAI in ways that instructors have specifically permitted or required for a particular course.
# 48: Class 1: What is the level of this course?
# 49: Class 1: How many sections of the course are you teaching?
# 50: Class 1: To what degree have you provided guidance to students on GenAI in this class?
# 51: Class 1:In this class, if you used language provided by the Provost's Office, how permissive is your Generative AI policy for your Fall 23 syllabus?
# 52: Class 2: What is the level of this course?
# 53: Class 2: How many sections of the course are you teaching?
# 54: Class 2: To what degree have you provided guidance to students on GenAI in this class?
# 55: Class 2:In this class, if you used language provided by the Provost's Office, how permissive is your Generative AI policy for your Fall 23 syllabus?
# 56: Class 3: What is the level of this course?
# 57: Class 3: How many sections of the course are you teaching?
# 58: Class 3: To what degree have you provided guidance to students on GenAI in this class?
# 59: Class 3:In this class, if you used language provided by the Provost's Office, how permissive is your Generative AI policy for your Fall 23 syllabus?
# 60: Class 4: What is the level of this course?
# 61: Class 4: How many sections of the course are you teaching?
# 62: Class 4: To what degree have you provided guidance to students on GenAI in this class?
# 63: Class 4:In this class, if you used language provided by the Provost's Office, how permissive is your Generative AI policy for your Fall 23 syllabus?
# 64: What is your current role at Mines?
# 65: Unnamed: 65
# 66: How many years of full-time industry experience (i.e. public or private sector work outside of academia but within your current discipline) did you obtain in your field prior to beginning your role at Mines? (Please do not include internships or part-time roles.)
# 67: How many years have you been at Mines?
# 68: What do you consider to be your primary department?
# 69: Unnamed: 69
# 70: Unnamed: 70
# 71: Unnamed: 71
# 72: Unnamed: 72
# 73: Unnamed: 73
# 74: Unnamed: 74
# 75: Unnamed: 75
# 76: Unnamed: 76
# 77: Unnamed: 77
# 78: Unnamed: 78
# 79: Unnamed: 79
# 80: Unnamed: 80
# 81: Unnamed: 81
# 82: Unnamed: 82
# 83: Unnamed: 83
# 84: Unnamed: 84
# 85: Unnamed: 85
# 86: Unnamed: 86
# 87: Please check this button to indicate that you have completed the survey. (This helps us know that you made it to the end, even if you chose not to answer demographic questions.)

# %%
ben_harm_course = df_new["To what extent do you feel GenAI can provide pedagogical benefit to your Fall23 courses? (1)Extremely damaging to (10) Extremely beneficial Row 1"]

# %%
ben_harm_course.value_counts()
# Out:
# To what extent do you feel GenAI can provide pedagogical benefit to your Fall23 courses? (1)Extremely damaging to (10) Extremely beneficial Row 1
# 5.0     31
# 6.0     20
# 7.0      8
# 1.0      7
# 3.0      7
# 2.0      7
# 10.0     5
# 8.0      5
# 9.0      3
# 4.0      1
# Name: count, dtype: int64

# %%
kde_plot(ben_harm_course, 1, 10, 'A', 'X', 'Y')
# Out:
# Peak values are at: [2.1758794 5.4321608]

# %%
print(ben_harm_course.mean())
print(ben_harm_course.median())
# Out:
# 5.25531914893617
# 5.0

# %%
ben_harm_course.isna().sum()
# Out:
# 1

# %%
ben_harm_clean = ben_harm_course.dropna()
ben_harm_clean.isna().sum()
# Out:
# 0

# %%
from scipy.stats import wilcoxon

w_stat, p_val_w = wilcoxon([r - 5.5 for r in ben_harm_clean])  # Testing if responses differ from 5

print(f"Wilcoxon Test Statistic: {w_stat}, P-Value: {p_val_w:.10e}")
# Out:
# Wilcoxon Test Statistic: 1975.5, P-Value: 3.2240400931e-01

# %%
# How have engineering students adopted GenAI, and what motivational and demographic factors contribute to its usage — and how do faculty perspectives align or differ?

# %%
file_path = '/Users/jesanahammed/Desktop/dataset/GenAI.csv'
df_24 = pd.read_csv(file_path, encoding='latin1')
df_24.columns = df_24.columns.str.replace(r'[^\x00-\x7F]+', '', regex=True)  # Remove non-ASCII characters
df_24.columns = df_24.columns.str.strip()  # Strip any leading/trailing spaces

# %%
print(len(df_24['Response ID']))
# Out:
# 862

# %%
file_path = '/Users/jesanahammed/Desktop/dataset/MOD - RAW - GenAI Survey Responses(Text).csv'
df_2023 = pd.read_csv(file_path, encoding='latin1')

# %%
print(len(df_2023['Response ID']))
# Out:
# 879

# %%
dept = df_2023['What department or program are you in?']
deg = df_2023['What degree are you enrolled in?']
year = df_2023['How many years have you been at Mines?']
count = 0
for i in range(len(dept)):
    if not pd.isna(dept[i]) and not pd.isna(deg[i]) and not pd.isna(year[i]):
        count += 1
print(count)
# Out:
# 601

# %%
df_2023_cleaned = df_2023.dropna(subset=['What department or program are you in?', 
                                         'What degree are you enrolled in?', 
                                         'How many years have you been at Mines?'])

# Reset the index and drop the old index column
df_2023_cleaned.reset_index(drop=True, inplace=True)

print(len(df_2023_cleaned['What department or program are you in?']))
# Out:
# 601

# %%
# frequency of usages

# %%
def two_proportion_z_test(n1, n2, x1, x2):
    # Perform the two-proportion z-test
    count = [x1, x2]
    nobs = [n1, n2]
    z_stat, p_value = proportions_ztest(count, nobs)
    
    print(f"Z-Statistic: {z_stat:.4f}")
    print(f"P-Value: {p_value:.4f}")
    # Calculate the P-value from the Z-statistic
    p_value_exact = 2 * norm.sf(abs(z_stat))
    print(f"Exact P-Value: {p_value_exact:.2e}")
        
    # Interpretation
    if p_value < 0.05:
        print("The change in proportions is statistically significant.")
    else:
        print("The change in proportions is not statistically significant.")

# %%
genai.value_counts()/95 * 100 # Faculty usages
# Out:
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts
# Once or Twice                                      35.789474
# Never                                              29.473684
# Regularly (Once or twice a week)                   18.947368
# All the time (daily, or more often)                 9.473684
# Have only used for fun or curiosity, never work     6.315789
# Name: count, dtype: float64

# %%
freq_llm_2023 = df_2023_cleaned['Please rate how frequently you have used the following genAI-based tools for your classes, research, and/or any other professional efforts.  - Large Language Models (e.g. ChatGPT, Bard, etc.)']

# %%
freq_llm_2023.value_counts() / 601 * 100
# Out:
# Please rate how frequently you have used the following genAI-based tools for your classes, research, and/or any other professional efforts.  - Large Language Models (e.g. ChatGPT, Bard, etc.)
# Never                                              30.782030
# Once or twice                                      30.782030
# Regularly (once or twice a week)                   22.462562
# All the time (daily, or more often)                 9.317804
# Have only used for fun or curiosity, never work     6.655574
# Name: count, dtype: float64

# %%
freq_llm_2024 = df_24['LLM-powered chatbots (e.g. ChatGPT Gemini Claude Llama etc.)']

# %%
freq_llm_2024.value_counts() / 862 * 100
# Out:
# LLM-powered chatbots (e.g. ChatGPT Gemini Claude Llama etc.)
# 3    32.250580
# 2    30.510441
# 1    17.865429
# 4    12.761021
# 5     6.612529
# Name: count, dtype: float64

# %%
# Never

# %%
two_proportion_z_test(95, 601, 28,185) # faculty vs 2023
# Out:
# Z-Statistic: -0.2571
# P-Value: 0.7971
# Exact P-Value: 7.97e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 28, 154)
# Out:
# Z-Statistic: 2.7362
# P-Value: 0.0062
# Exact P-Value: 6.21e-03
# The change in proportions is statistically significant.

# %%
# Irregular (Once or Twice)

# %%
two_proportion_z_test(95, 601, 34, 185)
# Out:
# Z-Statistic: 0.9766
# P-Value: 0.3287
# Exact P-Value: 3.29e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 34, 263)
# Out:
# Z-Statistic: 1.0555
# P-Value: 0.2912
# Exact P-Value: 2.91e-01
# The change in proportions is not statistically significant.

# %%
# Regular user

# %%
two_proportion_z_test(95, 601, 18, 135)
# Out:
# Z-Statistic: -0.7688
# P-Value: 0.4420
# Exact P-Value: 4.42e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 18, 278)
# Out:
# Z-Statistic: -2.6624
# P-Value: 0.0078
# Exact P-Value: 7.76e-03
# The change in proportions is statistically significant.

# %%
# Super user

# %%
two_proportion_z_test(95, 601, 9, 56)
# Out:
# Z-Statistic: 0.0485
# P-Value: 0.9613
# Exact P-Value: 9.61e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 9, 110)
# Out:
# Z-Statistic: -0.9216
# P-Value: 0.3568
# Exact P-Value: 3.57e-01
# The change in proportions is not statistically significant.

# %%
# Fun

# %%
two_proportion_z_test(95, 601, 6, 40)
# Out:
# Z-Statistic: -0.1239
# P-Value: 0.9014
# Exact P-Value: 9.01e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 6, 57)
# Out:
# Z-Statistic: -0.1107
# P-Value: 0.9119
# Exact P-Value: 9.12e-01
# The change in proportions is not statistically significant.

# %%
# Other GeanAI tools

# %%
img_fac = df_new["Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts.1"]

# %%
img_2023 = df_2023_cleaned['Please rate how frequently you have used the following genAI-based tools for your classes, research, and/or any other professional efforts.  - Image Generators (e.g. DALL-E, Midjourney)']

# %%
img_2024 = df_24['Image generators(e.g. DALL-E Midjourney etc.)']

# %%
img_fac.value_counts()
# Out:
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts.1
# Never                                              64
# Once or Twice                                      20
# Have only used for fun or curiosity, never work     6
# Regularly (Once or twice a week)                    5
# Name: count, dtype: int64

# %%
img_2023.value_counts()
# Out:
# Please rate how frequently you have used the following genAI-based tools for your classes, research, and/or any other professional efforts.  - Image Generators (e.g. DALL-E, Midjourney)
# Never                                              429
# Once or twice                                       89
# Have only used for fun or curiosity, never work     66
# Regularly (once or twice a week)                    15
# All the time (daily, or more often)                  2
# Name: count, dtype: int64

# %%
img_2024.value_counts()
# Out:
# Image generators(e.g. DALL-E Midjourney etc.)
# 1    501
# 2    199
# 5    134
# 3     25
# 4      3
# Name: count, dtype: int64

# %%
two_proportion_z_test(95, 601, 64, 429)
# Out:
# Z-Statistic: -0.7996
# P-Value: 0.4240
# Exact P-Value: 4.24e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 64, 501)
# Out:
# Z-Statistic: 1.7396
# P-Value: 0.0819
# Exact P-Value: 8.19e-02
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 601, 20, 89)
# Out:
# Z-Statistic: 1.5561
# P-Value: 0.1197
# Exact P-Value: 1.20e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 20, 199)
# Out:
# Z-Statistic: -0.4477
# P-Value: 0.6544
# Exact P-Value: 6.54e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 601, 6, 66)
# Out:
# Z-Statistic: -1.3877
# P-Value: 0.1652
# Exact P-Value: 1.65e-01
# The change in proportions is not statistically significant.

# %%
two_proportion_z_test(95, 862, 6, 25)
# Out:
# Z-Statistic: 1.7846
# P-Value: 0.0743
# Exact P-Value: 7.43e-02
# The change in proportions is not statistically significant.

# %%
# Conclusion: No significant changes is detected

# %%
# Coding Assistance (Facultuy)

# %%
coding_fac = df_new["Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts.2"]

# %%
coding_fac.value_counts()
# Out:
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts.2
# Never                                              75
# Once or Twice                                       9
# Regularly (Once or twice a week)                    7
# All the time (daily, or more often)                 3
# Have only used for fun or curiosity, never work     1
# Name: count, dtype: int64

# %%
# Use case + Motivation (Faculty)

# %%
um = df_new["If you have ever used any genAI-based tool(s) for your classes, research, and/or professional efforts, please tell us about how you have used them, why you used them, and how you feel about your use of these tool(s)."]

# %%
count = 0
for value in um:
    if not pd.isna(value):
        print(value)
        print("\n")
        count += 1
# Out:
# Generating images for research talks and discussing research ideas with ChatGPT
#
#
# Information on administrative policies and procedures. Ok to use them as long as you are not presenting the information as your own.
#
#
# I use ChatGPT daily to draft friendly emails, policies, proposals, goals and sometimes images. It's like having a team of assistants that understand my every request and never second guess themselves. Never do I use the first response, but after a few prompts I end up with a helluva first draft. At the very least, I end up with a good structure. ChatGPT allows me to spend my time making progress instead of creating documents. I'll never go back.
#
#
# Never
#
#
# I've used chatGPT to translate code between languages and edit (shorten) text, as well as to get instructions on using a new software tool. I have found it sometimes helpful, but also dangerously often wrong. I have also asked it questions like 'what are the biggest unsolved problems in field x' - to explore/understand the tool (and its training data).
#
#
# Help with coding websites
#
#
# n/a- never used
#
#
# I have used the image generator specifically to create images to discuss how this technology works.
#
#
# I used literature review and coding for research
#
#
# Have not used for classes
#
#
# ChatGPT is great for summarizing blocks of text. I've used it to summarize the major accomplishments of students when preparing student award speeches.
#
#
# LLMs like ChatGPT are useful for generating early drafts for e.g. proposals and papers at the level of individual paragraphs. They are also useful for generating alternative ways of writing small pieces of text more clearly. Other LLMs like Bing are useful for very rapid literature searches. However, their utility is currently limited to extremely superficial work. While this can be enough for initial drafts and initial literature searches, their utility in anything requiring deep or careful thought is extremely limited. What is important, however, is that the pace of these LLMs' development, which suggests that in the near future their capabilities will be far more impactful.
#
#
# I used image generation to help imagine label designs for gin. Basically to get the gears turning creatively and maybe provide a sort of halfway there example to artists who would potentially make the final version of a given label. I felt the tool was great for inspiration, but I'm concerned about how it uses artists' works to fuel its creation. For example, if I gave it a prompt to make an image in the style of one of my friend's work, it would obligingly put out a convincing piece of work similar to theirs. If someone commercialized it, my friend wouldn't get a dime. So, while I can see the use for inspiration and creative fuel, I worry that it will also result in artists having their style copied without any form of compensation.
#
#
# I use them to create rough, foundational drafts or outlines for content. I input my text into chat GPT and I ask it to make my writing more concise. I use Midjourney for visual inspiration on design and for meme's and jokes with friends. I feel fine using it and always make sure to rewrite everything in my own words. Within image generation, I have no choice but to recreate things myself because MidJourney doesn't provide source files (layers) or print quality content.
#
#
# 1) To check if chatgpt can solve homework problems correctly and/or provide correct reasoning. 2) To generate a homework problem where I gave an example of chatgpt getting the wrong (but convincing) answer and asking the students to correct it.
#
#
# For teaching, modify quiz questions, generate ideas for new quiz questions, for research, not much since info tends to be sketchy
#
#
# We tried searching for journal articles on pumping underpressured geothermal aquifers. It gave us four references that looked legitimate, i.e. they were from journals like Geothermics, the authors were people who publish on relevant material, there were volume and page numbers, etc. When we tried looking them up we found that the articles did not exist. Conclusion: This technology is not ready for serious use.
#
#
# I used ChatGPT originally just to test it out. Then I had a report from Turnitin that a student's paper looked suspicious for being AI generated, so I used an app to see if it came to the same conclusion. The results were conflicting, so I didn't take action against the student, but I am troubled by the possibility that students are cheating and wondering how to design assignments to assess mastery that don't involve in-class time. I have also used ChatGPT for generating basic outlines on subjects that I am preparing to lecture on in class. I use those outlines to help organize my plan for the lecture, but then I go to trustworthy expert source materials for data, quotes, and other information I want to reference in my talk or on my slides. I do not use any language from the LLM results nor do I rely on the accuracy of the results. I only use it as a starting point, much like one would use Google Scholar or other online research tools to refresh memory or see how another source has organized the information.I don't know that the results are all that helpful since I can't trust the accuracy because sources aren't cited to, so the only information/analysis that can be trusted is that which jibes with what I already know from my experience in the field. It marginally speeds up the process of preparing lectures, but not enough that I would use it regularly.
#
#
# First passes at proposal writing/rewriting when writers block strikes. They provide a starting point, that I can then retool appropriately.
#
#
# I've started using code generation features to write short scripts that will automate tasks that I'm too lazy to automate myself. Most of the time I'm happy with the results and it saves me some time. I have always relied heavily on grammar/spell checking and have am increasingly using word processing applications with AI back-ends for writing in my professional and personal life OUTSIDE Mines. I am aware that the free/public versions of these tools may ingest anything I write, so I am currently avoiding using them for anything course related.
#
#
# They generally provide a good starting point for new literature reviews.
#
#
# I use ChatGPT to help with coding. It helps to have something provide me syntax. I also use it to change the wording of things I've written to get more ideas on wording.
#
#
# I've used ChatGPT for research and professional efforts to generate code and references to online resources. This tool has saved me tens of hours compared to traditional search engines like Google. This tool can generate false data but it is very useful if you are knowledgeable about the topic and are able to sanitize the results.
#
#
# Used them to share with students that these tools exist and we need to understand them, how to use them, and when to use them.
#
#
# I used chatGPT to refine the writing of a student's final report for my future use as an exemplary report.
#
#
# Never used
#
#
# No
#
#
# I have tried asking ChatGPT the same questions in my homework assignments to see if it could get the answers correctly and to get accustomed to what GPT solutions might look like in case students would plagiarize. I found that in many instances I could not distinguish between ChatGPT's solutions and a student submission (even if the answer is incorrect), so it would be very difficult to tell if a student is using ChatGPT to do the thinking for them.
#
#
# I have used the LLMs for pulling summaries of the current state of technology in certain fields and for organizing/improving text.
#
#
# I have used them to help me brainstorm paper titles. I didn't use any of the suggestions, but it helped me think of a better title. I think we should be explicit in our expectations with students. Students are going to use them, so we need to ensure they use them responsibly. Yes, they might solve undergraduate level problems in some classes, but they aren't going to solve the big open problems out there. Our students need to be good at those basic problems so they are ready to tackle the problems we face.
#
#
# I have used them to save time on questions I would usually google. I have found that they have been able to direct me to key sources or quotations that might take longer to find on my own.
#
#
# Asked for summary of a specific scientific research approach. The answer was not detailed/specific enough to be of much use. I also once fed the text of an abstract into ChatGPT and asked for it to be shortened. Since playing around with ChatGPT a few times, I have mostly forgotten about it and don't really even think to try to use it in my daily professional life. My few attempts to make use of it were not all that beneficial.
#
#
# It seems that tools like ChatGPT are excellent at summarizing. So it can help me reduce word count, or summarize the key points of a much longer document.
#
#
# Used Chat GPT for basic research
#
#
# Mostly out of curiosity: Seeing what it would generate as readings/viewings for classes similar to the ones I'm teaching this semester (ChatGPT), and I've had DALL-E make some images about the topics of chapters of a book I'm currently researching.
#
#
# Used to provide examples to students for how they can use AI tools effectively.
#
#
# I wanted students to see how the cultural adaptation theories in my class map to how ChatGPT described them. Students will analyze the ChatGPT responses in terms of how well they align with established research. I'm hoping that shows them how useful yet superficial responses from ChatGPT can be compared to such research.
#
#
# Really just playing around with chatGPT to see what answers it gives to simple definition question sin introductory geology. I've had some students use ChatGPT to answer questions nd tell me that they did so I can look at the answers it spits out. This was right when it first came out and it was out of curiosity by both myself and some students. I think it has some place in helping students find useful information and synthesize it. I suspect I have had students use it to answer questions at some times, but didn't investigate much as the answers were not great, especially when it required referred to others parts of the assignment.
#
#
# I have never used
#
#
# I explored ChatGPT over the summer to see how it would respond to essay prompts we use in class, and how it would do with lesson planning from a prompt. I was impressed by the lesson planning capability and can imagine that being useful in the brainstorming phase of a new lesson plan or activity. The essay it produced in response to our prompt was easily recognizable as AI generated because it was so blatantly formulaic and generic, and essentially perfect in grammar/spelling. However, I could imagine a student turning in something not too different that they had written themselves; we see generic writing from students all the time who have not yet learned to delve deeply into a topic. So it did raise concerns for me about how I would differentiate between AI writing and unsophisticated student writing. I would like to explore using Chat GPT as a revision tool for written work, but ethically I am not comfortable with requiring students to input their own writing, knowing that ChatGPT then can use that writing in its model. So I'm not currently planning to use ChatGPT or similar for class, but it's something I am curious to explore, and I am not opposed to students voluntarily using it as a tool to analyze and improve their own writing.
#
#
# I wanted to see how they worked. I have not used it for any writing purposes, yet.
#
#
# I've used both LLMs and coding assistance tools to help explain advanced concepts or write boilerplate code to accelerate my efforts.
#
#
# The AI can provide a starting point, or help with problem solving. Very good a providing boilerplate text, which saves me time. Image generation tools can be helpful producing images to meet a specific purpose.
#
#
# Yes. For GPGN436/536 geophysics computing. I allow the students to use it for debugging and generate codes to solve actual physical problem.
#
#
# I have use ChatGPT to generate first drafts of text for course/workshop/modules. I have also played with image generators. The tools are only as good as the inputs/prompts that are used to generate the end product. It's a skill that needs to be learned.
#
#
# I used them to help write learning outcomes, summarize research papers, and generate ideas for assignments.
#
#
# Usually as an editor for professional writing -- will write a first draft and then feed it in to see whether there are better ways to phrase things and make the writing more concise (paragraph by paragraph, usually). Often, I reject the outputs, but it's nice to have a way to have a back and forth to see if there are improvements
#
#
# Refine text.
#
#
# i have used them to show students the incredible limitations of these tools, how they skip past actual learning to arrive at 'remembering' versus 'learning'
#
#
# I have a class-wide paid ChatGPT (ie GPT 4) account that I encourage them to use when coding for their homework. I want students to be able to focus on the physics that they can learn from simulations and not on the coding itself. Not all students are using these tools but some students who are weaker at programming are finding these tools to be valuable. While I am nervous about having a 'crutch' for students learning to program, I think the reality of the world is that these tools are here and students need to learn to use them efficiently to do science.
#
#
# I generated a syllabus and a reading list, mostly to see what ChatGBT could do. The syllabus was okay--the topics were sensible but not very interesting. The reading list had titles that do not exist. Interestingly, it had authors who work in that domain, but the actual books/articles didn't exist. Of 20 titles, three weren't real. I was pretty disappointed in the results--you have to know more than ChatGBT to assess whether it's accurate/appropriate. I suppose it did help confirm that I wasn't missing anything important?
#
#
# Help to generate example code and some questions for quizzes
#
#
# I let them use LLM in the classroom after they had done idea generation on their own.
#
#
# Fast, coherent answers to questions, and to start a conversation.
#
#
# I have played with them to see what kind of output they generate. I have tried prompting to generate messages, speeches, homework responses. I wasn't particularly impressed with the output--it all seemed quite generic, not tightly crafted, and definitely did not sound like my writing. But it was good to see what can be generated. I do think that these tools could be really useful in helping students polish their writing, though I haven't tested that yet. I am concerned that students may be tempted to rely on these tools to generate responses, though I suppose it's just another means by which students can avoid doing their own work.
#
#
# I have used AI to find language and help create job descriptions
#
#
# Yes--used chat gpt to help with lecture materials
#
#
# Never used.
#
#
# On the first day of class, I discussed the use of Chat-GPT and demonstrated that it can provide good answers for most (but not all) of the questions on the first few homework assignments. I use ChatGPT frequently for coding assistance, background information on topics outside my areas of expertise, and providing rephrasings of sentences when writing. In general I feel quite positive about these tools
#
#
# My work program is hosted on Gitlab and our project uses a set of security scanning tools as part of our normal build process. We also keep abreast of these tools as they apply to computer security.
#
#
# I rely heavily on ChatGPT both for generating assignments and grading rubrics for those assignments as well as requiring students to use ChatGPT for weekly written assignment submissions. I also use ChatGPT as an ideation technique in my project-based courses.
#
#
# I asked ChatGPT to suggest solutions to an intermediate level Verilog coding challenge, since Verilog is new to me. Its suggestions were plausible and interesting, but ultimately didn't work, even after several attempts. However, its responses to the simpler prompt, 'Explain Verilog with simple examples,' was impressively good.
#
#
# Brainstorming
#
#
# I tried Chat GPT to see how it would do at writing an exam question. The problem looked ok at a glance, but it had some ambiguity issues and was not very well defined and didn't address the higher order LO's like I'd hoped. I had Chat GPT generate a solution to its own question twice. It came up with two different solutions, both ok but neither great. I thought it would be a great exercise for the students to analyze the generated question and answers (telling them they were generated by AI) and write a critique of the problem demonstrating their knowledge of the course content in their analysis. I gave this as an optional 5 pt bonus problem for the exam and wrote my own problems for the exam itself. The students did ok (some great and some not so great) at the bonus problem assignment. I really like the idea of having students analyze the veracity of questions and answers generated by AI and assess them on their knowledge of the course content through how well they do and justify that critical analysis. I've added this as a learning outcome to one course so far this semester. I also used Chat GPT to get a first pass at a set of learning outcomes for a new course I'm developing. It did a decent job at giving me a place to start and I edited from there. I used it in the first case to try to create an interesting assessment and I used it in the second case to save myself time and I feel fine about both uses.
#
#
# Have used ChatGPT for help with some writing projects, coming up with simplified summaries of more complicated concepts, and as a quick alternative to a search engine query
#
#
# For work, I've used them to brainstorm different ideas based on a questions or theme, edit text for emails and a few documents, and draft/edit Arduino and MATLAB code. I have also used image generators to create images for fun (not work).
#
#
# Using ChatGPT in my PhD research.
#
#
# We ask AI questions related to class concepts and discuss the accuracy of the responses.
#
#
# I enjoy using image generators to create evocative or thought-provoking images to 'set the tone' of my slide decks/presentations for classes or research meetings, and to have conversations about the nature of AI and human-AI interaction. I often use LLMs in a more exploratory manner. I've used them to generate sample materials to support conversations with my students (e.g. what should a letter of recommendation look like? Here, let's see what ChatGPT spits out for a crappy baseline, that we can then improve.) I've also used them to ask about resources the students could use in their projects (e.g., a prompt I used recently was 'what are some psychometric scales for measuring loneliness and social isolation?). This saved me the time of having to look them up myself. I found it quicker to use ChatGPT rather than Google to help point students in a good direction, while I also told them they needed to look up original papers and ensure accuracy. (So, also using this interaction as an opportunity to educate them about best practices for using genAI.)

# %%
count = 0
for i in range(len(um)):
    if not pd.isna(um.iloc[i]):
        print(response_id.iloc[i])
        print(role.iloc[i])
        print(um.iloc[i])
        print("\n")
        count += 1
# Out:
# 114801644.0
# Tenure track faculty  Associate professor
# Generating images for research talks and discussing research ideas with ChatGPT
#
#
# 114801654.0
# Administrative faculty
# Information on administrative policies and procedures. Ok to use them as long as you are not presenting the information as your own.
#
#
# 114801670.0
# Administrative faculty
# I use ChatGPT daily to draft friendly emails, policies, proposals, goals and sometimes images. It's like having a team of assistants that understand my every request and never second guess themselves. Never do I use the first response, but after a few prompts I end up with a helluva first draft. At the very least, I end up with a good structure. ChatGPT allows me to spend my time making progress instead of creating documents. I'll never go back.
#
#
# 114801704.0
# Teaching faculty  Full professor
# Never
#
#
# 114801781.0
# Tenure track faculty  Assistant professor
# I've used chatGPT to translate code between languages and edit (shorten) text, as well as to get instructions on using a new software tool. I have found it sometimes helpful, but also dangerously often wrong. I have also asked it questions like 'what are the biggest unsolved problems in field x' - to explore/understand the tool (and its training data).
#
#
# 114801906.0
# Other (Please specify)
# Help with coding websites
#
#
# 114801956.0
# Administrative faculty
# n/a- never used
#
#
# 114802421.0
# Administrative faculty
# I have used the image generator specifically to create images to discuss how this technology works.
#
#
# 114802886.0
# Teaching faculty  Associate professor
# I used literature review and coding for research
#
#
# 114803243.0
# Tenure track faculty  Assistant professor
# Have not used for classes
#
#
# 114803641.0
# Teaching faculty  Associate professor
# ChatGPT is great for summarizing blocks of text. I've used it to summarize the major accomplishments of students when preparing student award speeches.
#
#
# 114803953.0
# Tenure track faculty  Assistant professor
# LLMs like ChatGPT are useful for generating early drafts for e.g. proposals and papers at the level of individual paragraphs. They are also useful for generating alternative ways of writing small pieces of text more clearly. Other LLMs like Bing are useful for very rapid literature searches. However, their utility is currently limited to extremely superficial work. While this can be enough for initial drafts and initial literature searches, their utility in anything requiring deep or careful thought is extremely limited. What is important, however, is that the pace of these LLMs' development, which suggests that in the near future their capabilities will be far more impactful.
#
#
# 114804700.0
# Teaching faculty  Assistant professor
# I used image generation to help imagine label designs for gin. Basically to get the gears turning creatively and maybe provide a sort of halfway there example to artists who would potentially make the final version of a given label. I felt the tool was great for inspiration, but I'm concerned about how it uses artists' works to fuel its creation. For example, if I gave it a prompt to make an image in the style of one of my friend's work, it would obligingly put out a convincing piece of work similar to theirs. If someone commercialized it, my friend wouldn't get a dime. So, while I can see the use for inspiration and creative fuel, I worry that it will also result in artists having their style copied without any form of compensation.
#
#
# 114807503.0
# Administrative faculty
# I use them to create rough, foundational drafts or outlines for content. I input my text into chat GPT and I ask it to make my writing more concise. I use Midjourney for visual inspiration on design and for meme's and jokes with friends. I feel fine using it and always make sure to rewrite everything in my own words. Within image generation, I have no choice but to recreate things myself because MidJourney doesn't provide source files (layers) or print quality content.
#
#
# 114808670.0
# Teaching faculty  Full professor
# 1) To check if chatgpt can solve homework problems correctly and/or provide correct reasoning. 2) To generate a homework problem where I gave an example of chatgpt getting the wrong (but convincing) answer and asking the students to correct it.
#
#
# 114808702.0
# Tenure track faculty  Assistant professor
# For teaching, modify quiz questions, generate ideas for new quiz questions, for research, not much since info tends to be sketchy
#
#
# 114809718.0
# Adjunct faculty
# We tried searching for journal articles on pumping underpressured geothermal aquifers. It gave us four references that looked legitimate, i.e. they were from journals like Geothermics, the authors were people who publish on relevant material, there were volume and page numbers, etc. When we tried looking them up we found that the articles did not exist. Conclusion: This technology is not ready for serious use.
#
#
# 114810278.0
# Adjunct faculty
# I used ChatGPT originally just to test it out. Then I had a report from Turnitin that a student's paper looked suspicious for being AI generated, so I used an app to see if it came to the same conclusion. The results were conflicting, so I didn't take action against the student, but I am troubled by the possibility that students are cheating and wondering how to design assignments to assess mastery that don't involve in-class time. I have also used ChatGPT for generating basic outlines on subjects that I am preparing to lecture on in class. I use those outlines to help organize my plan for the lecture, but then I go to trustworthy expert source materials for data, quotes, and other information I want to reference in my talk or on my slides. I do not use any language from the LLM results nor do I rely on the accuracy of the results. I only use it as a starting point, much like one would use Google Scholar or other online research tools to refresh memory or see how another source has organized the information.I don't know that the results are all that helpful since I can't trust the accuracy because sources aren't cited to, so the only information/analysis that can be trusted is that which jibes with what I already know from my experience in the field. It marginally speeds up the process of preparing lectures, but not enough that I would use it regularly.
#
#
# 114810380.0
# Tenure track faculty  Associate professor
# First passes at proposal writing/rewriting when writers block strikes. They provide a starting point, that I can then retool appropriately.
#
#
# 114822072.0
# Teaching faculty  Associate professor
# I've started using code generation features to write short scripts that will automate tasks that I'm too lazy to automate myself. Most of the time I'm happy with the results and it saves me some time. I have always relied heavily on grammar/spell checking and have am increasingly using word processing applications with AI back-ends for writing in my professional and personal life OUTSIDE Mines. I am aware that the free/public versions of these tools may ingest anything I write, so I am currently avoiding using them for anything course related.
#
#
# 114824850.0
# Tenure track faculty  Full professor
# They generally provide a good starting point for new literature reviews.
#
#
# 114844744.0
# Postdoctoral staff or research faculty
# I use ChatGPT to help with coding. It helps to have something provide me syntax. I also use it to change the wording of things I've written to get more ideas on wording.
#
#
# 114849738.0
# Administrative faculty
# I've used ChatGPT for research and professional efforts to generate code and references to online resources. This tool has saved me tens of hours compared to traditional search engines like Google. This tool can generate false data but it is very useful if you are knowledgeable about the topic and are able to sanitize the results.
#
#
# 114849752.0
# Tenure track faculty  Full professor
# Used them to share with students that these tools exist and we need to understand them, how to use them, and when to use them.
#
#
# 114850983.0
# Adjunct faculty
# I used chatGPT to refine the writing of a student's final report for my future use as an exemplary report.
#
#
# 114851226.0
# Teaching faculty  Assistant professor
# Never used
#
#
# 114858021.0
# Tenure track faculty  Associate professor
# No
#
#
# 114867495.0
# Teaching faculty  Full professor
# I have tried asking ChatGPT the same questions in my homework assignments to see if it could get the answers correctly and to get accustomed to what GPT solutions might look like in case students would plagiarize. I found that in many instances I could not distinguish between ChatGPT's solutions and a student submission (even if the answer is incorrect), so it would be very difficult to tell if a student is using ChatGPT to do the thinking for them.
#
#
# 114874217.0
# Administrative faculty
# I have used the LLMs for pulling summaries of the current state of technology in certain fields and for organizing/improving text.
#
#
# 114879598.0
# Teaching faculty  Full professor
# I have used them to help me brainstorm paper titles. I didn't use any of the suggestions, but it helped me think of a better title. I think we should be explicit in our expectations with students. Students are going to use them, so we need to ensure they use them responsibly. Yes, they might solve undergraduate level problems in some classes, but they aren't going to solve the big open problems out there. Our students need to be good at those basic problems so they are ready to tackle the problems we face.
#
#
# 114879842.0
# Adjunct faculty
# I have used them to save time on questions I would usually google. I have found that they have been able to direct me to key sources or quotations that might take longer to find on my own.
#
#
# 114890869.0
# Tenure track faculty  Full professor
# Asked for summary of a specific scientific research approach. The answer was not detailed/specific enough to be of much use. I also once fed the text of an abstract into ChatGPT and asked for it to be shortened. Since playing around with ChatGPT a few times, I have mostly forgotten about it and don't really even think to try to use it in my daily professional life. My few attempts to make use of it were not all that beneficial.
#
#
# 114899737.0
# Tenure track faculty  Associate professor
# It seems that tools like ChatGPT are excellent at summarizing. So it can help me reduce word count, or summarize the key points of a much longer document.
#
#
# 114938657.0
# Teaching faculty  Full professor
# Used Chat GPT for basic research
#
#
# 114960372.0
# Teaching faculty  Associate professor
# Mostly out of curiosity: Seeing what it would generate as readings/viewings for classes similar to the ones I'm teaching this semester (ChatGPT), and I've had DALL-E make some images about the topics of chapters of a book I'm currently researching.
#
#
# 115065414.0
# Administrative faculty
# Used to provide examples to students for how they can use AI tools effectively.
#
#
# 115112276.0
# Tenure track faculty  Full professor
# I wanted students to see how the cultural adaptation theories in my class map to how ChatGPT described them. Students will analyze the ChatGPT responses in terms of how well they align with established research. I'm hoping that shows them how useful yet superficial responses from ChatGPT can be compared to such research.
#
#
# 115155132.0
# Teaching faculty  Assistant professor
# Really just playing around with chatGPT to see what answers it gives to simple definition question sin introductory geology. I've had some students use ChatGPT to answer questions nd tell me that they did so I can look at the answers it spits out. This was right when it first came out and it was out of curiosity by both myself and some students. I think it has some place in helping students find useful information and synthesize it. I suspect I have had students use it to answer questions at some times, but didn't investigate much as the answers were not great, especially when it required referred to others parts of the assignment.
#
#
# 115172053.0
# Teaching faculty  Full professor
# I have never used
#
#
# 115174637.0
# Teaching faculty  Assistant professor
# I explored ChatGPT over the summer to see how it would respond to essay prompts we use in class, and how it would do with lesson planning from a prompt. I was impressed by the lesson planning capability and can imagine that being useful in the brainstorming phase of a new lesson plan or activity. The essay it produced in response to our prompt was easily recognizable as AI generated because it was so blatantly formulaic and generic, and essentially perfect in grammar/spelling. However, I could imagine a student turning in something not too different that they had written themselves; we see generic writing from students all the time who have not yet learned to delve deeply into a topic. So it did raise concerns for me about how I would differentiate between AI writing and unsophisticated student writing. I would like to explore using Chat GPT as a revision tool for written work, but ethically I am not comfortable with requiring students to input their own writing, knowing that ChatGPT then can use that writing in its model. So I'm not currently planning to use ChatGPT or similar for class, but it's something I am curious to explore, and I am not opposed to students voluntarily using it as a tool to analyze and improve their own writing.
#
#
# 115245867.0
# Other (Please specify)
# I wanted to see how they worked. I have not used it for any writing purposes, yet.
#
#
# 115297907.0
# Adjunct faculty
# I've used both LLMs and coding assistance tools to help explain advanced concepts or write boilerplate code to accelerate my efforts.
#
#
# 115394412.0
# Tenure track faculty  Full professor
# The AI can provide a starting point, or help with problem solving. Very good a providing boilerplate text, which saves me time. Image generation tools can be helpful producing images to meet a specific purpose.
#
#
# 115405026.0
# Tenure track faculty  Assistant professor
# Yes. For GPGN436/536 geophysics computing. I allow the students to use it for debugging and generate codes to solve actual physical problem.
#
#
# 115442779.0
# Administrative faculty
# I have use ChatGPT to generate first drafts of text for course/workshop/modules. I have also played with image generators. The tools are only as good as the inputs/prompts that are used to generate the end product. It's a skill that needs to be learned.
#
#
# 115446143.0
# Teaching faculty  Assistant professor
# I used them to help write learning outcomes, summarize research papers, and generate ideas for assignments.
#
#
# 115446166.0
# nan
# Usually as an editor for professional writing -- will write a first draft and then feed it in to see whether there are better ways to phrase things and make the writing more concise (paragraph by paragraph, usually). Often, I reject the outputs, but it's nice to have a way to have a back and forth to see if there are improvements
#
#
# 115446173.0
# Tenure track faculty  Full professor
# Refine text.
#
#
# 115446216.0
# Teaching faculty  Full professor
# i have used them to show students the incredible limitations of these tools, how they skip past actual learning to arrive at 'remembering' versus 'learning'
#
#
# 115446222.0
# Tenure track faculty  Full professor
# I have a class-wide paid ChatGPT (ie GPT 4) account that I encourage them to use when coding for their homework. I want students to be able to focus on the physics that they can learn from simulations and not on the coding itself. Not all students are using these tools but some students who are weaker at programming are finding these tools to be valuable. While I am nervous about having a 'crutch' for students learning to program, I think the reality of the world is that these tools are here and students need to learn to use them efficiently to do science.
#
#
# 115446661.0
# Teaching faculty  Full professor
# I generated a syllabus and a reading list, mostly to see what ChatGBT could do. The syllabus was okay--the topics were sensible but not very interesting. The reading list had titles that do not exist. Interestingly, it had authors who work in that domain, but the actual books/articles didn't exist. Of 20 titles, three weren't real. I was pretty disappointed in the results--you have to know more than ChatGBT to assess whether it's accurate/appropriate. I suppose it did help confirm that I wasn't missing anything important?
#
#
# 115446706.0
# Adjunct faculty
# Help to generate example code and some questions for quizzes
#
#
# 115446734.0
# Teaching faculty  Associate professor
# I let them use LLM in the classroom after they had done idea generation on their own.
#
#
# 115447557.0
# Teaching faculty  Full professor
# Fast, coherent answers to questions, and to start a conversation.
#
#
# 115447710.0
# Tenure track faculty  Full professor
# I have played with them to see what kind of output they generate. I have tried prompting to generate messages, speeches, homework responses. I wasn't particularly impressed with the output--it all seemed quite generic, not tightly crafted, and definitely did not sound like my writing. But it was good to see what can be generated. I do think that these tools could be really useful in helping students polish their writing, though I haven't tested that yet. I am concerned that students may be tempted to rely on these tools to generate responses, though I suppose it's just another means by which students can avoid doing their own work.
#
#
# 115447927.0
# Administrative faculty
# I have used AI to find language and help create job descriptions
#
#
# 115448224.0
# Tenure track faculty  Associate professor
# Yes--used chat gpt to help with lecture materials
#
#
# 115449020.0
# Tenure track faculty  Associate professor
# Never used.
#
#
# 115449138.0
# Tenure track faculty  Assistant professor
# On the first day of class, I discussed the use of Chat-GPT and demonstrated that it can provide good answers for most (but not all) of the questions on the first few homework assignments. I use ChatGPT frequently for coding assistance, background information on topics outside my areas of expertise, and providing rephrasings of sentences when writing. In general I feel quite positive about these tools
#
#
# 115449890.0
# Adjunct faculty
# My work program is hosted on Gitlab and our project uses a set of security scanning tools as part of our normal build process. We also keep abreast of these tools as they apply to computer security.
#
#
# 115451189.0
# Teaching faculty  Associate professor
# I rely heavily on ChatGPT both for generating assignments and grading rubrics for those assignments as well as requiring students to use ChatGPT for weekly written assignment submissions. I also use ChatGPT as an ideation technique in my project-based courses.
#
#
# 115451837.0
# Administrative faculty
# I asked ChatGPT to suggest solutions to an intermediate level Verilog coding challenge, since Verilog is new to me. Its suggestions were plausible and interesting, but ultimately didn't work, even after several attempts. However, its responses to the simpler prompt, 'Explain Verilog with simple examples,' was impressively good.
#
#
# 115452781.0
# Professor of practice
# Brainstorming
#
#
# 115454316.0
# Teaching faculty  Full professor
# I tried Chat GPT to see how it would do at writing an exam question. The problem looked ok at a glance, but it had some ambiguity issues and was not very well defined and didn't address the higher order LO's like I'd hoped. I had Chat GPT generate a solution to its own question twice. It came up with two different solutions, both ok but neither great. I thought it would be a great exercise for the students to analyze the generated question and answers (telling them they were generated by AI) and write a critique of the problem demonstrating their knowledge of the course content in their analysis. I gave this as an optional 5 pt bonus problem for the exam and wrote my own problems for the exam itself. The students did ok (some great and some not so great) at the bonus problem assignment. I really like the idea of having students analyze the veracity of questions and answers generated by AI and assess them on their knowledge of the course content through how well they do and justify that critical analysis. I've added this as a learning outcome to one course so far this semester. I also used Chat GPT to get a first pass at a set of learning outcomes for a new course I'm developing. It did a decent job at giving me a place to start and I edited from there. I used it in the first case to try to create an interesting assessment and I used it in the second case to save myself time and I feel fine about both uses.
#
#
# 115455720.0
# Postdoctoral staff or research faculty
# Have used ChatGPT for help with some writing projects, coming up with simplified summaries of more complicated concepts, and as a quick alternative to a search engine query
#
#
# 115458823.0
# Teaching faculty  Associate professor
# For work, I've used them to brainstorm different ideas based on a questions or theme, edit text for emails and a few documents, and draft/edit Arduino and MATLAB code. I have also used image generators to create images for fun (not work).
#
#
# 115473179.0
# Teaching faculty  Associate professor
# Using ChatGPT in my PhD research.
#
#
# 115488174.0
# Tenure track faculty  Full professor
# We ask AI questions related to class concepts and discuss the accuracy of the responses.
#
#
# 115496611.0
# Tenure track faculty  Assistant professor
# I enjoy using image generators to create evocative or thought-provoking images to 'set the tone' of my slide decks/presentations for classes or research meetings, and to have conversations about the nature of AI and human-AI interaction. I often use LLMs in a more exploratory manner. I've used them to generate sample materials to support conversations with my students (e.g. what should a letter of recommendation look like? Here, let's see what ChatGPT spits out for a crappy baseline, that we can then improve.) I've also used them to ask about resources the students could use in their projects (e.g., a prompt I used recently was 'what are some psychometric scales for measuring loneliness and social isolation?). This saved me the time of having to look them up myself. I found it quicker to use ChatGPT rather than Google to help point students in a good direction, while I also told them they needed to look up original papers and ensure accuracy. (So, also using this interaction as an opportunity to educate them about best practices for using genAI.)

# %%
print(count)
# Out:
# 69

# %%
import sys
sys.path.append('../scripts')  # Adjust path as needed
from module import (
    count_usage_cases,
    create_degree_lists,
    count_cluster_wise,
    pre_vec,
    nordept,
    deptwisecount,
    normalized_dept_cluster,
    create_vector,
    create_vector2,
    clear_vec,
    culster_wise_val,
    create_con_table,
    chi_square_test,
    residuals_cal,
    create_group,
    normality_test,
    agostino_pearson_test,
    kruskal_wallis_test
)
from plots import ( grouped_bar_graph_horizontal_color, stacked_bar_graph, grouped_bar_graph_horizontal_color_white, boxplot,
    kde_plot,
    heatmap_plot
)

# %%
# designation vs frequency usages

# %%
role = df_new["What is your current role at Mines?"]
role.unique()

for value in role:
    if value == "Tenure track faculty  Full professor":
        print("Y")
# Out:
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y
# Y

# %%
role.value_counts()
# Out:
# What is your current role at Mines?
# Administrative faculty                        16
# Tenure track faculty  Full professor         16
# Teaching faculty  Full professor             13
# Adjunct faculty                               10
# Tenure track faculty  Associate professor     9
# Tenure track faculty  Assistant professor     8
# Teaching faculty  Associate professor         8
# Teaching faculty  Assistant professor         6
# Postdoctoral staff or research faculty         4
# Other (Please specify)                         2
# Professor of practice                          2
# Name: count, dtype: int64

# %%
contigency_table = create_con_table(role, genai)

# %%
contigency_table
# Out:
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts  All the time (daily, or more often)  \
# What is your current role at Mines?
# Adjunct faculty                                                                                                                                                               1
# Administrative faculty                                                                                                                                                        1
# Other (Please specify)                                                                                                                                                        0
# Postdoctoral staff or research faculty                                                                                                                                        1
# Professor of practice                                                                                                                                                         0
# Teaching faculty  Assistant professor                                                                                                                                        0
# Teaching faculty  Associate professor                                                                                                                                        2
# Teaching faculty  Full professor                                                                                                                                             0
# Tenure track faculty  Assistant professor                                                                                                                                    3
# Tenure track faculty  Associate professor                                                                                                                                    0
# Tenure track faculty  Full professor                                                                                                                                         1
#
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts  Have only used for fun or curiosity, never work  \
# What is your current role at Mines?
# Adjunct faculty                                                                                                                                                                           0
# Administrative faculty                                                                                                                                                                    0
# Other (Please specify)                                                                                                                                                                    0
# Postdoctoral staff or research faculty                                                                                                                                                    1
# Professor of practice                                                                                                                                                                     0
# Teaching faculty  Assistant professor                                                                                                                                                    1
# Teaching faculty  Associate professor                                                                                                                                                    0
# Teaching faculty  Full professor                                                                                                                                                         2
# Tenure track faculty  Assistant professor                                                                                                                                                1
# Tenure track faculty  Associate professor                                                                                                                                                1
# Tenure track faculty  Full professor                                                                                                                                                     0
#
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts  Never  \
# What is your current role at Mines?
# Adjunct faculty                                                                                                                                 4
# Administrative faculty                                                                                                                          6
# Other (Please specify)                                                                                                                          0
# Postdoctoral staff or research faculty                                                                                                          1
# Professor of practice                                                                                                                           1
# Teaching faculty  Assistant professor                                                                                                          2
# Teaching faculty  Associate professor                                                                                                          0
# Teaching faculty  Full professor                                                                                                               3
# Tenure track faculty  Assistant professor                                                                                                      1
# Tenure track faculty  Associate professor                                                                                                      4
# Tenure track faculty  Full professor                                                                                                           6
#
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts  Once or Twice  \
# What is your current role at Mines?
# Adjunct faculty                                                                                                                                         5
# Administrative faculty                                                                                                                                  5
# Other (Please specify)                                                                                                                                  2
# Postdoctoral staff or research faculty                                                                                                                  1
# Professor of practice                                                                                                                                   0
# Teaching faculty  Assistant professor                                                                                                                  2
# Teaching faculty  Associate professor                                                                                                                  3
# Teaching faculty  Full professor                                                                                                                       7
# Tenure track faculty  Assistant professor                                                                                                              1
# Tenure track faculty  Associate professor                                                                                                              3
# Tenure track faculty  Full professor                                                                                                                   5
#
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts  Regularly (Once or twice a week)
# What is your current role at Mines?
# Adjunct faculty                                                                                                                                                            0
# Administrative faculty                                                                                                                                                     4
# Other (Please specify)                                                                                                                                                     0
# Postdoctoral staff or research faculty                                                                                                                                     0
# Professor of practice                                                                                                                                                      1
# Teaching faculty  Assistant professor                                                                                                                                     1
# Teaching faculty  Associate professor                                                                                                                                     3
# Teaching faculty  Full professor                                                                                                                                          1
# Tenure track faculty  Assistant professor                                                                                                                                 2
# Tenure track faculty  Associate professor                                                                                                                                 1
# Tenure track faculty  Full professor                                                                                                                                      4

# %%
# Chi-square is unreliable as cells don't have value >= 5

# %%
# Regression: Frequency usages as dependent variable and Role as IV

# %%
data = pd.DataFrame({
    'Role': role,
    'Usage': genai
})

# %%
data['Role']
# Out:
# 8      Tenure track faculty  Associate professor
# 9                          Administrative faculty
# 10                         Administrative faculty
# 11              Teaching faculty  Full professor
# 13          Tenure track faculty  Full professor
#                           ...
# 137         Tenure track faculty  Full professor
# 138        Teaching faculty  Associate professor
# 139         Tenure track faculty  Full professor
# 140         Tenure track faculty  Full professor
# 141    Tenure track faculty  Assistant professor
# Name: Role, Length: 95, dtype: object

# %%
from pandas.api.types import CategoricalDtype

# Define usage order
usage_order = CategoricalDtype(categories=['Never', 'Have only used for fun or curiosity, never work', 'Once or Twice', 'Regularly (Once or twice a week)', 'All the time (daily, or more often)'], ordered=True)

data['Usage'] = data['Usage'].astype(usage_order)

# %%
data['Usage']
# Out:
# 8         Regularly (Once or twice a week)
# 9                            Once or Twice
# 10     All the time (daily, or more often)
# 11                                   Never
# 13                                   Never
#                       ...
# 137                          Once or Twice
# 138    All the time (daily, or more often)
# 139                                  Never
# 140       Regularly (Once or twice a week)
# 141       Regularly (Once or twice a week)
# Name: Usage, Length: 95, dtype: category
# Categories (5, object): ['Never' < 'Have only used for fun or curiosity, never work' < 'Once or Twice' < 'Regularly (Once or twice a week)' < 'All the time (daily, or more often)']

# %%
X = pd.get_dummies(data['Role'], drop_first=True)  # drop_first avoids multicollinearity

# %%
X
# Out:
#      Administrative faculty  Other (Please specify)  \
# 8                     False                   False
# 9                      True                   False
# 10                     True                   False
# 11                    False                   False
# 13                    False                   False
# ..                      ...                     ...
# 137                   False                   False
# 138                   False                   False
# 139                   False                   False
# 140                   False                   False
# 141                   False                   False
#
#      Postdoctoral staff or research faculty  Professor of practice  \
# 8                                     False                  False
# 9                                     False                  False
# 10                                    False                  False
# 11                                    False                  False
# 13                                    False                  False
# ..                                      ...                    ...
# 137                                   False                  False
# 138                                   False                  False
# 139                                   False                  False
# 140                                   False                  False
# 141                                   False                  False
#
#      Teaching faculty  Assistant professor  \
# 8                                     False
# 9                                     False
# 10                                    False
# 11                                    False
# 13                                    False
# ..                                      ...
# 137                                   False
# 138                                   False
# 139                                   False
# 140                                   False
# 141                                   False
#
#      Teaching faculty  Associate professor  \
# 8                                     False
# 9                                     False
# 10                                    False
# 11                                    False
# 13                                    False
# ..                                      ...
# 137                                   False
# 138                                    True
# 139                                   False
# 140                                   False
# 141                                   False
#
#      Teaching faculty  Full professor  \
# 8                                False
# 9                                False
# 10                               False
# 11                                True
# 13                               False
# ..                                 ...
# 137                              False
# 138                              False
# 139                              False
# 140                              False
# 141                              False
#
#      Tenure track faculty  Assistant professor  \
# 8                                         False
# 9                                         False
# 10                                        False
# 11                                        False
# 13                                        False
# ..                                          ...
# 137                                       False
# 138                                       False
# 139                                       False
# 140                                       False
# 141                                        True
#
#      Tenure track faculty  Associate professor  \
# 8                                          True
# 9                                         False
# 10                                        False
# 11                                        False
# 13                                        False
# ..                                          ...
# 137                                       False
# 138                                       False
# 139                                       False
# 140                                       False
# 141                                       False
#
#      Tenure track faculty  Full professor
# 8                                    False
# 9                                    False
# 10                                   False
# 11                                   False
# 13                                    True
# ..                                     ...
# 137                                   True
# 138                                  False
# 139                                   True
# 140                                   True
# 141                                  False
#
# [95 rows x 10 columns]

# %%
from statsmodels.miscmodels.ordinal_model import OrderedModel

# Fit the model
model = OrderedModel(data['Usage'], X, distr='logit')
res = model.fit(method='bfgs')

# Summary of the model
print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 1.364920
#          Iterations: 68
#          Function evaluations: 70
#          Gradient evaluations: 70
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:                  Usage   Log-Likelihood:                -129.67
# Model:                   OrderedModel   AIC:                             287.3
# Method:            Maximum Likelihood   BIC:                             323.1
# Date:                Wed, 11 Jun 2025
# Time:                        14:19:37
# No. Observations:                  95
# Df Residuals:                      81
# Df Model:                          10
# ========================================================================================================================================
#                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# Administrative faculty                                                   0.1983      0.734      0.270      0.787      -1.241       1.638
# Other (Please specify)                                                   0.4692      1.225      0.383      0.702      -1.931       2.869
# Postdoctoral staff or research faculty                                   0.1940      1.095      0.177      0.859      -1.952       2.340
# Professor of practice                                                    0.1504      1.586      0.095      0.924      -2.957       3.258
# Teaching faculty  Assistant professor                                  -0.2355      0.909     -0.259      0.796      -2.018       1.547
# Teaching faculty  Associate professor                                   1.8946      0.849      2.231      0.026       0.230       3.559
# Teaching faculty  Full professor                                       -0.0850      0.725     -0.117      0.907      -1.505       1.335
# Tenure track faculty  Assistant professor                               1.8830      0.921      2.044      0.041       0.078       3.688
# Tenure track faculty  Associate professor                              -0.5688      0.824     -0.690      0.490      -2.184       1.047
# Tenure track faculty  Full professor                                    0.1983      0.734      0.270      0.787      -1.241       1.638
# Never/Have only used for fun or curiosity, never work                   -0.6757      0.570     -1.185      0.236      -1.794       0.442
# Have only used for fun or curiosity, never work/Once or Twice           -1.1839      0.396     -2.990      0.003      -1.960      -0.408
# Once or Twice/Regularly (Once or twice a week)                           0.5161      0.154      3.360      0.001       0.215       0.817
# Regularly (Once or twice a week)/All the time (daily, or more often)     0.4118      0.226      1.819      0.069      -0.032       0.855
# ========================================================================================================================================

# %%
from statsmodels.miscmodels.ordinal_model import OrderedModel

# After fitting your model:
llf = res.llf  # log-likelihood of full model
llnull = res.llnull  # log-likelihood of null model

pseudo_r2 = 1 - (llf / llnull)
print(f"McFadden's Pseudo R²: {pseudo_r2:.3f}")
# Out:
# McFadden's Pseudo R²: 0.053

# %%
# Industry exp

# %%
exp = df_new["How many years of full-time industry experience (i.e. public or private sector work outside of academia but within your current discipline) did you obtain in your field prior to beginning your role at Mines? (Please do not include internships or part-time roles.)"]

# %%
exp.value_counts()
print(exp)
# Out:
# 8                 NaN
# 9         10-20 years
# 10        10-20 years
# 11          1-5 years
# 13         > 20 years
#             ...
# 137               NaN
# 138        > 20 years
# 139        5-10 years
# 140               NaN
# 141    1 year or less
# Name: How many years of full-time industry experience (i.e. public or private sector work outside of academia but within your current discipline) did you obtain in your field prior to beginning your role at Mines? (Please do not include internships or part-time roles.), Length: 95, dtype: object

# %%
data

# %%
from scipy.stats import spearmanr

correlation, p_value = spearmanr(exp, genai)
print(f"Spearman correlation: {correlation:.3f}, p-value: {p_value:.3f}")
# Out:
# Spearman correlation: nan, p-value: nan

# %%
experience_map = {
    'None': 0,
    '1 year or less': 1,
    '1-5 years': 2,
    '5-10 years': 3,
    '10-20 years': 4,
    '> 20 years': 5
}

# %%
genai_map = {
    'Never': 0,
    'Have only used for fun or curiosity, never work': 1,
    'Once or Twice': 2,
    'Regularly (Once or twice a week)': 3,
    'All the time (daily, or more often)': 4
}

# %%
df_new['exp_code'] = df_new[exp.name].map(experience_map)
df_new['genai_code'] = df_new[genai.name].map(genai_map)
# Out:
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_67453/3579508699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['exp_code'] = df_new[exp.name].map(experience_map)
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_67453/3579508699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['genai_code'] = df_new[genai.name].map(genai_map)

# %%
subset = df_new[['exp_code', 'genai_code']].dropna()

# %%
from scipy.stats import spearmanr

corr, pval = spearmanr(subset['exp_code'], subset['genai_code'])
print(f"Spearman correlation: {corr:.3f}, p-value: {pval:.4f}")
# Out:
# Spearman correlation: -0.060, p-value: 0.6480

# %%
chal_opp = df_new["What do you see as the greatest challenges and opportunities for Mines faculty and staff in thoughtfully responding to the new availability of Generative AI models for our students and colleagues? How might GenAI impact learning outcomes and processes?"]

# %%
for i in range(len(chal_opp)):
    if not pd.isna(chal_opp.iloc[i]):
        print(response_id.iloc[i])
        print(role.iloc[i])
        print(chal_opp.iloc[i])
        print("\n\n")
# Out:
# 114801644.0
# Tenure track faculty  Associate professor
# Altering teaching and evaluation strategies to accomodate access
#
#
#
# 114801654.0
# Administrative faculty
# I think having no policies or procedures around using GenAI at Mines would make it challenging and be harmful. I think it can be useful as long as individuals are using it appropriately.
#
#
#
# 114801670.0
# Administrative faculty
# The biggest challenge is restructuring classes around it. I remember when we were taught how to 'talk' to Google, and I assume the process will be similar.
#
#
#
# 114801704.0
# Teaching faculty  Full professor
# Academic dishonestly, particularly in lab settings. Not sure how to deal with so not sure how will impact.
#
#
#
# 114801762.0
# Tenure track faculty  Full professor
# Challenge: Coursework might become meaningless. Opportunity: Rapid access t
#
#
#
# 114801781.0
# Tenure track faculty  Assistant professor
# I think there are responsible ways to use these tools, but I worry about students' ability to discern them. I have seen students use GenAI to help with coding, but in cases I've observed, GenAI (1) doesn't solve the code problems appropriately and (2) risks delaying finding a solution when the students try to use/modify GenAI code instead learning the underlying processes. I'm also concerned about IP issues - artists and creators (including scientific creators) haven't necessarily provided licenses to use their work as it is being used by GenAI. Even if the licenses to our work technically allow the use, they certainly weren't selected with full informed consent of the technology. Not sure this is a Mines issue but one I've been thinking about a lot that I'd like to see included in Mines' response to it.
#
#
#
# 114801956.0
# Administrative faculty
# A new definition of 'learning'-- or is it?
#
#
#
# 114802421.0
# Administrative faculty
# 1. I think it has gotten into people's minds that 'everyone is using AI', which doesn't seem to be the case. The more people who use it, the more problems people find with using it. Overcoming group think to evaluate this technology objectively is a challenge.
#
#
#
# 114802480.0
# Administrative faculty
# I think it could be used as a way to enhance one's own thoughts, processes, and ideas. I am concerned about a potential over-reliance on GenAI and the shortcuts one may take instead of struggling through the process of learning to doing their own thinking and creating.
#
#
#
# 114802630.0
# Postdoctoral staff or research faculty
# Honesty and integrity of work. I hope we don't see a rise in AI plagiarism.
#
#
#
# 114803243.0
# Tenure track faculty  Assistant professor
# Faculty that have structured their classes around frequent short to long writing assignments seem like they will have the most difficulty in responding. Faculty, staff, and ITS should absolutely not fool themselves into thinking there are robust ways to 'detect' the use of LLMs etc. This is a useless pursuit. The greatest opportunities are likely in teaching coding and math topics, and as study tools for students to acquire course content (textbook-style learning).
#
#
#
# 114803641.0
# Teaching faculty  Associate professor
# Learning when these tools are useful and can add value without becoming overly dependent on them and losing insight into a problem
#
#
#
# 114803953.0
# Tenure track faculty  Assistant professor
# The biggest challenge is that the pace of innovation in AI now appears to be much faster than our ability to adapt to it. Any response we formulate presently must be done with a view to long-term applicability, unless we can develop a continuous iterative process that isn't excessively burdensome. My main worry is whether we can provide instruction to our students in a manner that remains relevant by the time they have graduated. But since the development cycle of AI seems to be on the order of months, it is extremely unclear how to do this.
#
#
#
# 114804279.0
# Tenure track faculty  Associate professor
# I am less concerned about students submitting unoriginal work, but more so about the ability for the tool to generate information that is not in fact vetted or true. It seems more important to teach a way to ensure students continue to bring a critical eye to information found on the internet.
#
#
#
# 114804700.0
# Teaching faculty  Assistant professor
# I think for a lot of uses, it's probably very important we teach students how to use GenAI. I could see it getting used pretty extensively, particularly for technical writing and coding. I think if we teach it in a critical fashion, that is, how to use it to write something and then how to deeply critique and edit the work until it's useful, it could greatly improve our students' writing skills. I think this also leads us to challenging areas in terms of assignments. To get that critical thinking built into assignments, we'll have to focus more on iterative practices. I think those are great for learning, but challenging in terms of time to grade and time to deliver content.
#
#
#
# 114807076.0
# Adjunct faculty
# I think that AI will not affect data driven science and engineering fields as much as it will affect social sciences and the humanities.
#
#
#
# 114807503.0
# Administrative faculty
# Encouraging students to leverage new technologies to expand upon their work and understanding is at the foundation of what we do. The biggest challenge (and opportunity) will be in teaching students how to use these tools ethically and without eroding the academic integrity of their work. (I imagine this is much like what happened when the World Wide Web started emerging 30 years ago. EXCITING TIMES!
#
#
#
# 114808670.0
# Teaching faculty  Full professor
# A challenge is teaching students how to critically evaluate outputs from Gen AI rather than blindly believing them.
#
#
#
# 114808702.0
# Tenure track faculty  Assistant professor
# Students seem to want to use their brains less. They have forgotten how to confront a blank page or to proofread and polish a text on their own. I don't mind them using ChatGPT to debug code though but then I don't code so I might be biased.
#
#
#
# 114809188.0
# Tenure track faculty  Full professor
# Integrating its use when appropriate. Disallowing its use when inappropriate.
#
#
#
# 114809380.0
# Teaching faculty  Full professor
# How to teach students to use it in a way that won't cause harm (learn what the limitations are). How to make sure students are still meeting learning outcomes of a course knowing these tools are available to them.
#
#
#
# 114809718.0
# Adjunct faculty
# I see it as a net negative. Students need to learn how to write, research, and dig in the literature. I can see how a properly functioning AI could help with literature search, but the technology is not ready for that yet. I do not think that AI should be allowed to write papers, essays, etc. Neural networks have been in use in the geosciences for many years. Of course, they will continue to improve and become more powerful so they will clearly have a place in working with large data sets.
#
#
#
# 114810278.0
# Adjunct faculty
# The greatest challenge is designing meaningful assessments of understanding that cannot be completed using AI but that also don't take class time to conduct. Related to this is the challenge of holding students accountable for having done the assigned work if there is not enough time in class for all students to participate in a discussion on the materials. The opportunity is that we have to rethink what we are assessing and why and whether the existing methods are actually the best ones for measuring authentic achievement in our subjects. It is likely that in order to have meaningful and authentic assessments, we may have to reduce class size so that instructors can use in-the-moment methods to evaluate student mastery of content and skills, which would present other pedagogical and interpersonal benefits for students and faculty.
#
#
#
# 114810380.0
# Tenure track faculty  Associate professor
# We need to accept the tool exists and will be used (just like Chegg or the Greak historical folders of past works). It levels the playing field for those who need assistance writing or with grammar etc. We need to focus on how to use it responsibly and where its weaknesses are that need to be addressed, not be scared of it.
#
#
#
# 114812124.0
# Adjunct faculty
# Knowing how to guide students' use and how to know when they have used it.
#
#
#
# 114812414.0
# Adjunct faculty
# We need to avoid having students us AI exclusively to complete assignments. Students should be required to state how they used AI on all assignments. AI should be prohibited from writing a document, performing calculations and originating drawings or CAD files. Using AI to generate complete assignments will hamper students from developing many skills.
#
#
#
# 114813545.0
# Tenure track faculty  Associate professor
# I have a lot of concerns about students using this to research and write their papers. I have already had several admit to using it for this purpose, even though I am grading their research and writing skills. I mention in specific assignments how they can use it. For example, they were able to find out what energy controversies existed in their home states, but then they had to do their own research on those controversies and cite their sources. Almost all did a good job, but I suspect the one person who is resisting citing sources is doing so because he used ChatGPT for this findings and therefore cannot cite any sources.
#
#
#
# 114814551.0
# Tenure track faculty  Full professor
# At the moment, I am mainly worried about the negative impact on scientific publishing.
#
#
#
# 114816105.0
# Tenure track faculty  Full professor
# These AI models are very new and likely to be different a year from now. I'm concerned that student's, under time pressure, will try to use them as a substitute for critical thinking and effective communication when preparing lab reports. In my experience critical thinking expressed through effective communication in lab reports is something that many of our students really struggle with. It's not like the introduction of calculators.
#
#
#
# 114819658.0
# Professor of practice
# Provides additional reaources
#
#
#
# 114822072.0
# Teaching faculty  Associate professor
# Greatest challenge will the ability to use these tools to get answers without understanding the process used to arrive at the answer. While that may be a useful/acceptable shortcut in industry it has the potential to produce graduates who don't understand the theory underneath what they are doing. In the same way that it is still useful to know arithmetic even though we use a calculator, we will need to convince our students that they need to learn how to do things before they starting using AI to avoid the monotony of daily tasks. Critical thinking will become even more important as students will need to be able to evaluate the product of the AI, and it will be our job to teach those skills.
#
#
#
# 114824850.0
# Tenure track faculty  Full professor
# If used correctly, I can see where they might be beneficial to students in learning about new subjects, as well as helping them understand the potential misinformation out there with critical thinking skills.
#
#
#
# 114844744.0
# Postdoctoral staff or research faculty
# Huge opportunity for learning topics and asking for help outside of standard office hours as ChatGPT can explain (most) undergrad engineering topics quite well. However some students may become too reliant on it which could be a problem once they find a problem that ChatGPT doesn't know the answer to.
#
#
#
# 114847692.0
# Administrative faculty
# I see the greatest challenge being students not thinking critically for themselves but rather have GenAI do the work for them. Greatest impact would be on my work in preparing for classes, removing some of the busy work that can be done via GenAI.
#
#
#
# 114849738.0
# Administrative faculty
# I see possible abuse of using direct results from GenAI as a person's own work instead of interpreting the results and providing references. The greatest opportunities are the the ability to learn at an accelerated pace and save countless hours on research. GenAI is posed to disrupt the conventional way we perform research on all topics and increase the speed of learning outcomes.
#
#
#
# 114849752.0
# Tenure track faculty  Full professor
# Finding time to (1) learn how to use GenAI tools effectively and (2) integrate them into already intensive courses.
#
#
#
# 114850983.0
# Adjunct faculty
# The need to communicate that genAI could produce fake facts and plagiarized work
#
#
#
# 114851075.0
# Administrative faculty
# Study aid
#
#
#
# 114851226.0
# Teaching faculty  Assistant professor
# GenAI should be explored extensively, and the best way to do that is through our students.
#
#
#
# 114858021.0
# Tenure track faculty  Associate professor
# I'm nervous that students won't learn to think critically/creatively or write well on their own.
#
#
#
# 114867495.0
# Teaching faculty  Full professor
# Regular practice of the basics is critically important. It is difficult to assign this kind of homework in which students can practice their computation and interpretation skills and know that the student is actually the one doing the work/thinking. Assigning points to a students grade for this kind of work becomes problematic, but students appreciate a grade on regular homework.
#
#
#
# 114869948.0
# Tenure track faculty  Assistant professor
# Challenge: keeping up with what is possible through GenAI, designing assignments that are still valuable with the use of GenAI, assisting students with GenAI literacy Opportunities: assisting students with GenAI literacy, assisting students think critically about sources
#
#
#
# 114874217.0
# Administrative faculty
# The biggest opportunity is to have these tools for more quickly distill and understand the vast amount of information available from disparate sources. The biggest challenge is to structure the curriculum and assignments such that these GenAI can be used a tools and not as producing the final answers and solutions themselves.
#
#
#
# 114879598.0
# Teaching faculty  Full professor
# I think we need more guidance on what these programs can do and how our students are using them.
#
#
#
# 114879842.0
# Adjunct faculty
# I teach writing, and one obvious concern is the use of GenAI to write papers. The biggest challenge is the number of students I have and how long it takes to give good feedback on every step of the writing process. I think this relates to GenAI in that if I could read more steps of students' writing process, I'd be more able to catch and address instance of inappropriate GenAI use. That said, I think there is opportunity in discussing with students the ways in which they are better writers than ChaGPT.
#
#
#
# 114890869.0
# Tenure track faculty  Full professor
# Students may heavily lean on it for writing assignments and not develop good writing skills on their own in college.
#
#
#
# 114899737.0
# Tenure track faculty  Associate professor
# I'm concerned about students using GenAI to generate their written responses and lab reports. I have used essay questions and longer writing assignments to better judge critical thinking, rather than multiple choice questions or problems from the book that they can easily find the solutions too. Now I am concerned that they won't spend as much effort with the material to respond thoughtfully. I think if used constructively, these tools can help students get started, or provide a framework with which to adapt code.
#
#
#
# 114938657.0
# Teaching faculty  Full professor
# Largest challenge I think is plagiarism
#
#
#
# 114960372.0
# Teaching faculty  Associate professor
# As a HASS professor, I worry about shortcuts around the critical thinking necessary to write well-crafted, thoughtful, and rigorously researched essays. However, I think that AI provides some opportunity to have socratic engagement with an outside source, and I think that things like proofreading for grammatical errors (not for phrasing and flow) can be ethically outsourced to AI.
#
#
#
# 115065414.0
# Administrative faculty
# The greatest challenge is embracing Generative AI as a tool that will be used throughout their lives. It is incumbent as faculty that we teach them which of these tools can help them, and how to use the appropriately within their field.
#
#
#
# 115112276.0
# Tenure track faculty  Full professor
# Greaters challenges: Most faculty do not yet know how to leverage GenAI in our respective classrooms. Opportunities: to figure out just how to leverage GenAI to promote richer, deeper, more interactive learning. Most of the suggestions I have seen do not rest on a foundation of what we from neuroscience and cognitive psychology about how people learn. I don't think we know the answers to the last question yet.
#
#
#
# 115150124.0
# Teaching faculty  Full professor
# Challenge is students who use tools to do all the work (e.g., writing a paper, conducting research). Opportunity is to teach students to use these tools productively and to understand how tools can help their learning instead of replacing their learning. I would like to understand the tools well enough to think about how to leverage them in student learning. Outcomes could include using tools appropriately.
#
#
#
# 115155132.0
# Teaching faculty  Assistant professor
# I think the biggest challenge is determining when the use of these tools is appropriate and when it is not, and then communicating this with students and other colleagues. There will be times when it helps learning by synthesising literature, etc. and helping quicken some processes.
#
#
#
# 115172053.0
# Teaching faculty  Full professor
# One of the challenges is that I barely know anything about Generative AI, so I am not really sure how my students might be able to use it to (1) cheat or (2) enhance their learning (3) be trained to use it to be more effective in the fields that I teach.
#
#
#
# 115174637.0
# Teaching faculty  Assistant professor
# Challenges: it is so new, and there are going to be a ton of different perspectives on whether it is helpful/harmful, to what degree, and in what ways. Individual professors must experiment with it directly in order to determine how and whether it could be useful, and how/whether it can be harmful or concerning for their classes. Yet finding time to do this is not trivial. Opportunities: as noted earlier it could be a useful tool for some stages of lesson planning or assignment development, and it could be valuable as a tool for students if presented to them in the right way and with appropriate boundaries.
#
#
#
# 115245867.0
# Other (Please specify)
# Some students may copy the information given to them by an AI source without double checking the accuracy. I would not want people who need information in life and death situations (health, medical, engineering structures) to trust AI generated text to be accurate without making sure it is correct.
#
#
#
# 115297907.0
# Adjunct faculty
# I think generative AI makes it difficult to show how students reached certain conclusions or produced their work. Without explainability and citation, it's potentially easy for students to get right answers without actually learning the process by which they reached that outcome.
#
#
#
# 115307970.0
# Teaching faculty  Assistant professor
# It is here to stay and we must learn to regulate it and find best uses. Writing exercises will be most affected at this time
#
#
#
# 115394412.0
# Tenure track faculty  Full professor
# Using AI as a tool in a ethical and legal manner. We can't make it go away and it is going to change the nature of how we do business. Figuring that out, and how to guide our students to it is going to be the biggest challenge in academia.
#
#
#
# 115403305.0
# Tenure track faculty  Full professor
# It is another tool to get information. Many think it is unbiased, and/or always correct, is a major challenge.
#
#
#
# 115405026.0
# Tenure track faculty  Assistant professor
# We need to adjust the assignment such that it is compatible with the existence of GenAI.
#
#
#
# 115425525.0
# Tenure track faculty  Associate professor
# Greatest challenge is parsing student contributions (content, style) from AI contributions to written work submissions. A similar challenge exists for course instruction, but poor instruction might be improved by instructor utilization of GenAI. The unalloyed benefits for deploying GenAI in the learning environment are not yet clear to me.
#
#
#
# 115442779.0
# Administrative faculty
# GenAI is a powerful tool for assisting students in mastery of learning outcomes. Moving the focus away from preventing cheating and to thoughtful integration of GenAI into projects/activities will be the greatest challenge.
#
#
#
# 115446143.0
# Teaching faculty  Assistant professor
# Detecting if students are relying completely on using programs like ChatGPT to complete their work without making any attempt to complete the work themselves. Additionally, I am afraid that students lack the background knowledge to critically think about the output(s) from ChatGPT (i.e. is the information correct?).
#
#
#
# 115446166.0
# nan
# Generation of individual ideas and thoughts is immensely important. While I don't find NLP to be great at generating these things for professional research, I worry about it a little bit for introductory courses where there is lots of data feeding NLP models. If students don't have opportunities at lower-level courses to engage in idea generation, then it's going to be very difficult to make that transition in upper-division courses. However, I don't see this as much different than using (usually not allowed) things like Chegg. I'd much rather a student have to question whether the generated answers are correct than rely on Chegg.
#
#
#
# 115446173.0
# Tenure track faculty  Full professor
# It might create a false sense of knowledge. Current GenAI occasionally returns nonsense, and whether students can differentiate between truth and fiction is unclear.
#
#
#
# 115446216.0
# Teaching faculty  Full professor
# it will negatively impact learning in spaces where critical thinking or creative cognition is being used. it will likely be a wash for those who teach analytical learning outcomes and rote learning but could benefit students in their studies.
#
#
#
# 115446222.0
# Tenure track faculty  Full professor
# Challenge - Assessment of student learning in classes that have not leaned hard on written exams is going to be a challenge. For example lab classes or classes that were driven more by projects. Opportunities - I think that the ability to improve student learning through dialog w/ a chatbot is inspiring; not all students who should come to office hours do.
#
#
#
# 115446661.0
# Teaching faculty  Full professor
# Helping students see where it's helpful and when it's not, and for colleagues, to help them not be really afraid of it: there's a lot of consternation, and it's perceived as cheating. It CAN be cheating, but it can also just be used like I did, to make sure I didn't miss anything major. Students pressed for time will be overly tempted to use it in ways that aren't good, I'm afraid. To combat that temptation I'm designing assignments that are highly individualized, and am considering oral exams.
#
#
#
# 115446706.0
# Adjunct faculty
# Ensuring student are able to balance learning the material while still utilizing tools that will be mandatory in the upcoming decades
#
#
#
# 115446734.0
# Teaching faculty  Associate professor
# Due diligence on our (faculty) end, in making sure students are citing correctly, etc.
#
#
#
# 115447557.0
# Teaching faculty  Full professor
# I have no idea
#
#
#
# 115447600.0
# Postdoctoral staff or research faculty
# It provides an easy shortcut for students to complete assignments without learning the subject material. Most students (especially in undergrad) will find themselves in one crisis situation or another where they dont have time to learn course material, but cant afford to take a hit on their grades. GenAI provided too many loopholes for students to cheat their way through classes and their education. However, it may end up being an extremely useful skill once the students graduate and end up with jobs in industry. Some industries, such as Aerospace and Defense, will inherently have strong restrictions on the use of AI technology in the workspace due to security concerns. However, other less sensitive industries may rely on AI technologies as part of their workflow, and may expect graduating students to have experience using these tools.
#
#
#
# 115447710.0
# Tenure track faculty  Full professor
# I think GenAI makes writing assignments more difficult to rely on for assessment. I'm less worried about assignments like project reports, which I scaffold, are written in groups and are also topically very specific to the project. But more general writing assignments (e.g. a paper on the topic of each student's choosing) seems easier to produce via GenAI. Beyond telling students that they are not allowed to use GenAI to generate these assignments, I would love to understand strategies that help curb or prevent that temptation.
#
#
#
# 115447927.0
# Administrative faculty
# I think the biggest concern is not using open sourced AI.
#
#
#
# 115448224.0
# Tenure track faculty  Associate professor
# challenges would be students using GenAI to write assignments.
#
#
#
# 115449020.0
# Tenure track faculty  Associate professor
# 1. It is yet another field in which we need to keep our knowledge current. 2. It can upend the idea of what our 'value' add is. Certainly skills we used to teach may no longer need to be taught. 3. It can be used poorly, in a way that prevents students from getting practice with valuable skills, and leads to lower quality or inaccurate work. 4. Equity issues - students may not all have access to the tools, leading to yet another way in which the playing field is not level.
#
#
#
# 115449138.0
# Tenure track faculty  Assistant professor
#  Some of our testing and evaluation methods might need to be updated (e..g take-home coding assignments could be easily completed using ChatGPT/Copilot). - Probably we need to evaluate what skills we teach are actually useful. For example, it's possible that proficiency in writing C++ code might, in ten years, be as obsolete as proficiency in preparing punch cards. I think it's too soon to tell though.
#
#
#
# 115449890.0
# Adjunct faculty
# Biggest challenge: student cheating or dependence on these tools as opposed to individual learning. Biggest opportunity: the whole area of AI/ML is still an active research area. There are tremendous research and funding opportunities. For mines, this is particularly true in the institutions research specialties.
#
#
#
# 115451189.0
# Teaching faculty  Associate professor
# Fact-checking becomes the biggest challenge, especially when grading student reports.
#
#
#
# 115451837.0
# Administrative faculty
# Obviously, generative AI offers a shortcut to thinking and writing. Thinking and writing exercises tend to be central to the educational process, so taking shortcuts could be detremental to learning. At the same time, GenAI is obviously a very powerful tool. Learning how to effectively use powerful tools is also central to the education process, so obviously our challenge as educators is to find ways to exploit the educational benefits while minimizing the educational costs of this tool.
#
#
#
# 115452781.0
# Professor of practice
# Guiding students to use gen-AI tools as learning and problem-solving aids. Students could skip learning by getting all work and answers from GenAI. GenAI tools could become personalized learning tutors supplanting educators.
#
#
#
# 115454316.0
# Teaching faculty  Full professor
# I see it as providing opportunities to increase efficiency and to create more interesting assessments for students that will incorporate writing and be more authentic assessments (more like what they would have to do in industry). This assumes it is used well with good guidance given to the students and with SMART assessments using genAI assigned to the students. I think we can and should add LO's connected with genAI to our courses. For example, two learning outcomes I in my syllabus for a new course this semester include: 6. Critically analyze literature and GenAI responses to questions about membrane science and technology by applying knowledge and skills gained in this course. and 8. Communicate critical analyses effectively in writing and verbally, justifying claims made using credible evidence and properly citing sources. Provide useful and actionable feedback to others on their claims about membrane separation technology and respond appropriately to provided feedback on their own work.
#
#
#
# 115455720.0
# Postdoctoral staff or research faculty
# Students are going to use AI language models weather we want them to or not. the challenge will be teaching them when the use will be helpful and when it will be a detriment.
#
#
#
# 115458823.0
# Teaching faculty  Associate professor
# There is a big challenge and opportunity to determine whether GenAI helps or hurts students that are learning programming. It can be challenging because it can easily become a crutch, especially if it gets the coding tasks right for simpler tasks consistently. If it keeps getting things right, it will become a crutch, and students won't need to learn the details of coding effectively. The opportunity is if GenAI can help students learn how to debug code, generate ideas for implementing algorithms, and students can use it as a tool to generate simple code which frees up more time to design systems at a high level. My instinct is to limit access to GenAI at first as students are learning the basics, and then lets them use it for more open-ended design projects where they can integrated systems together using GenAI as long as they cite it and justify why they used it.
#
#
#
# 115473017.0
# Tenure track faculty  Full professor
# Teaching fundamental engineering concepts need knowledgeable professors and subject matter experts who can develop effective and specific objectives and learning outcomes for each course/topic. Using Generative AI models can change the teaching and learning processes; they may have some advantages, but they will surely produce shortcuts for both professors and students. Generative AI models can potentially have negative impacts on teaching and learning if not used responsibly or with awareness of their limitations. Here are some ways in which they can be problematic (generated with the help of OpenAI!; this is really bad because before I think I used it to generate this list, so I am directed to these topics and I am already somewhat biased!): Propagation of Misinformation: Generative AI models can generate text that sounds plausible but is factually incorrect or biased. If used as a primary source of information, they can perpetuate false or misleading content, which can be detrimental to students' understanding of a topic. Lack of Critical Thinking: Relying on AI-generated content can discourage critical thinking skills. Students may become passive consumers of information rather than actively engaging with and evaluating the material. Plagiarism and Academic Integrity: Students might misuse generative AI models to produce essays, assignments, or papers without understanding or contributing to the content. This can lead to issues of plagiarism and undermine the development of research and writing skills. Privacy Concerns: The use of generative AI models in educational settings may raise privacy concerns, as these models can potentially analyze and store data about students' interactions and preferences. Inequality in Access: Not all students have equal access to technology or the internet. Relying on AI-generated content could exacerbate educational inequalities, as it assumes access to these resources. Reduced Personalization: While AI can help automate certain aspects of education, it may lead to a one-size-fits-all approach that doesn't account for the diverse learning needs and styles of students. Teacher Redundancy Concerns: There is a fear in some quarters that advanced AI models could replace human educators, potentially leading to job losses and a lack of human interaction in the learning process.
#
#
#
# 115473179.0
# Teaching faculty  Associate professor
# I am struggling with a bit of cheating right now with ChatGPT, but am coaching the students on how to use it for guidance and to site it as a reference.
#
#
#
# 115474843.0
# Tenure track faculty  Full professor
# Generative AI tools have the opportunity for faculty to rethink how they transfer knowledge to their students. Students can now access so much knowledge through these GenAI tools, but the big challenge will be knowing how to interpret the information, apply critical thinking, and understand what and how it is useful. Learning outcomes will have to move away from just obtaining knowledge, but more about understanding it.
#
#
#
# 115488174.0
# Tenure track faculty  Full professor
# It's going to force more in-person assessment. AI is sometimes, but not always, very proficient at answering relatively complex conceptual questions.
#
#
#
# 115496611.0
# Tenure track faculty  Assistant professor
# Faculty are so busy and overloaded already. Adding in this whole GenAI issue is fascinating and fun and sometimes useful, but it's also just 'one more thing' to have to reason about. I'm only teaching a grad seminar right now, so I'm not worried about GenAI interfering with learning outcomes in this course; these are advanced students who have to complete a project for the course, and GenAI can't really harm their learning much. But when I need to teach younger/undergraduate students with less experience, I will be much more concerned about the students relying on GenAI too much. I believe that if I am highly intentional and instructional about how/when to use GenAI, then it will improve their learning outcomes and skills. But I believe that if instructors ignore its existence and do not provide guidance, it will be more likely to damage learning outcomes. I believe that younger students' learning will hinge quite dramatically on how instructors introduce and frame the use of these models.

# %%
count = 0
for val in chal_opp:
    if not pd.isna(val):
        print(val)
        print("\n")
        count += 1
# Out:
# Altering teaching and evaluation strategies to accomodate access
#
#
# I think having no policies or procedures around using GenAI at Mines would make it challenging and be harmful. I think it can be useful as long as individuals are using it appropriately.
#
#
# The biggest challenge is restructuring classes around it. I remember when we were taught how to 'talk' to Google, and I assume the process will be similar.
#
#
# Academic dishonestly, particularly in lab settings. Not sure how to deal with so not sure how will impact.
#
#
# Challenge: Coursework might become meaningless. Opportunity: Rapid access t
#
#
# I think there are responsible ways to use these tools, but I worry about students' ability to discern them. I have seen students use GenAI to help with coding, but in cases I've observed, GenAI (1) doesn't solve the code problems appropriately and (2) risks delaying finding a solution when the students try to use/modify GenAI code instead learning the underlying processes. I'm also concerned about IP issues - artists and creators (including scientific creators) haven't necessarily provided licenses to use their work as it is being used by GenAI. Even if the licenses to our work technically allow the use, they certainly weren't selected with full informed consent of the technology. Not sure this is a Mines issue but one I've been thinking about a lot that I'd like to see included in Mines' response to it.
#
#
# A new definition of 'learning'-- or is it?
#
#
# 1. I think it has gotten into people's minds that 'everyone is using AI', which doesn't seem to be the case. The more people who use it, the more problems people find with using it. Overcoming group think to evaluate this technology objectively is a challenge.
#
#
# I think it could be used as a way to enhance one's own thoughts, processes, and ideas. I am concerned about a potential over-reliance on GenAI and the shortcuts one may take instead of struggling through the process of learning to doing their own thinking and creating.
#
#
# Honesty and integrity of work. I hope we don't see a rise in AI plagiarism.
#
#
# Faculty that have structured their classes around frequent short to long writing assignments seem like they will have the most difficulty in responding. Faculty, staff, and ITS should absolutely not fool themselves into thinking there are robust ways to 'detect' the use of LLMs etc. This is a useless pursuit. The greatest opportunities are likely in teaching coding and math topics, and as study tools for students to acquire course content (textbook-style learning).
#
#
# Learning when these tools are useful and can add value without becoming overly dependent on them and losing insight into a problem
#
#
# The biggest challenge is that the pace of innovation in AI now appears to be much faster than our ability to adapt to it. Any response we formulate presently must be done with a view to long-term applicability, unless we can develop a continuous iterative process that isn't excessively burdensome. My main worry is whether we can provide instruction to our students in a manner that remains relevant by the time they have graduated. But since the development cycle of AI seems to be on the order of months, it is extremely unclear how to do this.
#
#
# I am less concerned about students submitting unoriginal work, but more so about the ability for the tool to generate information that is not in fact vetted or true. It seems more important to teach a way to ensure students continue to bring a critical eye to information found on the internet.
#
#
# I think for a lot of uses, it's probably very important we teach students how to use GenAI. I could see it getting used pretty extensively, particularly for technical writing and coding. I think if we teach it in a critical fashion, that is, how to use it to write something and then how to deeply critique and edit the work until it's useful, it could greatly improve our students' writing skills. I think this also leads us to challenging areas in terms of assignments. To get that critical thinking built into assignments, we'll have to focus more on iterative practices. I think those are great for learning, but challenging in terms of time to grade and time to deliver content.
#
#
# I think that AI will not affect data driven science and engineering fields as much as it will affect social sciences and the humanities.
#
#
# Encouraging students to leverage new technologies to expand upon their work and understanding is at the foundation of what we do. The biggest challenge (and opportunity) will be in teaching students how to use these tools ethically and without eroding the academic integrity of their work. (I imagine this is much like what happened when the World Wide Web started emerging 30 years ago. EXCITING TIMES!
#
#
# A challenge is teaching students how to critically evaluate outputs from Gen AI rather than blindly believing them.
#
#
# Students seem to want to use their brains less. They have forgotten how to confront a blank page or to proofread and polish a text on their own. I don't mind them using ChatGPT to debug code though but then I don't code so I might be biased.
#
#
# Integrating its use when appropriate. Disallowing its use when inappropriate.
#
#
# How to teach students to use it in a way that won't cause harm (learn what the limitations are). How to make sure students are still meeting learning outcomes of a course knowing these tools are available to them.
#
#
# I see it as a net negative. Students need to learn how to write, research, and dig in the literature. I can see how a properly functioning AI could help with literature search, but the technology is not ready for that yet. I do not think that AI should be allowed to write papers, essays, etc. Neural networks have been in use in the geosciences for many years. Of course, they will continue to improve and become more powerful so they will clearly have a place in working with large data sets.
#
#
# The greatest challenge is designing meaningful assessments of understanding that cannot be completed using AI but that also don't take class time to conduct. Related to this is the challenge of holding students accountable for having done the assigned work if there is not enough time in class for all students to participate in a discussion on the materials. The opportunity is that we have to rethink what we are assessing and why and whether the existing methods are actually the best ones for measuring authentic achievement in our subjects. It is likely that in order to have meaningful and authentic assessments, we may have to reduce class size so that instructors can use in-the-moment methods to evaluate student mastery of content and skills, which would present other pedagogical and interpersonal benefits for students and faculty.
#
#
# We need to accept the tool exists and will be used (just like Chegg or the Greak historical folders of past works). It levels the playing field for those who need assistance writing or with grammar etc. We need to focus on how to use it responsibly and where its weaknesses are that need to be addressed, not be scared of it.
#
#
# Knowing how to guide students' use and how to know when they have used it.
#
#
# We need to avoid having students us AI exclusively to complete assignments. Students should be required to state how they used AI on all assignments. AI should be prohibited from writing a document, performing calculations and originating drawings or CAD files. Using AI to generate complete assignments will hamper students from developing many skills.
#
#
# I have a lot of concerns about students using this to research and write their papers. I have already had several admit to using it for this purpose, even though I am grading their research and writing skills. I mention in specific assignments how they can use it. For example, they were able to find out what energy controversies existed in their home states, but then they had to do their own research on those controversies and cite their sources. Almost all did a good job, but I suspect the one person who is resisting citing sources is doing so because he used ChatGPT for this findings and therefore cannot cite any sources.
#
#
# At the moment, I am mainly worried about the negative impact on scientific publishing.
#
#
# These AI models are very new and likely to be different a year from now. I'm concerned that student's, under time pressure, will try to use them as a substitute for critical thinking and effective communication when preparing lab reports. In my experience critical thinking expressed through effective communication in lab reports is something that many of our students really struggle with. It's not like the introduction of calculators.
#
#
# Provides additional reaources
#
#
# Greatest challenge will the ability to use these tools to get answers without understanding the process used to arrive at the answer. While that may be a useful/acceptable shortcut in industry it has the potential to produce graduates who don't understand the theory underneath what they are doing. In the same way that it is still useful to know arithmetic even though we use a calculator, we will need to convince our students that they need to learn how to do things before they starting using AI to avoid the monotony of daily tasks. Critical thinking will become even more important as students will need to be able to evaluate the product of the AI, and it will be our job to teach those skills.
#
#
# If used correctly, I can see where they might be beneficial to students in learning about new subjects, as well as helping them understand the potential misinformation out there with critical thinking skills.
#
#
# Huge opportunity for learning topics and asking for help outside of standard office hours as ChatGPT can explain (most) undergrad engineering topics quite well. However some students may become too reliant on it which could be a problem once they find a problem that ChatGPT doesn't know the answer to.
#
#
# I see the greatest challenge being students not thinking critically for themselves but rather have GenAI do the work for them. Greatest impact would be on my work in preparing for classes, removing some of the busy work that can be done via GenAI.
#
#
# I see possible abuse of using direct results from GenAI as a person's own work instead of interpreting the results and providing references. The greatest opportunities are the the ability to learn at an accelerated pace and save countless hours on research. GenAI is posed to disrupt the conventional way we perform research on all topics and increase the speed of learning outcomes.
#
#
# Finding time to (1) learn how to use GenAI tools effectively and (2) integrate them into already intensive courses.
#
#
# The need to communicate that genAI could produce fake facts and plagiarized work
#
#
# Study aid
#
#
# GenAI should be explored extensively, and the best way to do that is through our students.
#
#
# I'm nervous that students won't learn to think critically/creatively or write well on their own.
#
#
# Regular practice of the basics is critically important. It is difficult to assign this kind of homework in which students can practice their computation and interpretation skills and know that the student is actually the one doing the work/thinking. Assigning points to a students grade for this kind of work becomes problematic, but students appreciate a grade on regular homework.
#
#
# Challenge: keeping up with what is possible through GenAI, designing assignments that are still valuable with the use of GenAI, assisting students with GenAI literacy Opportunities: assisting students with GenAI literacy, assisting students think critically about sources
#
#
# The biggest opportunity is to have these tools for more quickly distill and understand the vast amount of information available from disparate sources. The biggest challenge is to structure the curriculum and assignments such that these GenAI can be used a tools and not as producing the final answers and solutions themselves.
#
#
# I think we need more guidance on what these programs can do and how our students are using them.
#
#
# I teach writing, and one obvious concern is the use of GenAI to write papers. The biggest challenge is the number of students I have and how long it takes to give good feedback on every step of the writing process. I think this relates to GenAI in that if I could read more steps of students' writing process, I'd be more able to catch and address instance of inappropriate GenAI use. That said, I think there is opportunity in discussing with students the ways in which they are better writers than ChaGPT.
#
#
# Students may heavily lean on it for writing assignments and not develop good writing skills on their own in college.
#
#
# I'm concerned about students using GenAI to generate their written responses and lab reports. I have used essay questions and longer writing assignments to better judge critical thinking, rather than multiple choice questions or problems from the book that they can easily find the solutions too. Now I am concerned that they won't spend as much effort with the material to respond thoughtfully. I think if used constructively, these tools can help students get started, or provide a framework with which to adapt code.
#
#
# Largest challenge I think is plagiarism
#
#
# As a HASS professor, I worry about shortcuts around the critical thinking necessary to write well-crafted, thoughtful, and rigorously researched essays. However, I think that AI provides some opportunity to have socratic engagement with an outside source, and I think that things like proofreading for grammatical errors (not for phrasing and flow) can be ethically outsourced to AI.
#
#
# The greatest challenge is embracing Generative AI as a tool that will be used throughout their lives. It is incumbent as faculty that we teach them which of these tools can help them, and how to use the appropriately within their field.
#
#
# Greaters challenges: Most faculty do not yet know how to leverage GenAI in our respective classrooms. Opportunities: to figure out just how to leverage GenAI to promote richer, deeper, more interactive learning. Most of the suggestions I have seen do not rest on a foundation of what we from neuroscience and cognitive psychology about how people learn. I don't think we know the answers to the last question yet.
#
#
# Challenge is students who use tools to do all the work (e.g., writing a paper, conducting research). Opportunity is to teach students to use these tools productively and to understand how tools can help their learning instead of replacing their learning. I would like to understand the tools well enough to think about how to leverage them in student learning. Outcomes could include using tools appropriately.
#
#
# I think the biggest challenge is determining when the use of these tools is appropriate and when it is not, and then communicating this with students and other colleagues. There will be times when it helps learning by synthesising literature, etc. and helping quicken some processes.
#
#
# One of the challenges is that I barely know anything about Generative AI, so I am not really sure how my students might be able to use it to (1) cheat or (2) enhance their learning (3) be trained to use it to be more effective in the fields that I teach.
#
#
# Challenges: it is so new, and there are going to be a ton of different perspectives on whether it is helpful/harmful, to what degree, and in what ways. Individual professors must experiment with it directly in order to determine how and whether it could be useful, and how/whether it can be harmful or concerning for their classes. Yet finding time to do this is not trivial. Opportunities: as noted earlier it could be a useful tool for some stages of lesson planning or assignment development, and it could be valuable as a tool for students if presented to them in the right way and with appropriate boundaries.
#
#
# Some students may copy the information given to them by an AI source without double checking the accuracy. I would not want people who need information in life and death situations (health, medical, engineering structures) to trust AI generated text to be accurate without making sure it is correct.
#
#
# I think generative AI makes it difficult to show how students reached certain conclusions or produced their work. Without explainability and citation, it's potentially easy for students to get right answers without actually learning the process by which they reached that outcome.
#
#
# It is here to stay and we must learn to regulate it and find best uses. Writing exercises will be most affected at this time
#
#
# Using AI as a tool in a ethical and legal manner. We can't make it go away and it is going to change the nature of how we do business. Figuring that out, and how to guide our students to it is going to be the biggest challenge in academia.
#
#
# It is another tool to get information. Many think it is unbiased, and/or always correct, is a major challenge.
#
#
# We need to adjust the assignment such that it is compatible with the existence of GenAI.
#
#
# Greatest challenge is parsing student contributions (content, style) from AI contributions to written work submissions. A similar challenge exists for course instruction, but poor instruction might be improved by instructor utilization of GenAI. The unalloyed benefits for deploying GenAI in the learning environment are not yet clear to me.
#
#
# GenAI is a powerful tool for assisting students in mastery of learning outcomes. Moving the focus away from preventing cheating and to thoughtful integration of GenAI into projects/activities will be the greatest challenge.
#
#
# Detecting if students are relying completely on using programs like ChatGPT to complete their work without making any attempt to complete the work themselves. Additionally, I am afraid that students lack the background knowledge to critically think about the output(s) from ChatGPT (i.e. is the information correct?).
#
#
# Generation of individual ideas and thoughts is immensely important. While I don't find NLP to be great at generating these things for professional research, I worry about it a little bit for introductory courses where there is lots of data feeding NLP models. If students don't have opportunities at lower-level courses to engage in idea generation, then it's going to be very difficult to make that transition in upper-division courses. However, I don't see this as much different than using (usually not allowed) things like Chegg. I'd much rather a student have to question whether the generated answers are correct than rely on Chegg.
#
#
# It might create a false sense of knowledge. Current GenAI occasionally returns nonsense, and whether students can differentiate between truth and fiction is unclear.
#
#
# it will negatively impact learning in spaces where critical thinking or creative cognition is being used. it will likely be a wash for those who teach analytical learning outcomes and rote learning but could benefit students in their studies.
#
#
# Challenge - Assessment of student learning in classes that have not leaned hard on written exams is going to be a challenge. For example lab classes or classes that were driven more by projects. Opportunities - I think that the ability to improve student learning through dialog w/ a chatbot is inspiring; not all students who should come to office hours do.
#
#
# Helping students see where it's helpful and when it's not, and for colleagues, to help them not be really afraid of it: there's a lot of consternation, and it's perceived as cheating. It CAN be cheating, but it can also just be used like I did, to make sure I didn't miss anything major. Students pressed for time will be overly tempted to use it in ways that aren't good, I'm afraid. To combat that temptation I'm designing assignments that are highly individualized, and am considering oral exams.
#
#
# Ensuring student are able to balance learning the material while still utilizing tools that will be mandatory in the upcoming decades
#
#
# Due diligence on our (faculty) end, in making sure students are citing correctly, etc.
#
#
# I have no idea
#
#
# It provides an easy shortcut for students to complete assignments without learning the subject material. Most students (especially in undergrad) will find themselves in one crisis situation or another where they dont have time to learn course material, but cant afford to take a hit on their grades. GenAI provided too many loopholes for students to cheat their way through classes and their education. However, it may end up being an extremely useful skill once the students graduate and end up with jobs in industry. Some industries, such as Aerospace and Defense, will inherently have strong restrictions on the use of AI technology in the workspace due to security concerns. However, other less sensitive industries may rely on AI technologies as part of their workflow, and may expect graduating students to have experience using these tools.
#
#
# I think GenAI makes writing assignments more difficult to rely on for assessment. I'm less worried about assignments like project reports, which I scaffold, are written in groups and are also topically very specific to the project. But more general writing assignments (e.g. a paper on the topic of each student's choosing) seems easier to produce via GenAI. Beyond telling students that they are not allowed to use GenAI to generate these assignments, I would love to understand strategies that help curb or prevent that temptation.
#
#
# I think the biggest concern is not using open sourced AI.
#
#
# challenges would be students using GenAI to write assignments.
#
#
# 1. It is yet another field in which we need to keep our knowledge current. 2. It can upend the idea of what our 'value' add is. Certainly skills we used to teach may no longer need to be taught. 3. It can be used poorly, in a way that prevents students from getting practice with valuable skills, and leads to lower quality or inaccurate work. 4. Equity issues - students may not all have access to the tools, leading to yet another way in which the playing field is not level.
#
#
#  Some of our testing and evaluation methods might need to be updated (e..g take-home coding assignments could be easily completed using ChatGPT/Copilot). - Probably we need to evaluate what skills we teach are actually useful. For example, it's possible that proficiency in writing C++ code might, in ten years, be as obsolete as proficiency in preparing punch cards. I think it's too soon to tell though.
#
#
# Biggest challenge: student cheating or dependence on these tools as opposed to individual learning. Biggest opportunity: the whole area of AI/ML is still an active research area. There are tremendous research and funding opportunities. For mines, this is particularly true in the institutions research specialties.
#
#
# Fact-checking becomes the biggest challenge, especially when grading student reports.
#
#
# Obviously, generative AI offers a shortcut to thinking and writing. Thinking and writing exercises tend to be central to the educational process, so taking shortcuts could be detremental to learning. At the same time, GenAI is obviously a very powerful tool. Learning how to effectively use powerful tools is also central to the education process, so obviously our challenge as educators is to find ways to exploit the educational benefits while minimizing the educational costs of this tool.
#
#
# Guiding students to use gen-AI tools as learning and problem-solving aids. Students could skip learning by getting all work and answers from GenAI. GenAI tools could become personalized learning tutors supplanting educators.
#
#
# I see it as providing opportunities to increase efficiency and to create more interesting assessments for students that will incorporate writing and be more authentic assessments (more like what they would have to do in industry). This assumes it is used well with good guidance given to the students and with SMART assessments using genAI assigned to the students. I think we can and should add LO's connected with genAI to our courses. For example, two learning outcomes I in my syllabus for a new course this semester include: 6. Critically analyze literature and GenAI responses to questions about membrane science and technology by applying knowledge and skills gained in this course. and 8. Communicate critical analyses effectively in writing and verbally, justifying claims made using credible evidence and properly citing sources. Provide useful and actionable feedback to others on their claims about membrane separation technology and respond appropriately to provided feedback on their own work.
#
#
# Students are going to use AI language models weather we want them to or not. the challenge will be teaching them when the use will be helpful and when it will be a detriment.
#
#
# There is a big challenge and opportunity to determine whether GenAI helps or hurts students that are learning programming. It can be challenging because it can easily become a crutch, especially if it gets the coding tasks right for simpler tasks consistently. If it keeps getting things right, it will become a crutch, and students won't need to learn the details of coding effectively. The opportunity is if GenAI can help students learn how to debug code, generate ideas for implementing algorithms, and students can use it as a tool to generate simple code which frees up more time to design systems at a high level. My instinct is to limit access to GenAI at first as students are learning the basics, and then lets them use it for more open-ended design projects where they can integrated systems together using GenAI as long as they cite it and justify why they used it.
#
#
# Teaching fundamental engineering concepts need knowledgeable professors and subject matter experts who can develop effective and specific objectives and learning outcomes for each course/topic. Using Generative AI models can change the teaching and learning processes; they may have some advantages, but they will surely produce shortcuts for both professors and students. Generative AI models can potentially have negative impacts on teaching and learning if not used responsibly or with awareness of their limitations. Here are some ways in which they can be problematic (generated with the help of OpenAI!; this is really bad because before I think I used it to generate this list, so I am directed to these topics and I am already somewhat biased!): Propagation of Misinformation: Generative AI models can generate text that sounds plausible but is factually incorrect or biased. If used as a primary source of information, they can perpetuate false or misleading content, which can be detrimental to students' understanding of a topic. Lack of Critical Thinking: Relying on AI-generated content can discourage critical thinking skills. Students may become passive consumers of information rather than actively engaging with and evaluating the material. Plagiarism and Academic Integrity: Students might misuse generative AI models to produce essays, assignments, or papers without understanding or contributing to the content. This can lead to issues of plagiarism and undermine the development of research and writing skills. Privacy Concerns: The use of generative AI models in educational settings may raise privacy concerns, as these models can potentially analyze and store data about students' interactions and preferences. Inequality in Access: Not all students have equal access to technology or the internet. Relying on AI-generated content could exacerbate educational inequalities, as it assumes access to these resources. Reduced Personalization: While AI can help automate certain aspects of education, it may lead to a one-size-fits-all approach that doesn't account for the diverse learning needs and styles of students. Teacher Redundancy Concerns: There is a fear in some quarters that advanced AI models could replace human educators, potentially leading to job losses and a lack of human interaction in the learning process.
#
#
# I am struggling with a bit of cheating right now with ChatGPT, but am coaching the students on how to use it for guidance and to site it as a reference.
#
#
# Generative AI tools have the opportunity for faculty to rethink how they transfer knowledge to their students. Students can now access so much knowledge through these GenAI tools, but the big challenge will be knowing how to interpret the information, apply critical thinking, and understand what and how it is useful. Learning outcomes will have to move away from just obtaining knowledge, but more about understanding it.
#
#
# It's going to force more in-person assessment. AI is sometimes, but not always, very proficient at answering relatively complex conceptual questions.
#
#
# Faculty are so busy and overloaded already. Adding in this whole GenAI issue is fascinating and fun and sometimes useful, but it's also just 'one more thing' to have to reason about. I'm only teaching a grad seminar right now, so I'm not worried about GenAI interfering with learning outcomes in this course; these are advanced students who have to complete a project for the course, and GenAI can't really harm their learning much. But when I need to teach younger/undergraduate students with less experience, I will be much more concerned about the students relying on GenAI too much. I believe that if I am highly intentional and instructional about how/when to use GenAI, then it will improve their learning outcomes and skills. But I believe that if instructors ignore its existence and do not provide guidance, it will be more likely to damage learning outcomes. I believe that younger students' learning will hinge quite dramatically on how instructors introduce and frame the use of these models.

# %%
print(count)
# Out:
# 90

# %%
pre = df_new["How prepared do you feel to integrate pedagogical uses of GenAI in your Fall23 courses?(1) Extremely unprepared to (10) Extremely prepared Row 1"]

# %%
pre.value_counts()
# Out:
# How prepared do you feel to integrate pedagogical uses of GenAI in your Fall23 courses?(1) Extremely unprepared to (10) Extremely prepared Row 1
# 2.0     18
# 1.0     17
# 5.0     15
# 3.0     15
# 4.0      9
# 7.0      6
# 8.0      5
# 6.0      5
# 9.0      3
# 10.0     1
# Name: count, dtype: int64

# %%
kde_plot(pre, 1, 10, 'A', 'X', 'Y')
# Out:
# Peak values are at: [2.08542714]

# %%
pre_dic = pre.value_counts().sort_values(ascending=False)

# %%
pre_dic
# Out:
# How prepared do you feel to integrate pedagogical uses of GenAI in your Fall23 courses?(1) Extremely unprepared to (10) Extremely prepared Row 1
# 2.0     18
# 1.0     17
# 5.0     15
# 3.0     15
# 4.0      9
# 7.0      6
# 8.0      5
# 6.0      5
# 9.0      3
# 10.0     1
# Name: count, dtype: int64

# %%
def draw_barplot(data, xlabel, ylabel):
    plt.figure(figsize=(8, 6))
    ax = sns.barplot(x=data.index, y=data.values, palette="Blues_d")
    
    # Annotate bars with values
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.0f}',  
                    (p.get_x() + p.get_width() / 2, p.get_height()),  # Position
                    ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')
   
    # Rotate X-axis labels
    plt.xticks(rotation=45, ha='right') 

    # Adding titles and labels
    plt.xlabel(xlabel, fontsize=12)
    plt.ylabel(ylabel, fontsize=12)
    plt.savefig('/Users/jesanahammed/Desktop/faculty_preparedness.png', dpi=300)
    
    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
draw_barplot(pre_dic, "", "")
# Out:
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_67453/1680264997.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=data.index, y=data.values, palette="Blues_d")

# %%
print(pre.mean())
# Out:
# 3.8085106382978724

# %%
print(pre.median())
# Out:
# 3.0

# %%
from scipy.stats import wilcoxon

w_stat, p_val_w = wilcoxon([r - 5.5 for r in pre])  # Testing if responses differ from 5

print(f"Wilcoxon Test Statistic: {w_stat}, P-Value: {p_val_w:.10e}")
# Out:
# Wilcoxon Test Statistic: nan, P-Value: nan

# %%
pre
# Out:
# 8       2.0
# 9       1.0
# 10     10.0
# 11      1.0
# 13      1.0
#        ...
# 137     NaN
# 138     4.0
# 139     3.0
# 140     6.0
# 141     6.0
# Name: How prepared do you feel to integrate pedagogical uses of GenAI in your Fall23 courses?(1) Extremely unprepared to (10) Extremely prepared Row 1, Length: 95, dtype: float64

# %%
ben_sci_2024 = df_24['Your scientific field or major']

# %%
ben_sci_2024_cleaned = ben_sci_2024.dropna()

# %%
ben_sci_2023 = df_2023_cleaned['Please rate your current feelings on whether generative AI will be beneficial or harmful for your field.']

# %%
mapping = {
    '7': 7,
    '9': 9,
    '6': 6,
    '8': 8,
    '5': 5,
    '10 (Extremely beneficial)': 10,
    '4': 4,
    '3': 3,
    '1 (Extremely harmful)': 1,
    '2': 2
}

# Convert the values to numeric using the mapping
ben_sci_2023_numeric = ben_sci_2023.replace(mapping).astype(int)

# Check the result
print(ben_sci_2023_numeric.unique())
# Out:
# [ 7  9  6  8  5 10  4  3  1  2]

# %%
ben_sci_faculty = df_new["Please rate your current feelings on whether generative AI will be beneficial or harmful to your field. (1) Extremely harmful to (10) Extremely beneficial Row 1"]

# %%
ben_sci_faculty.isna().sum()
# Out:
# 0

# %%
ben_sci_faculty_cleaned = ben_sci_faculty.dropna()
ben_sci_faculty_cleaned.isna().sum()
# Out:
# 0

# %%
print(f'Median 2023: {ben_sci_2023_numeric.median()}')
print(f'Median 2024: {ben_sci_2024_cleaned.median()}')
print(f'Median Faculty: {ben_sci_faculty_cleaned.median()}')
# Out:
# Median 2023: 7.0
# Median 2024: 6.0
# Median Faculty: 6.0

# %%
from scipy.stats import kruskal
kruskal(ben_sci_2023_numeric, ben_sci_2024_cleaned, ben_sci_faculty_cleaned)
# Out:
# KruskalResult(statistic=12.319133278302852, pvalue=0.0021131688379739076)

# %%
import scikit_posthocs as sp
sp.posthoc_dunn([ben_sci_2023_numeric, ben_sci_2024_cleaned, ben_sci_faculty_cleaned], p_adjust='bonferroni')
# Out:
#           1         2    3
# 1  1.000000  0.001358  1.0
# 2  0.001358  1.000000  1.0
# 3  1.000000  1.000000  1.0

# %%
kde_plot(ben_sci_faculty_cleaned, 1, 10, 'A', 'X', 'Y')
# Out:
# Peak values are at: [5.61306533]

# %%
ben_harm = ben_harm_clean.value_counts().sort_values(ascending=False)
draw_barplot(ben_harm, "", "")
# Out:
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_67453/1680264997.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=data.index, y=data.values, palette="Blues_d")

# %%
genai.value_counts() # Faculty usages
# Out:
# Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts
# Once or Twice                                      34
# Never                                              28
# Regularly (Once or twice a week)                   18
# All the time (daily, or more often)                 9
# Have only used for fun or curiosity, never work     6
# Name: count, dtype: int64

# %%
ams = df_new["What do you consider to be your primary department?"]

# %%
ams.value_counts()
# Out:
# What do you consider to be your primary department?
# 0                                     89
# Applied Mathematics and Statistics     6
# Name: count, dtype: int64

# %%
cbe = df_new["Unnamed: 69"]
cbe.value_counts()
# Out:
# Unnamed: 69
# 0                                      92
# Chemical and Biological Engineering     3
# Name: count, dtype: int64

# %%
che = df_new["Unnamed: 70"]
che.value_counts()
# Out:
# Unnamed: 70
# 0            93
# Chemistry     2
# Name: count, dtype: int64

# %%
ce = df_new["Unnamed: 71"]
ce.value_counts()
# Out:
# Unnamed: 71
# 0                                      91
# Civil and Environmental Engineering     4
# Name: count, dtype: int64

# %%
cs = df_new["Unnamed: 72"]
cs.value_counts()
# Out:
# Unnamed: 72
# 0                   86
# Computer Science     9
# Name: count, dtype: int64

# %%
eb = df_new["Unnamed: 73"]
eb.value_counts()
# Out:
# Unnamed: 73
# 0                         92
# Economics and Business     3
# Name: count, dtype: int64

# %%
ee = df_new["Unnamed: 74"]
ee.value_counts()
# Out:
# Unnamed: 74
# 0    95
# Name: count, dtype: int64

# %%
eds = df_new["Unnamed: 75"]
eds.value_counts()
# Out:
# Unnamed: 75
# 0                                 86
# Engineering Design and Society     9
# Name: count, dtype: int64

# %%
gge = df_new["Unnamed: 76"]
gge.value_counts()
# Out:
# Unnamed: 76
# 0                                     92
# Geology and Geological Engineering     3
# Name: count, dtype: int64

# %%
geop = df_new["Unnamed: 77"]
geop.value_counts()
# Out:
# Unnamed: 77
# 0             92
# Geophysics     3
# Name: count, dtype: int64

# %%
has = df_new["Unnamed: 78"]
has.value_counts()
# Out:
# Unnamed: 78
# 0                                        88
# Humanities, Arts, and Social Sciences     7
# Name: count, dtype: int64

# %%
me = df_new["Unnamed: 79"]
me.value_counts()
# Out:
# Unnamed: 79
# 0                         87
# Mechanical Engineering     8
# Name: count, dtype: int64

# %%
mme = df_new["Unnamed: 80"]
mme.value_counts()
# Out:
# Unnamed: 80
# 0                                          92
# Metallurgical and Materials Engineering     3
# Name: count, dtype: int64

# %%
mee = df_new["Unnamed: 81"]
mee.value_counts()
# Out:
# Unnamed: 81
# 0    95
# Name: count, dtype: int64

# %%
mme.isna().sum()
# Out:
# 0

# %%
pe = df_new["Unnamed: 82"]
pe.value_counts()
# Out:
# Unnamed: 82
# 0                        94
# Petroleum Engineering     1
# Name: count, dtype: int64

# %%
def num_of_res(att):
    count = 0
    for val in att:
        if not pd.isna(val) and val != '0' and val != 0:
            count += 1
            #print(val)
    return count

# %%
n = num_of_res(mee)
print(n)
# Out:
# 0

# %%
phy = df_new["Unnamed: 83"]
phy.value_counts()
# Out:
# Unnamed: 83
# 0          89
# Physics     6
# Name: count, dtype: int64

# %%
au = df_new["Unnamed: 84"]
au.value_counts()
# Out:
# Unnamed: 84
# 0    95
# Name: count, dtype: int64

# %%
af = df_new["Unnamed: 85"]
af.value_counts()
# Out:
# Unnamed: 85
# 0                               82
# N/A - Administrative Faculty    13
# Name: count, dtype: int64

# %%
other = df_new["Unnamed: 86"]
other.value_counts()
# Out:
# Unnamed: 86
# 0                                                             85
# Library                                                        2
# IT: Cyberinfrastructure & Advanced Research Computing team     1
# Payne Institute                                                1
# Research and Technology Transfer                               1
# University Honors and Scholars Programs                        1
# Nuclear Science and Engineering                                1
# Other                                                          1
# Mining Engineering--thanks for leaving us out                  1
# RTT                                                            1
# Name: count, dtype: int64

# %%
dept_df = pd.DataFrame({
    'ams': ams,
    'cbe': cbe,
    'che': che,
    'ce': ce,
    'cs': cs,
    'eb': eb,
    'ee': ee,
    'eds': eds,
    'gge': gge,
    'geop': geop,
    'has': has,
    'me': me,
    'mme': mme,
    'mee': mee,
    'pe': pe,
    'phy': phy,
    'au': au,
    'af': af,
    'other': other
})

# %%
print(dept_df.columns)
# Out:
# Index(['ams', 'cbe', 'che', 'ce', 'cs', 'eb', 'ee', 'eds', 'gge', 'geop',
#        'has', 'me', 'mme', 'mee', 'pe', 'phy', 'au', 'af', 'other'],
#       dtype='object')

# %%
num_all_zero_rows = (dept_df == '0').all(axis=1).sum()
print(num_all_zero_rows)
# Out:
# 5

# %%
total = 0
for col in dept_df.columns:
    count = 0
    print(col)
    for val in dept_df[col]:
        if val != '0':
            print(val)
            total += 1
            count += 1
    print(count)
# Out:
# ams
# Applied Mathematics and Statistics
# Applied Mathematics and Statistics
# Applied Mathematics and Statistics
# Applied Mathematics and Statistics
# Applied Mathematics and Statistics
# Applied Mathematics and Statistics
# 6
# cbe
# Chemical and Biological Engineering
# Chemical and Biological Engineering
# Chemical and Biological Engineering
# 3
# che
# Chemistry
# Chemistry
# 2
# ce
# Civil and Environmental Engineering
# Civil and Environmental Engineering
# Civil and Environmental Engineering
# Civil and Environmental Engineering
# 4
# cs
# Computer Science
# Computer Science
# Computer Science
# Computer Science
# Computer Science
# Computer Science
# Computer Science
# Computer Science
# Computer Science
# 9
# eb
# Economics and Business
# Economics and Business
# Economics and Business
# 3
# ee
# 0
# eds
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# Engineering Design and Society
# 9
# gge
# Geology and Geological Engineering
# Geology and Geological Engineering
# Geology and Geological Engineering
# 3
# geop
# Geophysics
# Geophysics
# Geophysics
# 3
# has
# Humanities, Arts, and Social Sciences
# Humanities, Arts, and Social Sciences
# Humanities, Arts, and Social Sciences
# Humanities, Arts, and Social Sciences
# Humanities, Arts, and Social Sciences
# Humanities, Arts, and Social Sciences
# Humanities, Arts, and Social Sciences
# 7
# me
# Mechanical Engineering
# Mechanical Engineering
# Mechanical Engineering
# Mechanical Engineering
# Mechanical Engineering
# Mechanical Engineering
# Mechanical Engineering
# Mechanical Engineering
# 8
# mme
# Metallurgical and Materials Engineering
# Metallurgical and Materials Engineering
# Metallurgical and Materials Engineering
# 3
# mee
# 0
# pe
# Petroleum Engineering
# 1
# phy
# Physics
# Physics
# Physics
# Physics
# Physics
# Physics
# 6
# au
# 0
# af
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# N/A - Administrative Faculty
# 13
# other
# IT: Cyberinfrastructure & Advanced Research Computing team
# Library
# Payne Institute
# Research and Technology Transfer
# University Honors and Scholars Programs
# Library
# Nuclear Science and Engineering
# Other
# Mining Engineering--thanks for leaving us out
# RTT
# 10

# %%
mech_civil = 4 + 8
cs_ee_ams = 6 + 9 + 0
met_geo_pet = 3 + 3 + 3 + 1 + 1
phy_chem = 3 + 2 + 6 + 1
soc = 3 + 9 + 7




print(mech_civil)
print(cs_ee_ams)
print(met_geo_pet)
print(phy_chem)
print(soc)
# Out:
# 12
# 15
# 11
# 12
# 19

# %%
print(total)
# Out:
# 90

# %%
n = num_of_res(phy)
print(n)
# Out:
# 6

# %%
mech_civil = [0] * 5
cs_ee_ams = [0] * 5
met_geo_pet = [0] * 5
phys_chem = [0] * 5
society = [0]*5

# %%
def dept_count(att1, att2):
    tem = [0] * 5
    for i in range(len(att1)):
        if not pd.isna(att1.iloc[i]) and att1.iloc[i] != '0' and att1.iloc[i] != 0:
            if att2.iloc[i] == "Never":
                tem[0] += 1
            elif att2.iloc[i] == "Once or Twice":
                tem[1] += 1
            elif att2.iloc[i] == "Regularly (Once or twice a week)":
                tem[2] += 1
            elif att2.iloc[i] == "All the time (daily, or more often)":
                tem[3] += 1
            elif att2.iloc[i] == "Have only used for fun or curiosity, never work":
                tem[4] += 1
    return tem

# %%
tem = dept_count(ams, genai)
print(tem)
cs_ee_ams = [a + b for a, b in zip(cs_ee_ams, tem)]
print(cs_ee_ams)
# Out:
# [2, 2, 0, 2, 0]
# [2, 2, 0, 2, 0]

# %%
tem = dept_count(cbe, genai)
print(tem)
phys_chem = [a + b for a, b in zip(phys_chem, tem)]
print(phys_chem)
# Out:
# [0, 1, 1, 0, 1]
# [0, 1, 1, 0, 1]

# %%
tem = dept_count(che, genai)
print(tem)
phys_chem = [a + b for a, b in zip(phys_chem, tem)]
print(phys_chem)
# Out:
# [1, 0, 1, 0, 0]
# [1, 1, 2, 0, 1]

# %%
tem = dept_count(ce, genai)
print(tem)
mech_civil = [a + b for a, b in zip(mech_civil, tem)]
print(mech_civil)
# Out:
# [2, 2, 0, 0, 0]
# [2, 2, 0, 0, 0]

# %%
tem = dept_count(cs, genai)
print(tem)
cs_ee_ams = [a + b for a, b in zip(cs_ee_ams, tem)]
print(cs_ee_ams)
# Out:
# [2, 1, 4, 2, 0]
# [4, 3, 4, 4, 0]

# %%
tem = dept_count(eb, genai)
print(tem)
society = [a + b for a, b in zip(society, tem)]
print(society)
# Out:
# [3, 0, 0, 0, 0]
# [3, 0, 0, 0, 0]

# %%
tem = dept_count(ee, genai)
print(tem)
cs_ee_ams = [a + b for a, b in zip(cs_ee_ams, tem)]
print(cs_ee_ams)
# Out:
# [0, 0, 0, 0, 0]
# [4, 3, 4, 4, 0]

# %%
tem = dept_count(gge, genai)
print(tem)
met_geo_pet = [a + b for a, b in zip(met_geo_pet, tem)]
print(met_geo_pet)
# Out:
# [0, 2, 0, 1, 0]
# [0, 2, 0, 1, 0]

# %%
tem = dept_count(geop, genai)
print(tem)
met_geo_pet = [a + b for a, b in zip(met_geo_pet, tem)]
print(met_geo_pet)
# Out:
# [0, 1, 1, 1, 0]
# [0, 3, 1, 2, 0]

# %%
tem = dept_count(has, genai)
print(tem)
society = [a + b for a, b in zip(society, tem)]
print(society)
# Out:
# [1, 4, 1, 0, 1]
# [4, 4, 1, 0, 1]

# %%
tem = dept_count(me, genai)
print(tem)
mech_civil = [a + b for a, b in zip(mech_civil, tem)]
print(mech_civil)
# Out:
# [2, 4, 1, 0, 1]
# [4, 6, 1, 0, 1]

# %%
tem = dept_count(mme, genai)
print(tem)
met_geo_pet = [a + b for a, b in zip(met_geo_pet, tem)]
print(met_geo_pet)
# Out:
# [1, 1, 1, 0, 0]
# [1, 4, 2, 2, 0]

# %%
tem = dept_count(mee, genai)
print(tem)
met_geo_pet = [a + b for a, b in zip(met_geo_pet, tem)]
print(met_geo_pet)
# Out:
# [0, 0, 0, 0, 0]
# [1, 4, 2, 2, 0]

# %%
tem = dept_count(pe, genai)
print(tem)
met_geo_pet = [a + b for a, b in zip(met_geo_pet, tem)]
print(met_geo_pet)
# Out:
# [0, 0, 1, 0, 0]
# [1, 4, 3, 2, 0]

# %%
tem = dept_count(phy, genai)
print(tem)
phys_chem = [a + b for a, b in zip(phys_chem, tem)]
print(phys_chem)
# Out:
# [1, 2, 1, 1, 1]
# [2, 3, 3, 1, 2]

# %%
admf = [0]*5

# %%
tem = dept_count(af, genai)
print(tem)
admf = [a + b for a, b in zip(admf, tem)]
print(admf)
# Out:
# [6, 3, 4, 0, 0]
# [6, 3, 4, 0, 0]

# %%
print(mech_civil)
print(cs_ee_ams)
print(met_geo_pet)
print(phys_chem)
print(society)
# Out:
# [4, 6, 1, 0, 1]
# [4, 3, 4, 4, 0]
# [1, 4, 3, 2, 0]
# [2, 3, 3, 1, 2]
# [4, 4, 1, 0, 1]

# %%
total = sum(mech_civil)
mech_civil = [round((x / total) * 100, 1) for x in mech_civil]

# %%
total = sum(cs_ee_ams)
cs_ee_ams = [round((x / total) * 100, 1) for x in cs_ee_ams]

# %%
total = sum(met_geo_pet)
met_geo_pet = [round((x / total) * 100, 1) for x in met_geo_pet]

# %%
total = sum(phys_chem)
phys_chem = [round((x / total) * 100, 1) for x in phys_chem]

# %%
total = sum(society)
society = [round((x / total) * 100, 1) for x in society]

# %%
print(mech_civil)
print(cs_ee_ams)
print(met_geo_pet)
print(phys_chem)
print(society)
# Out:
# [33.3, 50.0, 8.3, 0.0, 8.3]
# [26.7, 20.0, 26.7, 26.7, 0.0]
# [10.0, 40.0, 30.0, 20.0, 0.0]
# [18.2, 27.3, 27.3, 9.1, 18.2]
# [40.0, 40.0, 10.0, 0.0, 10.0]

# %%
categories = ['Never', 'Irregular Users', 'Regular Users', 'Superusers', 'Having fun']

# %%
grouped_bar_graph_horizontal_color(categories, mech_civil, cs_ee_ams, met_geo_pet, phys_chem, society, 'Frequency of using LLM-powered Chatbots',7,7) # size 7X7, font 16

# %%
years_at_mines_faculty = df_new["How many years have you been at Mines?"]

# %%
years_at_mines_faculty.value_counts()
# Out:
# How many years have you been at Mines?
# 1-5 years         26
# 10-20 years       24
# 5-10 years        22
# 1 year or less    12
# > 20 years         9
# Name: count, dtype: int64

# %%
ins_exp = df_new["How many years of full-time industry experience (i.e. public or private sector work outside of academia but within your current discipline) did you obtain in your field prior to beginning your role at Mines? (Please do not include internships or part-time roles.)"]

# %%
ins_exp.value_counts()
# Out:
# How many years of full-time industry experience (i.e. public or private sector work outside of academia but within your current discipline) did you obtain in your field prior to beginning your role at Mines? (Please do not include internships or part-time roles.)
# 1-5 years         21
# 10-20 years       13
# 5-10 years        12
# > 20 years         8
# 1 year or less     7
# Name: count, dtype: int64

# %%
count = 0
for val in ins_exp:
    if pd.isna(val):
        count += 1
print(count)
# Out:
# 34

# %%
# RQ4

# %%
spring_course = df_new["Did you teach at least one course during Spring 2023?"]

# %%
spring_course.value_counts()
# Out:
# Did you teach at least one course during Spring 2023?
# Yes    60
# No     35
# Name: count, dtype: int64

# %%
fall_course = df_new["How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select \"1.\" If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select \"2.\""]

# %%
fall_course.value_counts()
# Out:
# How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select "1." If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select "2."
# 1.0    34
# 2.0    30
# 0.0    21
# 3.0     8
# 4.0     2
# Name: count, dtype: int64

# %% [markdown]
# spring_policy = df_new["For the course(s) you taught during Spring 2023, to what degree did you provide guidance to students on GenAI?"]

# %%
spring_policy.value_counts()/ 60 * 100
# Out:
# For the course(s) you taught during Spring 2023, to what degree did you provide guidance to students on GenAI?
# Did not provide any guidance                                                             61.666667
# Loose guidance mentioned in class, but no formal policy statement                        23.333333
# Stated a policy in class or on the course website that was not listed on the syllabus    10.000000
# Formal policy in at least one syllabus                                                    5.000000
# Name: count, dtype: float64

# %%
class1 = df_new["Class 1: To what degree have you provided guidance to students on GenAI in this class?"]
class2 = df_new["Class 2: To what degree have you provided guidance to students on GenAI in this class?"]
class3 = df_new["Class 3: To what degree have you provided guidance to students on GenAI in this class?"]
class4 = df_new["Class 4: To what degree have you provided guidance to students on GenAI in this class?"]

# %%
class1.value_counts()
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office          45
# No guidance specific to GenAI has been provided yet                                       14
# Loose guidance mentioned in class, but no formal statement of policy                       6
# Formal policy in the syllabus that was not provided by the Provost's Office                5
# Formal policy was stated in class or on the course website, but not listed in syllabus     4
# Name: count, dtype: int64

# %%
filtered = df_new[fall_course == 1]

# %%
# Get value counts of class1 for these rows
print(filtered["Class 1: To what degree have you provided guidance to students on GenAI in this class?"].value_counts(dropna=False))
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office          20
# No guidance specific to GenAI has been provided yet                                        7
# Formal policy in the syllabus that was not provided by the Provost's Office                3
# Formal policy was stated in class or on the course website, but not listed in syllabus     2
# Loose guidance mentioned in class, but no formal statement of policy                       2
# Name: count, dtype: int64

# %%
filtered = df_new[(fall_course == 2)]

# %%
print(filtered["Class 1: To what degree have you provided guidance to students on GenAI in this class?"].value_counts(dropna=False))
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office          19
# No guidance specific to GenAI has been provided yet                                        5
# Formal policy in the syllabus that was not provided by the Provost's Office                2
# Formal policy was stated in class or on the course website, but not listed in syllabus     2
# Loose guidance mentioned in class, but no formal statement of policy                       2
# Name: count, dtype: int64

# %%
print(filtered["Class 2: To what degree have you provided guidance to students on GenAI in this class?"].value_counts(dropna=False))
# Out:
# Class 2: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    16
# No guidance specific to GenAI has been provided yet                                 11
# Formal policy in the syllabus that was not provided by the Provost's Office          2
# Loose guidance mentioned in class, but no formal statement of policy                 1
# Name: count, dtype: int64

# %%
filtered = df_new[(fall_course == 3)]

# %%
print(filtered["Class 1: To what degree have you provided guidance to students on GenAI in this class?"].value_counts(dropna=False))
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    5
# No guidance specific to GenAI has been provided yet                                 2
# Loose guidance mentioned in class, but no formal statement of policy                1
# Name: count, dtype: int64

# %%
print(filtered["Class 2: To what degree have you provided guidance to students on GenAI in this class?"].value_counts(dropna=False))
# Out:
# Class 2: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    5
# No guidance specific to GenAI has been provided yet                                 2
# Loose guidance mentioned in class, but no formal statement of policy                1
# Name: count, dtype: int64

# %%
print(filtered["Class 3: To what degree have you provided guidance to students on GenAI in this class?"].value_counts(dropna=False))
# Out:
# Class 3: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    4
# Loose guidance mentioned in class, but no formal statement of policy                2
# No guidance specific to GenAI has been provided yet                                 2
# Name: count, dtype: int64

# %%
aware_guidance = df_new["To what degree are you aware of the Mines-wide guidance that was issued by the Office of the Provost over email in August 2023? Please select all that apply:"]

# %%
aware_guidance.value_counts()
# Out:
# To what degree are you aware of the Mines-wide guidance that was issued by the Office of the Provost over email in August 2023? Please select all that apply:
# 0                                                      85
# I am unaware of any institutional guidance on GenAI    10
# Name: count, dtype: int64

# %%
class1.value_counts()
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office          45
# No guidance specific to GenAI has been provided yet                                       14
# Loose guidance mentioned in class, but no formal statement of policy                       6
# Formal policy in the syllabus that was not provided by the Provost's Office                5
# Formal policy was stated in class or on the course website, but not listed in syllabus     4
# Name: count, dtype: int64

# %%
class2.value_counts()
# Out:
# Class 2: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    21
# No guidance specific to GenAI has been provided yet                                 15
# Formal policy in the syllabus that was not provided by the Provost's Office          2
# Loose guidance mentioned in class, but no formal statement of policy                 2
# Name: count, dtype: int64

# %%
class3.value_counts()
# Out:
# Class 3: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    5
# No guidance specific to GenAI has been provided yet                                 3
# Loose guidance mentioned in class, but no formal statement of policy                2
# Name: count, dtype: int64

# %%
class4.value_counts()
# Out:
# Class 4: To what degree have you provided guidance to students on GenAI in this class?
# No guidance specific to GenAI has been provided yet                                 1
# Formal policy in the syllabus using language recommended by the Provost's Office    1
# Name: count, dtype: int64

# %%
# RQ4 -> Need re-analyze everything by not considering admitrative faculty as they didn't conduct any courses. More over, course order doesn't matter for those faculty whi took more than one unique course

# %%
role.value_counts()
# Out:
# What is your current role at Mines?
# Administrative faculty                        16
# Tenure track faculty  Full professor         16
# Teaching faculty  Full professor             13
# Adjunct faculty                               10
# Tenure track faculty  Associate professor     9
# Tenure track faculty  Assistant professor     8
# Teaching faculty  Associate professor         8
# Teaching faculty  Assistant professor         6
# Postdoctoral staff or research faculty         4
# Other (Please specify)                         2
# Professor of practice                          2
# Name: count, dtype: int64

# %%
filtered = df_new[~role.isin(["Administrative faculty", "Other (Please specify)"])]

# %%
role_filtered = filtered["What is your current role at Mines?"]
role_filtered.value_counts()
# Out:
# What is your current role at Mines?
# Tenure track faculty  Full professor         16
# Teaching faculty  Full professor             13
# Adjunct faculty                               10
# Tenure track faculty  Associate professor     9
# Tenure track faculty  Assistant professor     8
# Teaching faculty  Associate professor         8
# Teaching faculty  Assistant professor         6
# Postdoctoral staff or research faculty         4
# Professor of practice                          2
# Name: count, dtype: int64

# %%
role_filtered.value_counts().sum()
# Out:
# 76

# %%
spring_course_fil = filtered["Did you teach at least one course during Spring 2023?"]

# %%
spring_course_fil.value_counts()
# Out:
# Did you teach at least one course during Spring 2023?
# Yes    58
# No     19
# Name: count, dtype: int64

# %%
for i in range(len(spring_course)):
    print(response_id.iloc[i])
    print(role.iloc[i])
    print(spring_course.iloc[i])
    print("\n")
# Out:
# 114801644.0
# Tenure track faculty  Associate professor
# No
#
#
# 114801654.0
# Administrative faculty
# No
#
#
# 114801670.0
# Administrative faculty
# No
#
#
# 114801704.0
# Teaching faculty  Full professor
# Yes
#
#
# 114801762.0
# Tenure track faculty  Full professor
# No
#
#
# 114801781.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 114801906.0
# Other (Please specify)
# No
#
#
# 114801956.0
# Administrative faculty
# No
#
#
# 114802421.0
# Administrative faculty
# No
#
#
# 114802480.0
# Administrative faculty
# No
#
#
# 114802630.0
# Postdoctoral staff or research faculty
# No
#
#
# 114802886.0
# Teaching faculty  Associate professor
# Yes
#
#
# 114803243.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 114803641.0
# Teaching faculty  Associate professor
# Yes
#
#
# 114803953.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 114804279.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 114804700.0
# Teaching faculty  Assistant professor
# Yes
#
#
# 114807076.0
# Adjunct faculty
# Yes
#
#
# 114807181.0
# Administrative faculty
# No
#
#
# 114807503.0
# Administrative faculty
# No
#
#
# 114808670.0
# Teaching faculty  Full professor
# Yes
#
#
# 114808702.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 114809188.0
# Tenure track faculty  Full professor
# Yes
#
#
# 114809380.0
# Teaching faculty  Full professor
# Yes
#
#
# 114809718.0
# Adjunct faculty
# No
#
#
# 114810278.0
# Adjunct faculty
# Yes
#
#
# 114810380.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 114812124.0
# Adjunct faculty
# Yes
#
#
# 114812414.0
# Adjunct faculty
# Yes
#
#
# 114813545.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 114814551.0
# Tenure track faculty  Full professor
# No
#
#
# 114816105.0
# Tenure track faculty  Full professor
# Yes
#
#
# 114819658.0
# Professor of practice
# Yes
#
#
# 114822072.0
# Teaching faculty  Associate professor
# Yes
#
#
# 114824850.0
# Tenure track faculty  Full professor
# Yes
#
#
# 114844744.0
# Postdoctoral staff or research faculty
# No
#
#
# 114847692.0
# Administrative faculty
# Yes
#
#
# 114849738.0
# Administrative faculty
# No
#
#
# 114849752.0
# Tenure track faculty  Full professor
# No
#
#
# 114850983.0
# Adjunct faculty
# Yes
#
#
# 114851075.0
# Administrative faculty
# No
#
#
# 114851226.0
# Teaching faculty  Assistant professor
# No
#
#
# 114858021.0
# Tenure track faculty  Associate professor
# No
#
#
# 114867495.0
# Teaching faculty  Full professor
# Yes
#
#
# 114869948.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 114874217.0
# Administrative faculty
# No
#
#
# 114879598.0
# Teaching faculty  Full professor
# Yes
#
#
# 114879842.0
# Adjunct faculty
# Yes
#
#
# 114890869.0
# Tenure track faculty  Full professor
# No
#
#
# 114899737.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 114938657.0
# Teaching faculty  Full professor
# Yes
#
#
# 114960372.0
# Teaching faculty  Associate professor
# Yes
#
#
# 115065414.0
# Administrative faculty
# No
#
#
# 115098118.0
# Teaching faculty  Full professor
# Yes
#
#
# 115112276.0
# Tenure track faculty  Full professor
# Yes
#
#
# 115150124.0
# Teaching faculty  Full professor
# Yes
#
#
# 115155132.0
# Teaching faculty  Assistant professor
# Yes
#
#
# 115172053.0
# Teaching faculty  Full professor
# Yes
#
#
# 115174637.0
# Teaching faculty  Assistant professor
# Yes
#
#
# 115245867.0
# Other (Please specify)
# No
#
#
# 115297907.0
# Adjunct faculty
# Yes
#
#
# 115307970.0
# Teaching faculty  Assistant professor
# Yes
#
#
# 115394412.0
# Tenure track faculty  Full professor
# Yes
#
#
# 115403305.0
# Tenure track faculty  Full professor
# Yes
#
#
# 115405026.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 115425525.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 115442779.0
# Administrative faculty
# No
#
#
# 115446143.0
# Teaching faculty  Assistant professor
# No
#
#
# 115446166.0
# nan
# Yes
#
#
# 115446173.0
# Tenure track faculty  Full professor
# No
#
#
# 115446216.0
# Teaching faculty  Full professor
# Yes
#
#
# 115446222.0
# Tenure track faculty  Full professor
# No
#
#
# 115446661.0
# Teaching faculty  Full professor
# Yes
#
#
# 115446706.0
# Adjunct faculty
# No
#
#
# 115446734.0
# Teaching faculty  Associate professor
# Yes
#
#
# 115447557.0
# Teaching faculty  Full professor
# Yes
#
#
# 115447600.0
# Postdoctoral staff or research faculty
# No
#
#
# 115447710.0
# Tenure track faculty  Full professor
# No
#
#
# 115447927.0
# Administrative faculty
# No
#
#
# 115448224.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 115449020.0
# Tenure track faculty  Associate professor
# Yes
#
#
# 115449138.0
# Tenure track faculty  Assistant professor
# Yes
#
#
# 115449890.0
# Adjunct faculty
# No
#
#
# 115450715.0
# Administrative faculty
# No
#
#
# 115451189.0
# Teaching faculty  Associate professor
# Yes
#
#
# 115451837.0
# Administrative faculty
# Yes
#
#
# 115452781.0
# Professor of practice
# Yes
#
#
# 115454316.0
# Teaching faculty  Full professor
# Yes
#
#
# 115455720.0
# Postdoctoral staff or research faculty
# Yes
#
#
# 115458823.0
# Teaching faculty  Associate professor
# Yes
#
#
# 115473017.0
# Tenure track faculty  Full professor
# No
#
#
# 115473179.0
# Teaching faculty  Associate professor
# Yes
#
#
# 115474843.0
# Tenure track faculty  Full professor
# No
#
#
# 115488174.0
# Tenure track faculty  Full professor
# Yes
#
#
# 115496611.0
# Tenure track faculty  Assistant professor
# Yes

# %%
fall_course_fil = filtered["How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select \"1.\" If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select \"2.\""]

# %%
fall_course_fil.value_counts()
# Out:
# How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select "1." If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select "2."
# 2.0    30
# 1.0    29
# 0.0     9
# 3.0     7
# 4.0     2
# Name: count, dtype: int64

# %%
fall_course_fil.value_counts().sum()
# Out:
# 77

# %%
spring_policy_fil = filtered["For the course(s) you taught during Spring 2023, to what degree did you provide guidance to students on GenAI?"]

# %%
spring_policy_fil.value_counts() / 58 * 100
# Out:
# For the course(s) you taught during Spring 2023, to what degree did you provide guidance to students on GenAI?
# Did not provide any guidance                                                             60.344828
# Loose guidance mentioned in class, but no formal policy statement                        24.137931
# Stated a policy in class or on the course website that was not listed on the syllabus    10.344828
# Formal policy in at least one syllabus                                                    5.172414
# Name: count, dtype: float64

# %%
class1 = filtered["Class 1: To what degree have you provided guidance to students on GenAI in this class?"]
class2 = filtered["Class 2: To what degree have you provided guidance to students on GenAI in this class?"]
class3 = filtered["Class 3: To what degree have you provided guidance to students on GenAI in this class?"]
class4 = filtered["Class 4: To what degree have you provided guidance to students on GenAI in this class?"]

# %%
res = filtered["Response ID"]
print(len(res))
# Out:
# 77

# %%
fil2 = filtered[fall_course_fil == 1]

# %%
print(fil2["Class 1: To what degree have you provided guidance to students on GenAI in this class?"].value_counts())
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office          19
# No guidance specific to GenAI has been provided yet                                        4
# Formal policy in the syllabus that was not provided by the Provost's Office                3
# Loose guidance mentioned in class, but no formal statement of policy                       2
# Formal policy was stated in class or on the course website, but not listed in syllabus     1
# Name: count, dtype: int64

# %%
formal_recommended = "Formal policy in the syllabus using language recommended by the Provost's Office"
formal_own = "Formal policy in the syllabus that was not provided by the Provost's Office"
formal_other = "Formal policy was stated in class or on the course website, but not listed in syllabus"
informal = "Loose guidance mentioned in class, but no formal statement of policy"
none = "No guidance specific to GenAI has been provided yet"

# %%
fil2 = filtered[fall_course_fil == 2]

# %%
print(fil2["Class 1: To what degree have you provided guidance to students on GenAI in this class?"].value_counts())
# Out:
# Class 1: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office          19
# No guidance specific to GenAI has been provided yet                                        5
# Formal policy in the syllabus that was not provided by the Provost's Office                2
# Formal policy was stated in class or on the course website, but not listed in syllabus     2
# Loose guidance mentioned in class, but no formal statement of policy                       2
# Name: count, dtype: int64

# %%
print(fil2["Class 2: To what degree have you provided guidance to students on GenAI in this class?"].value_counts())
# Out:
# Class 2: To what degree have you provided guidance to students on GenAI in this class?
# Formal policy in the syllabus using language recommended by the Provost's Office    16
# No guidance specific to GenAI has been provided yet                                 11
# Formal policy in the syllabus that was not provided by the Provost's Office          2
# Loose guidance mentioned in class, but no formal statement of policy                 1
# Name: count, dtype: int64

# %%
fil2 = filtered[(fall_course_fil == 1) | (fall_course_fil == 2) | (fall_course_fil == 3) | (fall_course_fil == 4)]

# %%
res2 = fil2["Response ID"]
print(len(res2))
# Out:
# 68

# %%
class1_level = fil2["Class 1: What is the level of this course?"]
class2_level = fil2["Class 2: What is the level of this course?"]
class3_level = fil2["Class 3: What is the level of this course?"]
class4_level = fil2["Class 4: What is the level of this course?"]

# %%
# Initialize counters
frec = 0      # Formal - Provost syllabus
fown = 0      # Formal - own syllabus
fother = 0    # Formal - in-class/website
info_only = 0 # Informal guidance only
none_count = 0  # No guidance at all
not_res = 0
not_res_vec = []
# Constants (your original strings)
formal_recommended = "Formal policy in the syllabus using language recommended by the Provost's Office"
formal_own = "Formal policy in the syllabus that was not provided by the Provost's Office"
formal_other = "Formal policy was stated in class or on the course website, but not listed in syllabus"
informal = "Loose guidance mentioned in class, but no formal statement of policy"
none = "No guidance specific to GenAI has been provided yet"

# Loop through faculty
for i in range(len(res2)):
    
    responses = [class1.iloc[i], class2.iloc[i], class3.iloc[i], class4.iloc[i]]
    responses_clean = [r for r in responses if pd.notna(r)]
    if len(responses_clean) == 0:
        not_res += 1
        not_res_vec.append(res2.iloc[i])
    course_level = [class1_level.iloc[i], class2_level.iloc[i], class3_level.iloc[i], class4_level.iloc[i]]
    #print(res.iloc[i])
    #print(responses)
    # First check for formal types (priority)
    if formal_recommended in responses_clean:
        frec += 1
    elif formal_own in responses_clean:
        fown += 1
    elif formal_other in responses_clean:
        fother += 1
    elif len(responses_clean) > 0 and all(r == informal for r in responses_clean):
        info_only += 1
        #print(course_level)
    elif len(responses_clean) > 0 and all(r == none for r in responses_clean):
        none_count += 1
    else:
        if informal in responses_clean:
            info_only += 1

# %%
print(frec)
print(fown)
print(fother)
print(info_only)
print(none_count)
print(not_res)
print(not_res_vec)
# Out:
# 39
# 6
# 2
# 6
# 8
# 7
# [114802886.0, 114808670.0, 114809188.0, 114812414.0, 114867495.0, 114960372.0, 115452781.0]

# %%
total = len(res2)
total_formal = frec + fown + fother
pct_formal = total_formal / total * 100
pct_frec = frec / total * 100
pct_fown = fown / total * 100
pct_fother = fother / total * 100
pct_info = info_only / total * 100
pct_none = none_count / total * 100

# %%
print(f"{pct_formal:.1f}% of faculty gave some form of formal GenAI guidance in at least one course they taught:")
print(f"  - {pct_frec:.1f}% used Provost’s Office language in their syllabus")
print(f"  - {pct_fown:.1f}% used their own syllabus language")
print(f"  - {pct_fother:.1f}% gave formal guidance outside the syllabus (e.g., in class or online)")

print(f"{pct_info:.1f}% gave only informal guidance in all courses")
print(f"{pct_none:.1f}% gave no GenAI-related guidance in any of their courses")
# Out:
# 69.1% of faculty gave some form of formal GenAI guidance in at least one course they taught:
#   - 57.4% used Provost’s Office language in their syllabus
#   - 8.8% used their own syllabus language
#   - 2.9% gave formal guidance outside the syllabus (e.g., in class or online)
# 8.8% gave only informal guidance in all courses
# 11.8% gave no GenAI-related guidance in any of their courses

# %%
# Aware Vs Guidance

# %%
unaware = fil2["To what degree are you aware of the Mines-wide guidance that was issued by the Office of the Provost over email in August 2023? Please select all that apply:"]

# %%
unaware.value_counts()
# Out:
# To what degree are you aware of the Mines-wide guidance that was issued by the Office of the Provost over email in August 2023? Please select all that apply:
# 0                                                      63
# I am unaware of any institutional guidance on GenAI     5
# Name: count, dtype: int64

# %%
saw_email = fil2["Unnamed: 40"]
saw_email.value_counts()
# Out:
# Unnamed: 40
# I saw the email from the Provosts email    49
# 0                                           19
# Name: count, dtype: int64

# %%
read_guidelines_email = fil2["Unnamed: 41"]
read_guidelines_email.value_counts()
# Out:
# Unnamed: 41
# I read the guidelines provided in the email    51
# 0                                              17
# Name: count, dtype: int64

# %%
read_lan_syl_tem = fil2["Unnamed: 42"]
read_lan_syl_tem.value_counts()
# Out:
# Unnamed: 42
# I have read the language on GenAI in the new syllabus template    50
# 0                                                                 18
# Name: count, dtype: int64

# %%
visit_trefny = fil2["Unnamed: 43"]
visit_trefny.value_counts()
# Out:
# Unnamed: 43
# 0                                                   38
# I have visited the Trefny Centers resource page    30
# Name: count, dtype: int64

# %%
guidance_binary = []  # 1 = gave formal guidance in any course, 0 = only informal or none

for i in range(len(res2)):
    responses = [class1.iloc[i], class2.iloc[i], class3.iloc[i], class4.iloc[i]]
    responses_clean = [r for r in responses if pd.notna(r)]

    if formal_recommended in responses_clean or formal_own in responses_clean or formal_other in responses_clean:
        guidance_binary.append(1)
    elif len(responses_clean) > 0 and all(r in [informal, none] for r in responses_clean):
        guidance_binary.append(0)
    elif len(responses_clean) == 0:
        guidance_binary.append(0)  # optionally exclude these or set as 0

# %%
pd.Series(guidance_binary).value_counts()
# Out:
# 1    47
# 0    21
# Name: count, dtype: int64

# %%
del str  # Restore built-in str type

# %%
unaware_binary = unaware.apply(lambda x: 1 if isinstance(x, str) and "unaware" in x.lower() else 0)
saw_email_binary = saw_email.apply(lambda x: 1 if isinstance(x, str) and "email" in x.lower() else 0)
read_guidelines_binary = fil2["Unnamed: 41"].apply(lambda x: 1 if isinstance(x, str) and "guidelines" in x.lower() else 0)
syllabus_template_binary = fil2["Unnamed: 42"].apply(lambda x: 1 if isinstance(x, str) and "syllabus" in x.lower() else 0)
trefny_binary = fil2["Unnamed: 43"].apply(lambda x: 1 if isinstance(x, str) and "trefny" in x.lower() else 0)

# %%
pd.Series(unaware_binary).value_counts()
# Out:
# To what degree are you aware of the Mines-wide guidance that was issued by the Office of the Provost over email in August 2023? Please select all that apply:
# 0    63
# 1     5
# Name: count, dtype: int64

# %%
df_model = pd.DataFrame({
    "Id": res2,
    "guidance": guidance_binary,
    "unaware": unaware_binary,
    "aware_email": saw_email_binary,
    "aware_read_guidelines": read_guidelines_binary,
    "aware_syllabus_template": syllabus_template_binary,
    "aware_trefny": trefny_binary
})

# %%
df_model = df_model[~df_model["Id"].isin(not_res_vec)]

# %%
df_model
# Out:
#               Id  guidance  unaware  aware_email  aware_read_guidelines  \
# 8    114801644.0         0        0            1                      0
# 11   114801704.0         1        0            1                      1
# 13   114801762.0         0        0            0                      0
# 14   114801781.0         1        0            1                      1
# 31   114803243.0         0        0            1                      0
# ..           ...       ...      ...          ...                    ...
# 134  115458823.0         1        0            1                      1
# 138  115473179.0         1        0            1                      1
# 139  115474843.0         1        0            1                      1
# 140  115488174.0         0        0            1                      1
# 141  115496611.0         1        0            1                      1
#
#      aware_syllabus_template  aware_trefny
# 8                          0             0
# 11                         1             0
# 13                         0             1
# 14                         1             0
# 31                         0             0
# ..                       ...           ...
# 134                        1             1
# 138                        1             0
# 139                        0             0
# 140                        1             1
# 141                        1             1
#
# [61 rows x 7 columns]

# %%
# Cross-tab of awareness vs guidance
pd.crosstab(df_model["aware_email"], df_model["guidance"])
# Out:
# guidance      0   1
# aware_email
# 0             4  12
# 1            10  35

# %%
aware_summary = pd.crosstab(df_model["unaware"], df_model["guidance"], normalize='index') * 100
print(aware_summary)
# Out:
# guidance          0           1
# unaware
# 0         24.561404   75.438596
# 1          0.000000  100.000000

# %%
import statsmodels.api as sm

# %%
# Define IVs and DV
X = df_model[[ "aware_email", "aware_read_guidelines", "aware_syllabus_template", "aware_trefny"]]
y = df_model["guidance"]

# %%
# Add intercept to X
X = sm.add_constant(X)

# %%
# Fit logistic regression
model = sm.Logit(y, X)
result = model.fit()

# Output summary
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.530140
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               guidance   No. Observations:                   61
# Model:                          Logit   Df Residuals:                       56
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 02 Jul 2025   Pseudo R-squ.:                 0.01586
# Time:                        16:10:08   Log-Likelihood:                -32.339
# converged:                       True   LL-Null:                       -32.860
# Covariance Type:            nonrobust   LLR p-value:                    0.9034
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.7908      0.680      1.163      0.245      -0.542       2.123
# aware_email                -0.1476      0.759     -0.194      0.846      -1.636       1.340
# aware_read_guidelines       0.4158      0.937      0.444      0.657      -1.420       2.251
# aware_syllabus_template     0.4111      0.925      0.444      0.657      -1.402       2.224
# aware_trefny               -0.1294      0.659     -0.196      0.844      -1.422       1.163
# ===========================================================================================

# %%
from scipy.stats import fisher_exact

table = [[14, 43],  # Unaware = 0
         [0, 4]]    # Unaware = 1

oddsratio, p_value = fisher_exact(table)
print(f"Fisher's exact test p-value: {p_value:.4f}")
# Out:
# Fisher's exact test p-value: 0.5650

# %%
course_levels = pd.DataFrame({
    'class1': class1_level,
    'class2': class2_level,
    'class3': class3_level,
    'class4': class4_level
})

# %%
course_levels
# Out:
#                                                 class1  \
# 8                Graduate (mostly M.S./Ph.D. students)
# 11   Early undergraduate (mostly first-/second-year...
# 13               Graduate (mostly M.S./Ph.D. students)
# 14               Graduate (mostly M.S./Ph.D. students)
# 29   Late undergraduate (mostly third-/fourth-year ...
# ..                                                 ...
# 134  Early undergraduate (mostly first-/second-year...
# 138  Early undergraduate (mostly first-/second-year...
# 139  Late undergraduate (mostly third-/fourth-year ...
# 140  Late undergraduate (mostly third-/fourth-year ...
# 141              Graduate (mostly M.S./Ph.D. students)
#
#                                                 class2  \
# 8                Graduate (mostly M.S./Ph.D. students)
# 11                                                 NaN
# 13               Graduate (mostly M.S./Ph.D. students)
# 14                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 134  Late undergraduate (mostly third-/fourth-year ...
# 138  Late undergraduate (mostly third-/fourth-year ...
# 139                                                NaN
# 140              Graduate (mostly M.S./Ph.D. students)
# 141                                                NaN
#
#                                                 class3 class4
# 8    Late undergraduate (mostly third-/fourth-year ...    NaN
# 11                                                 NaN    NaN
# 13                                                 NaN    NaN
# 14                                                 NaN    NaN
# 29                                                 NaN    NaN
# ..                                                 ...    ...
# 134                                                NaN    NaN
# 138                                                NaN    NaN
# 139                                                NaN    NaN
# 140                                                NaN    NaN
# 141                                                NaN    NaN
#
# [68 rows x 4 columns]

# %%
early_ug = course_levels.apply(lambda row: any("Early undergraduate" in str(val) for val in row), axis=1).astype(int)
late_ug = course_levels.apply(lambda row: any("Late undergraduate" in str(val) for val in row), axis=1).astype(int)
grad = course_levels.apply(lambda row: any("Graduate" in str(val) for val in row), axis=1).astype(int)

# %%
grad
# Out:
# 8      1
# 11     0
# 13     1
# 14     1
# 29     0
#       ..
# 134    0
# 138    0
# 139    0
# 140    1
# 141    1
# Length: 68, dtype: int64

# %%
unique_course = fil2["How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select \"1.\" If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select \"2.\""]

# %%
unique_course.value_counts()
# Out:
# How many unique courses are you teaching during Fall 2023? For example, if you are teaching 1 course with 3 sections, please select "1." If you are teaching 2 different courses, 1 with 2 sections, the other with 1 section, please select "2."
# 2.0    30
# 1.0    29
# 3.0     7
# 4.0     2
# Name: count, dtype: int64

# %%
df_model2 = pd.DataFrame({
    "guidance": guidance_binary,
    "num_courses": unique_course,
    "early_ug": early_ug,
    "late_ug": late_ug,
    "grad": grad
})

# %%
df_model2
# Out:
#      guidance  num_courses  early_ug  late_ug  grad
# 8           0          3.0         0        1     1
# 11          1          1.0         1        0     0
# 13          0          2.0         0        0     1
# 14          1          1.0         0        0     1
# 29          0          1.0         0        1     0
# ..        ...          ...       ...      ...   ...
# 134         1          2.0         1        1     0
# 138         1          2.0         1        1     0
# 139         1          1.0         0        1     0
# 140         0          2.0         0        1     1
# 141         1          1.0         0        0     1
#
# [68 rows x 5 columns]

# %%
print(len(guidance_binary))
print(len(unique_course))
print(len(early_ug))
print(len(late_ug))
print(len(grad))
# Out:
# 68
# 68
# 68
# 68
# 68

# %%
# Define IVs (excluding one dummy to serve as reference group)
X = df_model2[["num_courses", "early_ug", "late_ug", "grad"]]  
X = sm.add_constant(X)

# DV
y = df_model2["guidance"]

# Fit logistic regression
model = sm.Logit(y, X)
result = model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.567000
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               guidance   No. Observations:                   68
# Model:                          Logit   Df Residuals:                       63
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 03 Jul 2025   Pseudo R-squ.:                 0.08276
# Time:                        13:00:17   Log-Likelihood:                -38.556
# converged:                       True   LL-Null:                       -42.035
# Covariance Type:            nonrobust   LLR p-value:                    0.1382
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.4148      0.921      2.622      0.009       0.610       4.220
# num_courses    -0.8901      0.434     -2.053      0.040      -1.740      -0.040
# early_ug        0.0679      0.775      0.088      0.930      -1.451       1.587
# late_ug        -0.1340      0.793     -0.169      0.866      -1.689       1.421
# grad            0.2565      0.788      0.326      0.745      -1.287       1.800
# ===============================================================================

# %%
role_fall = fil2["What is your current role at Mines?"]
genai_usage_freq_fall = fil2["Please rate how frequently you have used the following GenAI-based tools for your classes, research, and/or any other professional efforts"]

# %%
role_fall.value_counts()
# Out:
# What is your current role at Mines?
# Tenure track faculty  Full professor         15
# Teaching faculty  Full professor             13
# Tenure track faculty  Associate professor     8
# Teaching faculty  Associate professor         8
# Adjunct faculty                                8
# Tenure track faculty  Assistant professor     7
# Teaching faculty  Assistant professor         6
# Professor of practice                          2
# Name: count, dtype: int64

# %%
df_model3 = pd.DataFrame({
    "usage": genai_usage_freq_fall,
    "role": role_fall,
    "num_course": unique_course
})

# %%
df_model3
# Out:
#                                    usage  \
# 8       Regularly (Once or twice a week)
# 11                                 Never
# 13                                 Never
# 14                         Once or Twice
# 29      Regularly (Once or twice a week)
# ..                                   ...
# 134     Regularly (Once or twice a week)
# 138  All the time (daily, or more often)
# 139                                Never
# 140     Regularly (Once or twice a week)
# 141     Regularly (Once or twice a week)
#
#                                            role  num_course
# 8    Tenure track faculty  Associate professor         3.0
# 11            Teaching faculty  Full professor         1.0
# 13        Tenure track faculty  Full professor         2.0
# 14   Tenure track faculty  Assistant professor         1.0
# 29       Teaching faculty  Associate professor         1.0
# ..                                          ...         ...
# 134      Teaching faculty  Associate professor         2.0
# 138      Teaching faculty  Associate professor         2.0
# 139       Tenure track faculty  Full professor         1.0
# 140       Tenure track faculty  Full professor         2.0
# 141  Tenure track faculty  Assistant professor         1.0
#
# [68 rows x 3 columns]

# %%
# Define usage order
from pandas.api.types import CategoricalDtype

usage_order = CategoricalDtype(categories=['Never', 'Have only used for fun or curiosity, never work', 'Once or Twice', 'Regularly (Once or twice a week)', 'All the time (daily, or more often)'], ordered=True)

df_model3['usage'] = df_model3['usage'].astype(usage_order)

# %%
df_dummies = pd.get_dummies(df_model3['role'], drop_first=True)  # drop_first avoids multicollinearity
X = pd.concat([df_dummies, df_model3['num_course']], axis=1)

# %%
X
# Out:
#      Professor of practice  Teaching faculty  Assistant professor  \
# 8                    False                                   False
# 11                   False                                   False
# 13                   False                                   False
# 14                   False                                   False
# 29                   False                                   False
# ..                     ...                                     ...
# 134                  False                                   False
# 138                  False                                   False
# 139                  False                                   False
# 140                  False                                   False
# 141                  False                                   False
#
#      Teaching faculty  Associate professor  \
# 8                                     False
# 11                                    False
# 13                                    False
# 14                                    False
# 29                                     True
# ..                                      ...
# 134                                    True
# 138                                    True
# 139                                   False
# 140                                   False
# 141                                   False
#
#      Teaching faculty  Full professor  \
# 8                                False
# 11                                True
# 13                               False
# 14                               False
# 29                               False
# ..                                 ...
# 134                              False
# 138                              False
# 139                              False
# 140                              False
# 141                              False
#
#      Tenure track faculty  Assistant professor  \
# 8                                         False
# 11                                        False
# 13                                        False
# 14                                         True
# 29                                        False
# ..                                          ...
# 134                                       False
# 138                                       False
# 139                                       False
# 140                                       False
# 141                                        True
#
#      Tenure track faculty  Associate professor  \
# 8                                          True
# 11                                        False
# 13                                        False
# 14                                        False
# 29                                        False
# ..                                          ...
# 134                                       False
# 138                                       False
# 139                                       False
# 140                                       False
# 141                                       False
#
#      Tenure track faculty  Full professor  num_course
# 8                                    False         3.0
# 11                                   False         1.0
# 13                                    True         2.0
# 14                                   False         1.0
# 29                                   False         1.0
# ..                                     ...         ...
# 134                                  False         2.0
# 138                                  False         2.0
# 139                                   True         1.0
# 140                                   True         2.0
# 141                                  False         1.0
#
# [68 rows x 8 columns]

# %%
usage_order = CategoricalDtype(
    categories=[
        'Never', 
        'Have only used for fun or curiosity, never work', 
        'Once or Twice', 
        'Regularly (Once or twice a week)', 
        'All the time (daily, or more often)'
    ],
    ordered=True
)
df_model3['usage'] = df_model3['usage'].astype(usage_order)

# %%
df_model3['usage_code'] = df_model3['usage'].cat.codes

# %%
y = df_model3['usage']

# %%
y
# Out:
# 8         Regularly (Once or twice a week)
# 11                                   Never
# 13                                   Never
# 14                           Once or Twice
# 29        Regularly (Once or twice a week)
#                       ...
# 134       Regularly (Once or twice a week)
# 138    All the time (daily, or more often)
# 139                                  Never
# 140       Regularly (Once or twice a week)
# 141       Regularly (Once or twice a week)
# Name: usage, Length: 68, dtype: category
# Categories (5, object): ['Never' < 'Have only used for fun or curiosity, never work' < 'Once or Twice' < 'Regularly (Once or twice a week)' < 'All the time (daily, or more often)']

# %%
import pandas as pd
from statsmodels.miscmodels.ordinal_model import OrderedModel
from pandas.api.types import CategoricalDtype

# Define the usage order
usage_order = CategoricalDtype(
    categories=[
        'Never',
        'Have only used for fun or curiosity, never work',
        'Once or Twice',
        'Regularly (Once or twice a week)',
        'All the time (daily, or more often)'
    ],
    ordered=True
)

# Apply ordered category
df_model3['usage'] = df_model3['usage'].astype(usage_order)
df_model3['usage_code'] = df_model3['usage'].cat.codes

# Convert 'role' to dummies and ensure all are numeric
df_dummies = pd.get_dummies(df_model3['role'], drop_first=True).astype(float)

# Ensure num_course is numeric
df_model3['num_course'] = pd.to_numeric(df_model3['num_course'], errors='coerce')

# Combine predictors
X = pd.concat([df_dummies, df_model3['num_course']], axis=1).astype(float)

# Target
y = df_model3['usage_code'].astype(int)

# Fit the model
model = OrderedModel(y, X, distr='logit')
result = model.fit(method='bfgs')  # method required sometimes
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 1.335716
#          Iterations: 57
#          Function evaluations: 59
#          Gradient evaluations: 59
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:             usage_code   Log-Likelihood:                -90.829
# Model:                   OrderedModel   AIC:                             205.7
# Method:            Maximum Likelihood   BIC:                             232.3
# Date:                Thu, 03 Jul 2025
# Time:                        13:49:04
# No. Observations:                  68
# Df Residuals:                      56
# Df Model:                           8
# ==============================================================================================================
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Professor of practice                         -0.7815      1.956     -0.399      0.690      -4.616       3.053
# Teaching faculty  Assistant professor        -0.8159      1.017     -0.802      0.422      -2.809       1.177
# Teaching faculty  Associate professor         1.5085      0.955      1.579      0.114      -0.363       3.380
# Teaching faculty  Full professor             -0.5601      0.824     -0.680      0.496      -2.174       1.054
# Tenure track faculty  Assistant professor     2.3728      1.013      2.341      0.019       0.386       4.359
# Tenure track faculty  Associate professor    -0.8195      0.924     -0.887      0.375      -2.630       0.991
# Tenure track faculty  Full professor         -0.0591      0.819     -0.072      0.942      -1.665       1.547
# num_course                                     0.4584      0.342      1.340      0.180      -0.212       1.129
# 0/1                                           -0.3683      0.784     -0.470      0.638      -1.905       1.168
# 1/2                                           -0.9444      0.431     -2.192      0.028      -1.789      -0.100
# 2/3                                            0.5701      0.184      3.092      0.002       0.209       0.931
# 3/4                                            0.5253      0.255      2.064      0.039       0.026       1.024
# ==============================================================================================================

# %%
print(df_model3.dtypes)
print(df_dummies.dtypes)
# Out:
# usage         category
# role            object
# num_course     float64
# usage_code        int8
# dtype: object
# Professor of practice                         float64
# Teaching faculty  Assistant professor        float64
# Teaching faculty  Associate professor        float64
# Teaching faculty  Full professor             float64
# Tenure track faculty  Assistant professor    float64
# Tenure track faculty  Associate professor    float64
# Tenure track faculty  Full professor         float64
# dtype: object

# %%
mines_li = df_new["Which of the following resources would you be likely to use in order to integrate generative AI effectively and responsibly in your role at Mines? (Select all that apply)"]

# %%
mines_li.value_counts()
# Out:
# Which of the following resources would you be likely to use in order to integrate generative AI effectively and responsibly in your role at Mines? (Select all that apply)
# Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)    64
# 0                                                                                                         30
# Name: count, dtype: int64

# %%
mines_li.value_counts()["Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)"]
# Out:
# 64

# %%
custom_imp = df_new["Unnamed: 32"]

# %%
custom_imp.value_counts()
# Out:
# Unnamed: 32
# 0                                                                                                                               67
# Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)    27
# Name: count, dtype: int64

# %%
tools_idn_ai_con = df_new["Unnamed: 33"]

# %%
tools_idn_ai_con.value_counts()
# Out:
# Unnamed: 33
# 0                                             47
# Tools for identifying AI-generated content    47
# Name: count, dtype: int64

# %%
trefny = df_new["Unnamed: 34"]
trefny.value_counts()
# Out:
# Unnamed: 34
# 0                                                                                                                                       55
# Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework    39
# Name: count, dtype: int64

# %%
prof_dev_evn = df_new["Unnamed: 35"]
prof_dev_evn.value_counts()
# Out:
# Unnamed: 35
# In-person professional development events (e.g., GenAI workshops, roundtables, etc.)    56
# 0                                                                                       38
# Name: count, dtype: int64

# %%
online_training = df_new["Unnamed: 36"]
online_training.value_counts()
# Out:
# Unnamed: 36
# Online training resources (e.g., online modules or courses on GenAI best practices)    48
# 0                                                                                      46
# Name: count, dtype: int64

# %%
mod_tem = df_new["Unnamed: 37"]
mod_tem.value_counts()
# Out:
# Unnamed: 37
# 0                                                                       49
# Modifiable templates for GenAI lessons, assignments, and assessments    46
# Name: count, dtype: int64

# %%
other = df_new["Unnamed: 38"]
other.value_counts()
# Out:
# Unnamed: 38
# 0                                                                                               87
# The CIARC team hopes to collaborate with Trefny to support the addition of AI in classrooms.     1
# I do not see me integrating AI at all at this time.                                              1
# none at this time                                                                                1
# none                                                                                             1
# Advanced courses for training GenAI to custom content. Not just 'gpt for babies'....             1
# More computational resources (e.g. more GPUs) would be nice!                                     1
# Name: count, dtype: int64

# %%
resources = {
    'Mines License': mines_li.value_counts()["Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)"],
    'Custom Tools': custom_imp.value_counts()["Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)"],
    'AI Detection Tools': tools_idn_ai_con.value_counts()["Tools for identifying AI-generated content"],
    'Trefny Help': trefny.value_counts()["Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework"],
    'In-person Events': prof_dev_evn.value_counts()["In-person professional development events (e.g., GenAI workshops, roundtables, etc.)"],
    'Online Training': online_training.value_counts()["Online training resources (e.g., online modules or courses on GenAI best practices)"],
    'GenAI Templates': mod_tem.value_counts()["Modifiable templates for GenAI lessons, assignments, and assessments"]
}

# %%
resources
# Out:
# {'Mines License': 64,
#  'Custom Tools': 27,
#  'AI Detection Tools': 47,
#  'Trefny Help': 39,
#  'In-person Events': 56,
#  'Online Training': 48,
#  'GenAI Templates': 46}

# %%
sorted_resources = dict(sorted(resources.items(), key=lambda item: item[1], reverse=True))
sorted_resources
# Out:
# {'Mines License': 64,
#  'In-person Events': 56,
#  'Online Training': 48,
#  'AI Detection Tools': 47,
#  'GenAI Templates': 46,
#  'Trefny Help': 39,
#  'Custom Tools': 27}

# %%
normalized_resources = {k: round(((v/95) * 100), 1) for k, v in sorted_resources.items()}
normalized_resources
# Out:
# {'Mines License': 67.4,
#  'In-person Events': 58.9,
#  'Online Training': 50.5,
#  'AI Detection Tools': 49.5,
#  'GenAI Templates': 48.4,
#  'Trefny Help': 41.1,
#  'Custom Tools': 28.4}

# %%
#res = resources.value_counts().sort_values(ascending=False)
draw_barplot(pd.Series(resources), "", "")
# Out:
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_50570/1680264997.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=data.index, y=data.values, palette="Blues_d")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties

def draw_barplot2(data, xlabel, ylabel):
    plt.figure(figsize=(8, 6))
    ax = sns.barplot(y=data.index, x=data.values, palette="Blues_d")

    # Annotate bars
    for p in ax.patches:
        ax.annotate(f'{p.get_width():.1f}',  
                    (p.get_width(), p.get_y() + p.get_height() / 2),
                    ha='left', va='center', fontsize=12, color='black', fontweight='bold')

    ax.tick_params(axis='y', labelsize=11, labelcolor='black')
    for tick in ax.get_yticklabels():
        tick.set_fontweight('bold')
    # Define bold font properties
    bold_font = FontProperties()
    bold_font.set_weight('bold')
    bold_font.set_size(12)

    # Apply bold font to axis labels
    ax.set_xlabel(xlabel, fontproperties=bold_font)
    ax.set_ylabel(ylabel, fontproperties=bold_font)

    plt.tight_layout()
    plt.savefig('/Users/jesanahammed/Desktop/faculty_preparedness.png', dpi=300)
    plt.show()

# %%
draw_barplot2(pd.Series(resources), "", "")
# Out:
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_50570/1831596787.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y=data.index, x=data.values, palette="Blues_d")

# %%
draw_barplot2(pd.Series(normalized_resources), "", "")
# Out:
# /var/folders/v7/gphzyn511m1_qjvs14t04n000000gn/T/ipykernel_50570/2237919878.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(y=data.index, x=data.values, palette="Blues_d")

# %%
def createDataframe(a1, v1, a2, v2):
    df = pd.DataFrame({
       a1: v1,
       a2: v2 
    })

    return df

# %%
df = createDataframe('mines_license', mines_li, 'inperson_event', prof_dev_evn)

# %%
df
# Out:
#                                          mines_license  \
# 8    Mines-wide licensing and ITS support for exter...
# 9                                                    0
# 10   Mines-wide licensing and ITS support for exter...
# 11                                                   0
# 13                                                   0
# ..                                                 ...
# 137                                                  0
# 138  Mines-wide licensing and ITS support for exter...
# 139  Mines-wide licensing and ITS support for exter...
# 140  Mines-wide licensing and ITS support for exter...
# 141                                                NaN
#
#                                         inperson_event
# 8                                                    0
# 9    In-person professional development events (e.g...
# 10   In-person professional development events (e.g...
# 11                                                   0
# 13                                                   0
# ..                                                 ...
# 137                                                  0
# 138                                                  0
# 139                                                  0
# 140  In-person professional development events (e.g...
# 141                                                NaN
#
# [95 rows x 2 columns]

# %%
# Create boolean masks
def npArray(a1, a2, v1, v2):
    both_yes = ((df[a1] == v1) & (df[a2] == v2)).sum()
    a1_only = ((df[a1] == v1) & (df[a2] == '0')).sum()
    a2_only = ((df[a1] == '0') & (df[a2] == v2)).sum()
    neither = ((df[a1] == '0') & (df[a2] == '0')).sum()
    table = np.array([[both_yes, a1_only],
                  [a2_only, neither]])
    return table

# %%
v1 = "Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)"
v2 = "In-person professional development events (e.g., GenAI workshops, roundtables, etc.)"

# %%
table = npArray('mines_license', 'inperson_event', v1, v2)

# %%
print(table)
# Out:
# [[40 24]
#  [16 14]]

# %%
from statsmodels.stats.contingency_tables import mcnemar
def McNemarTest(table):
    result = mcnemar(table, exact=True)
    print(f"McNemar’s p-value: {result.pvalue:.4f}")

# %%
McNemarTest(table)
# Out:
# McNemar’s p-value: 0.2682

# %%
resources
# Out:
# {'Mines License': 64,
#  'Custom Tools': 27,
#  'AI Detection Tools': 47,
#  'Trefny Help': 39,
#  'In-person Events': 56,
#  'Online Training': 48,
#  'GenAI Templates': 46}

# %%
df = pd.DataFrame({
    'Mines License': mines_li,
    'Custom Tools': custom_imp,
    'AI Detection Tools': tools_idn_ai_con,
    'Trefny Help': trefny,
    'In-person Events': prof_dev_evn,
    'Online Training': online_training,
    'GenAI Templates': mod_tem
})

# %%
num_unique_participants = df.notna().any(axis=1).sum()
print(num_unique_participants)
# Out:
# 95

# %%
labels_dict = {
    'Mines License': "Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)",
    'Custom Tools': "Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)",
    'AI Detection Tools': "Tools for identifying AI-generated content",
    'Trefny Help': "Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework",
    'In-person Events': "In-person professional development events (e.g., GenAI workshops, roundtables, etc.)",
    'Online Training': "Online training resources (e.g., online modules or courses on GenAI best practices)",
    'GenAI Templates': "Modifiable templates for GenAI lessons, assignments, and assessments"
}

# %%
def clean_column(df, col):
    """Fill NaN and convert to binary string labels"""
    return df[col].fillna("0").astype(str)

# %%
def compute_mcnemar_table(col1, col2, v1, v2):
    """Create a 2x2 contingency table for McNemar test"""
    both_yes = ((col1 == v1) & (col2 == v2)).sum()
    a1_only  = ((col1 == v1) & (col2 == "0")).sum()
    a2_only  = ((col1 == "0") & (col2 == v2)).sum()
    neither  = ((col1 == "0") & (col2 == "0")).sum()
    return np.array([[both_yes, a1_only], [a2_only, neither]])

# %%
def run_mcnemar_tests(df, labels_dict):
    cols = list(labels_dict.keys())
    labels = list(labels_dict.values())
    
    # Prepare p-value matrix
    p_matrix = pd.DataFrame(np.ones((len(cols), len(cols))), columns=cols, index=cols)

    # Compare each pair
    for i, col1 in enumerate(cols):
        for j, col2 in enumerate(cols):
            if i >= j:  # skip redundant pairs and self-comparison
                continue

            c1 = clean_column(df, col1)
            c2 = clean_column(df, col2)

            table = compute_mcnemar_table(c1, c2, labels_dict[col1], labels_dict[col2])

            try:
                result = mcnemar(table, exact=True)
                p_matrix.loc[col1, col2] = result.pvalue
                p_matrix.loc[col2, col1] = result.pvalue
            except Exception as e:
                print(f"Error comparing {col1} vs {col2}: {e}")
    
    return p_matrix

# %%
def plot_heatmap(p_matrix, title="McNemar Test P-Value Heatmap"):
    plt.figure(figsize=(10, 8))
    sns.heatmap(p_matrix, annot=True, fmt=".3f", cmap="Blues", cbar_kws={"label": "p-value"},
                linewidths=0.5, linecolor='gray', square=True)
    plt.title(title, fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %%
# Run McNemar tests
p_matrix = run_mcnemar_tests(df, labels_dict)

# Plot heatmap
plot_heatmap(p_matrix)

# %%
print(p_matrix)
# Out:
#                  mines_license  custom_tools  tools_id    trefny  \
# mines_license     1.000000e+00  1.211526e-07  0.011508  0.000621
# custom_tools      1.211526e-07  1.000000e+00  0.005515  0.028959
# tools_id          1.150779e-02  5.515201e-03  1.000000  0.255875
# trefny            6.210435e-04  2.895927e-02  0.255875  1.000000
# inperson_event    2.681873e-01  1.537409e-05  0.211024  0.009475
# online_training   3.283914e-02  3.087676e-03  1.000000  0.280610
# mod_templates     5.097643e-03  3.377848e-03  1.000000  0.281042
#
#                  inperson_event  online_training  mod_templates
# mines_license          0.268187         0.032839       0.005098
# custom_tools           0.000015         0.003088       0.003378
# tools_id               0.211024         1.000000       1.000000
# trefny                 0.009475         0.280610       0.281042
# inperson_event         1.000000         0.242985       0.132498
# online_training        0.242985         1.000000       0.867939
# mod_templates          0.132498         0.867939       1.000000

# %%
def plot_heatmap2(p_matrix, title=""):
    import seaborn as sns
    import matplotlib.pyplot as plt
    import numpy as np

    plt.figure(figsize=(10, 8))

    # Format: scientific notation for very small p-values
    def fmt_func(x):
        return f"{x:.2e}" if x < 0.001 else f"{x:.3f}"

    sns.heatmap(p_matrix, 
                annot=p_matrix.applymap(fmt_func), 
                fmt='', cmap="Blues", 
                cbar_kws={"label": "p-value"},
                linewidths=0.5, linecolor='gray', square=True)

    plt.title(title, fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %%
plot_heatmap2(p_matrix)

# %%
def bonferroni_correct(p_matrix):
    from itertools import combinations
    corrected = p_matrix.copy()

    # Get number of unique comparisons (above diagonal)
    n = int((len(p_matrix) * (len(p_matrix) - 1)) / 2)

    # Apply Bonferroni correction to all off-diagonal p-values
    for i in range(len(corrected)):
        for j in range(len(corrected)):
            if i != j:
                p = corrected.iloc[i, j]
                corrected.iloc[i, j] = min(p * n, 1.0)

    return corrected

# %%
p_corrected = bonferroni_correct(p_matrix)

# %%
def plot_significance_heatmap(p_matrix, corrected_matrix, alpha=0.0024):
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np

    plt.figure(figsize=(10, 8))

    # Generate annotations with significance
    annotations = p_matrix.copy().astype(str)
    for i in range(len(p_matrix)):
        for j in range(len(p_matrix)):
            pval = p_matrix.iloc[i, j]
            sig = corrected_matrix.iloc[i, j] < alpha and i != j
            if pval < 0.001:
                label = "p<.001"
            else:
                label = f"{pval:.3f}"
            annotations.iloc[i, j] = f"{label}{'*' if sig else ''}"

    sns.heatmap(p_matrix, 
                annot=annotations, fmt='',
                cmap="Blues", cbar_kws={"label": "Uncorrected p-value"},
                linewidths=0.5, linecolor='gray', square=True)

    plt.title("")
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig('/Users/jesanahammed/Desktop/p_value.png', dpi=300)
    plt.show()

# %%
plot_significance_heatmap(p_matrix, p_corrected)

# %%
print(p_corrected)
# Out:
#                     Mines License  Custom Tools  AI Detection Tools  \
# Mines License            1.000000      0.000003            0.241664
# Custom Tools             0.000003      1.000000            0.115819
# AI Detection Tools       0.241664      0.115819            1.000000
# Trefny Help              0.013042      0.608145            1.000000
# In-person Events         1.000000      0.000323            1.000000
# Online Training          0.689622      0.064841            1.000000
# GenAI Templates          0.107051      0.070935            1.000000
#
#                     Trefny Help  In-person Events  Online Training  \
# Mines License          0.013042          1.000000         0.689622
# Custom Tools           0.608145          0.000323         0.064841
# AI Detection Tools     1.000000          1.000000         1.000000
# Trefny Help            1.000000          0.198981         1.000000
# In-person Events       0.198981          1.000000         1.000000
# Online Training        1.000000          1.000000         1.000000
# GenAI Templates        1.000000          1.000000         1.000000
#
#                     GenAI Templates
# Mines License              0.107051
# Custom Tools               0.070935
# AI Detection Tools         1.000000
# Trefny Help                1.000000
# In-person Events           1.000000
# Online Training            1.000000
# GenAI Templates            1.000000

# %%
df_long = pd.DataFrame({
    'role': role
})

# %%
df_long
# Out:
#                                            role
# 8    Tenure track faculty  Associate professor
# 9                        Administrative faculty
# 10                       Administrative faculty
# 11            Teaching faculty  Full professor
# 13        Tenure track faculty  Full professor
# ..                                          ...
# 137       Tenure track faculty  Full professor
# 138      Teaching faculty  Associate professor
# 139       Tenure track faculty  Full professor
# 140       Tenure track faculty  Full professor
# 141  Tenure track faculty  Assistant professor
#
# [95 rows x 1 columns]

# %%
df_rename = df_new.rename(columns={
    'Unnamed: 37': 'Modifiable templates for GenAI lessons, assignments, and assessments',
    'Unnamed: 36': 'Online training resources (e.g., online modules or courses on GenAI best practices)',
    'Unnamed: 35': 'In-person professional development events (e.g., GenAI workshops, roundtables, etc.)',
    'Unnamed: 34': 'Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework',
    'Unnamed: 33': 'Tools for identifying AI-generated content',
    'Unnamed: 32': 'Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)',
    'Which of the following resources would you be likely to use in order to integrate generative AI effectively and responsibly in your role at Mines? (Select all that apply)': 'Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)'
})

# %%
resource_cols = [
    'Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)',
    'Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)',
    'Tools for identifying AI-generated content',
    'Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework',
    'In-person professional development events (e.g., GenAI workshops, roundtables, etc.)',
    'Online training resources (e.g., online modules or courses on GenAI best practices)',
    'Modifiable templates for GenAI lessons, assignments, and assessments'
]

# %%
df_lon = pd.melt(df_rename,
                 id_vars = ["Response ID", "What is your current role at Mines?", "How many years have you been at Mines?"],
                 value_vars = resource_cols,
                 var_name = 'resources_type',
                 value_name = 'selected'
                )

# %%
df_lon
# Out:
#      Response ID         What is your current role at Mines?  \
# 0    114801644.0  Tenure track faculty  Associate professor
# 1    114801654.0                      Administrative faculty
# 2    114801670.0                      Administrative faculty
# 3    114801704.0           Teaching faculty  Full professor
# 4    114801762.0       Tenure track faculty  Full professor
# ..           ...                                         ...
# 660  115473017.0       Tenure track faculty  Full professor
# 661  115473179.0      Teaching faculty  Associate professor
# 662  115474843.0       Tenure track faculty  Full professor
# 663  115488174.0       Tenure track faculty  Full professor
# 664  115496611.0  Tenure track faculty  Assistant professor
#
#     How many years have you been at Mines?  \
# 0                               5-10 years
# 1                               5-10 years
# 2                           1 year or less
# 3                              10-20 years
# 4                               > 20 years
# ..                                     ...
# 660                             5-10 years
# 661                              1-5 years
# 662                              1-5 years
# 663                            10-20 years
# 664                         1 year or less
#
#                                         resources_type  \
# 0    Mines-wide licensing and ITS support for exter...
# 1    Mines-wide licensing and ITS support for exter...
# 2    Mines-wide licensing and ITS support for exter...
# 3    Mines-wide licensing and ITS support for exter...
# 4    Mines-wide licensing and ITS support for exter...
# ..                                                 ...
# 660  Modifiable templates for GenAI lessons, assign...
# 661  Modifiable templates for GenAI lessons, assign...
# 662  Modifiable templates for GenAI lessons, assign...
# 663  Modifiable templates for GenAI lessons, assign...
# 664  Modifiable templates for GenAI lessons, assign...
#
#                                               selected
# 0    Mines-wide licensing and ITS support for exter...
# 1                                                    0
# 2    Mines-wide licensing and ITS support for exter...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 660                                                  0
# 661  Modifiable templates for GenAI lessons, assign...
# 662  Modifiable templates for GenAI lessons, assign...
# 663  Modifiable templates for GenAI lessons, assign...
# 664  Modifiable templates for GenAI lessons, assign...
#
# [665 rows x 5 columns]

# %%
from pandas.api.types import CategoricalDtype

# Define the order
years_order = ['1 year or less', '1-5 years', '5-10 years', '10-20 years', '> 20 years']

# %%
# Convert to ordered categorical type
cat_type = CategoricalDtype(categories=years_order, ordered=True)
df_lon["How many years have you been at Mines?"] = df_lon["How many years have you been at Mines?"].astype(cat_type)

# %%
df_lon
# Out:
#      Response ID         What is your current role at Mines?  \
# 0    114801644.0  Tenure track faculty  Associate professor
# 1    114801654.0                      Administrative faculty
# 2    114801670.0                      Administrative faculty
# 3    114801704.0           Teaching faculty  Full professor
# 4    114801762.0       Tenure track faculty  Full professor
# ..           ...                                         ...
# 660  115473017.0       Tenure track faculty  Full professor
# 661  115473179.0      Teaching faculty  Associate professor
# 662  115474843.0       Tenure track faculty  Full professor
# 663  115488174.0       Tenure track faculty  Full professor
# 664  115496611.0  Tenure track faculty  Assistant professor
#
#     How many years have you been at Mines?  \
# 0                               5-10 years
# 1                               5-10 years
# 2                           1 year or less
# 3                              10-20 years
# 4                               > 20 years
# ..                                     ...
# 660                             5-10 years
# 661                              1-5 years
# 662                              1-5 years
# 663                            10-20 years
# 664                         1 year or less
#
#                                         resources_type  \
# 0    Mines-wide licensing and ITS support for exter...
# 1    Mines-wide licensing and ITS support for exter...
# 2    Mines-wide licensing and ITS support for exter...
# 3    Mines-wide licensing and ITS support for exter...
# 4    Mines-wide licensing and ITS support for exter...
# ..                                                 ...
# 660  Modifiable templates for GenAI lessons, assign...
# 661  Modifiable templates for GenAI lessons, assign...
# 662  Modifiable templates for GenAI lessons, assign...
# 663  Modifiable templates for GenAI lessons, assign...
# 664  Modifiable templates for GenAI lessons, assign...
#
#                                               selected
# 0    Mines-wide licensing and ITS support for exter...
# 1                                                    0
# 2    Mines-wide licensing and ITS support for exter...
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 660                                                  0
# 661  Modifiable templates for GenAI lessons, assign...
# 662  Modifiable templates for GenAI lessons, assign...
# 663  Modifiable templates for GenAI lessons, assign...
# 664  Modifiable templates for GenAI lessons, assign...
#
# [665 rows x 5 columns]

# %%
print(df_lon.dtypes)
print(df_lon['selected'].value_counts())
print(df_lon['resources_type'].unique())
# Out:
# Response ID                                float64
# What is your current role at Mines?         object
# How many years have you been at Mines?    category
# resources_type                              object
# selected                                    object
# dtype: object
# selected
# 0                                                                                                                                       332
# Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)                                   64
# In-person professional development events (e.g., GenAI workshops, roundtables, etc.)                                                     56
# Online training resources (e.g., online modules or courses on GenAI best practices)                                                      48
# Tools for identifying AI-generated content                                                                                               47
# Modifiable templates for GenAI lessons, assignments, and assessments                                                                     46
# Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework     39
# Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)             27
# Name: count, dtype: int64
# ['Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)'
#  'Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)'
#  'Tools for identifying AI-generated content'
#  'Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework'
#  'In-person professional development events (e.g., GenAI workshops, roundtables, etc.)'
#  'Online training resources (e.g., online modules or courses on GenAI best practices)'
#  'Modifiable templates for GenAI lessons, assignments, and assessments']

# %%
# Convert selected column to binary: 1 if selected, 0 if not
df_lon['selected'] = (df_lon['selected'] != '0').astype(int)

# %%
print(df_lon['selected'].value_counts())
# Out:
# selected
# 1    333
# 0    332
# Name: count, dtype: int64

# %%
df_lon = df_lon.rename(columns={
    'What is your current role at Mines?': 'designation',
    'How many years have you been at Mines?': 'years_at_mines'
})

# %%
df_lon
# Out:
#      Response ID                                 designation  years_at_mines  \
# 0    114801644.0  Tenure track faculty  Associate professor      5-10 years
# 1    114801654.0                      Administrative faculty      5-10 years
# 2    114801670.0                      Administrative faculty  1 year or less
# 3    114801704.0           Teaching faculty  Full professor     10-20 years
# 4    114801762.0       Tenure track faculty  Full professor      > 20 years
# ..           ...                                         ...             ...
# 660  115473017.0       Tenure track faculty  Full professor      5-10 years
# 661  115473179.0      Teaching faculty  Associate professor       1-5 years
# 662  115474843.0       Tenure track faculty  Full professor       1-5 years
# 663  115488174.0       Tenure track faculty  Full professor     10-20 years
# 664  115496611.0  Tenure track faculty  Assistant professor  1 year or less
#
#                                         resources_type  selected
# 0    Mines-wide licensing and ITS support for exter...         1
# 1    Mines-wide licensing and ITS support for exter...         0
# 2    Mines-wide licensing and ITS support for exter...         1
# 3    Mines-wide licensing and ITS support for exter...         0
# 4    Mines-wide licensing and ITS support for exter...         0
# ..                                                 ...       ...
# 660  Modifiable templates for GenAI lessons, assign...         0
# 661  Modifiable templates for GenAI lessons, assign...         1
# 662  Modifiable templates for GenAI lessons, assign...         1
# 663  Modifiable templates for GenAI lessons, assign...         1
# 664  Modifiable templates for GenAI lessons, assign...         1
#
# [665 rows x 5 columns]

# %%
import statsmodels.formula.api as smf

# %%
model = smf.logit("selected ~ C(resources_type) + C(designation) + C(years_at_mines)", data=df_lon).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.647729
#          Iterations 5

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               selected   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      630
# Method:                           MLE   Df Model:                           20
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.06533
# Time:                        13:30:08   Log-Likelihood:                -421.67
# converged:                       True   LL-Null:                       -451.15
# Covariance Type:            nonrobust   LLR p-value:                 1.035e-05
# =============================================================================================================================================================================================================================
#                                                                                                                                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                                                                     0.0101      0.389      0.026      0.979      -0.752       0.772
# C(resources_type)[T.In-person professional development events (e.g., GenAI workshops, roundtables, etc.)]                                                     1.4015      0.318      4.406      0.000       0.778       2.025
# C(resources_type)[T.Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)]                                   1.7436      0.326      5.353      0.000       1.105       2.382
# C(resources_type)[T.Modifiable templates for GenAI lessons, assignments, and assessments]                                                                     0.9038      0.314      2.877      0.004       0.288       1.520
# C(resources_type)[T.Online training resources (e.g., online modules or courses on GenAI best practices)]                                                      1.0376      0.314      3.300      0.001       0.421       1.654
# C(resources_type)[T.Tools for identifying AI-generated content]                                                                                               0.9929      0.314      3.159      0.002       0.377       1.609
# C(resources_type)[T.Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework]     0.6344      0.315      2.011      0.044       0.016       1.253
# C(designation)[T.Administrative faculty]                                                                                                                     -0.5242      0.328     -1.599      0.110      -1.167       0.118
# C(designation)[T.Other (Please specify)]                                                                                                                     -1.3799      0.641     -2.151      0.031      -2.637      -0.123
# C(designation)[T.Postdoctoral staff or research faculty]                                                                                                     -0.9466      0.485     -1.953      0.051      -1.897       0.004
# C(designation)[T.Professor of practice]                                                                                                                      -0.0147      0.626     -0.023      0.981      -1.242       1.213
# C(designation)[T.Teaching faculty  Assistant professor]                                                                                                     -0.3861      0.440     -0.878      0.380      -1.248       0.476
# C(designation)[T.Teaching faculty  Associate professor]                                                                                                      0.3049      0.405      0.752      0.452      -0.490       1.099
# C(designation)[T.Teaching faculty  Full professor]                                                                                                          -0.3246      0.389     -0.835      0.404      -1.087       0.437
# C(designation)[T.Tenure track faculty  Assistant professor]                                                                                                 -0.6453      0.392     -1.647      0.099      -1.413       0.122
# C(designation)[T.Tenure track faculty  Associate professor]                                                                                                 -0.4169      0.397     -1.049      0.294      -1.196       0.362
# C(designation)[T.Tenure track faculty  Full professor]                                                                                                      -0.5148      0.363     -1.420      0.156      -1.225       0.196
# C(years_at_mines)[T.1-5 years]                                                                                                                               -0.4448      0.291     -1.529      0.126      -1.015       0.125
# C(years_at_mines)[T.5-10 years]                                                                                                                              -0.5596      0.342     -1.637      0.102      -1.230       0.110
# C(years_at_mines)[T.10-20 years]                                                                                                                             -0.8546      0.368     -2.321      0.020      -1.576      -0.133
# C(years_at_mines)[T.> 20 years]                                                                                                                              -0.7270      0.439     -1.657      0.097      -1.587       0.133
# =============================================================================================================================================================================================================================

# %%
resource_type = df_lon['resources_type'].unique()
resource_type
# Out:
# array(['Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.)',
#        'Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)',
#        'Tools for identifying AI-generated content',
#        'Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework',
#        'In-person professional development events (e.g., GenAI workshops, roundtables, etc.)',
#        'Online training resources (e.g., online modules or courses on GenAI best practices)',
#        'Modifiable templates for GenAI lessons, assignments, and assessments'],
#       dtype=object)

# %%
result = {}

for res in resource_type:
    df_temp = df_lon.copy()
    df_temp['selected_res'] = ((df_temp['resources_type'] == res) & (df_temp['selected'] == 1)).astype(int)

    try:
        model = smf.logit("selected_res ~ C(designation) + C(years_at_mines)", data=df_temp).fit_regularized()
        result[res] = model
        print(f"{res} ✓ Model fit successful")
    except Exception as e:
        print(f"{res} ✗ Model failed: {e}")
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.31721660397656276
#             Iterations: 98
#             Function evaluations: 99
#             Gradient evaluations: 98
# Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.) ✓ Model fit successful
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.16138649003704383
#             Iterations: 122
#             Function evaluations: 123
#             Gradient evaluations: 122
# Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally) ✓ Model fit successful
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.25375054307953787
#             Iterations: 115
#             Function evaluations: 115
#             Gradient evaluations: 115
# Tools for identifying AI-generated content ✓ Model fit successful
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.22158273070657944
#             Iterations: 137
#             Function evaluations: 137
#             Gradient evaluations: 137
# Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework ✓ Model fit successful
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2920663974651601
#             Iterations: 103
#             Function evaluations: 103
#             Gradient evaluations: 103
# In-person professional development events (e.g., GenAI workshops, roundtables, etc.) ✓ Model fit successful
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2625245488503855
#             Iterations: 114
#             Function evaluations: 114
#             Gradient evaluations: 114
# Online training resources (e.g., online modules or courses on GenAI best practices) ✓ Model fit successful
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.24673681667329936
#             Iterations: 134
#             Function evaluations: 135
#             Gradient evaluations: 134
# Modifiable templates for GenAI lessons, assignments, and assessments ✓ Model fit successful

# %%
for res, model in result.items():
    print(f"\n==== {res} ====")
    print(model.summary())
# Out:
# ==== Mines-wide licensing and ITS support for external GenAI tools (e.g., ChatGPT4+, Git-Hub CoPilot, etc.) ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.01288
# Time:                        14:05:43   Log-Likelihood:                -206.51
# converged:                       True   LL-Null:                       -209.20
# Covariance Type:            nonrobust   LLR p-value:                    0.9797
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -1.9051      0.475     -4.009      0.000      -2.836      -0.974
# C(designation)[T.Administrative faculty]                        -0.0081      0.507     -0.016      0.987      -1.002       0.986
# C(designation)[T.Other (Please specify)]                         0.2023      0.872      0.232      0.816      -1.506       1.911
# C(designation)[T.Postdoctoral staff or research faculty]         0.2511      0.687      0.365      0.715      -1.096       1.598
# C(designation)[T.Professor of practice]                          0.4066      0.885      0.459      0.646      -1.328       2.142
# C(designation)[T.Teaching faculty  Assistant professor]        -0.1223      0.731     -0.167      0.867      -1.556       1.311
# C(designation)[T.Teaching faculty  Associate professor]         0.5115      0.609      0.840      0.401      -0.682       1.705
# C(designation)[T.Teaching faculty  Full professor]             -0.0926      0.668     -0.138      0.890      -1.403       1.218
# C(designation)[T.Tenure track faculty  Assistant professor]    -0.1986      0.635     -0.313      0.754      -1.443       1.046
# C(designation)[T.Tenure track faculty  Associate professor]     0.2896      0.662      0.438      0.662      -1.007       1.586
# C(designation)[T.Tenure track faculty  Full professor]          0.0598      0.615      0.097      0.923      -1.146       1.265
# C(years_at_mines)[T.1-5 years]                                  -0.1859      0.418     -0.444      0.657      -1.006       0.634
# C(years_at_mines)[T.5-10 years]                                 -0.7671      0.547     -1.403      0.160      -1.838       0.304
# C(years_at_mines)[T.10-20 years]                                -0.4090      0.570     -0.718      0.473      -1.526       0.707
# C(years_at_mines)[T.> 20 years]                                 -0.8073      0.756     -1.067      0.286      -2.290       0.675
# ================================================================================================================================
#
# ==== Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally) ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.06498
# Time:                        14:05:43   Log-Likelihood:                -105.06
# converged:                       True   LL-Null:                       -112.36
# Covariance Type:            nonrobust   LLR p-value:                    0.4058
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -2.5964      0.634     -4.096      0.000      -3.839      -1.354
# C(designation)[T.Administrative faculty]                         0.0754      0.652      0.116      0.908      -1.203       1.354
# C(designation)[T.Other (Please specify)]                       -18.7525   1.24e+04     -0.002      0.999   -2.43e+04    2.42e+04
# C(designation)[T.Postdoctoral staff or research faculty]       -26.6596   4.74e+05  -5.63e-05      1.000   -9.28e+05    9.28e+05
# C(designation)[T.Professor of practice]                        -16.0882   3611.323     -0.004      0.996   -7094.151    7061.975
# C(designation)[T.Teaching faculty  Assistant professor]        -0.0320      0.903     -0.035      0.972      -1.801       1.737
# C(designation)[T.Teaching faculty  Associate professor]         0.2478      0.783      0.317      0.751      -1.286       1.782
# C(designation)[T.Teaching faculty  Full professor]             -0.7978      1.018     -0.783      0.433      -2.794       1.198
# C(designation)[T.Tenure track faculty  Assistant professor]    -0.0399      0.816     -0.049      0.961      -1.639       1.559
# C(designation)[T.Tenure track faculty  Associate professor]   -37.7847   8.28e+07  -4.56e-07      1.000   -1.62e+08    1.62e+08
# C(designation)[T.Tenure track faculty  Full professor]         -0.0456      0.797     -0.057      0.954      -1.607       1.516
# C(years_at_mines)[T.1-5 years]                                  -0.2942      0.613     -0.480      0.631      -1.496       0.908
# C(years_at_mines)[T.5-10 years]                                 -0.1567      0.690     -0.227      0.820      -1.509       1.196
# C(years_at_mines)[T.10-20 years]                                -0.3841      0.820     -0.468      0.639      -1.991       1.223
# C(years_at_mines)[T.> 20 years]                                 -0.6546      1.035     -0.633      0.527      -2.683       1.374
# ================================================================================================================================
#
# Possibly complete quasi-separation: A fraction 0.18 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#
# ==== Tools for identifying AI-generated content ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.03586
# Time:                        14:05:43   Log-Likelihood:                -165.19
# converged:                       True   LL-Null:                       -171.34
# Covariance Type:            nonrobust   LLR p-value:                    0.5831
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -1.8139      0.497     -3.648      0.000      -2.788      -0.839
# C(designation)[T.Administrative faculty]                        -1.2623      0.638     -1.978      0.048      -2.513      -0.012
# C(designation)[T.Other (Please specify)]                        -0.5995      1.119     -0.536      0.592      -2.793       1.594
# C(designation)[T.Postdoctoral staff or research faculty]        -0.0680      0.743     -0.092      0.927      -1.523       1.387
# C(designation)[T.Professor of practice]                          0.5429      0.888      0.611      0.541      -1.198       2.284
# C(designation)[T.Teaching faculty  Assistant professor]        -1.5659      1.088     -1.439      0.150      -3.698       0.566
# C(designation)[T.Teaching faculty  Associate professor]        -0.1112      0.625     -0.178      0.859      -1.336       1.114
# C(designation)[T.Teaching faculty  Full professor]              0.0107      0.682      0.016      0.987      -1.326       1.348
# C(designation)[T.Tenure track faculty  Assistant professor]    -0.2616      0.627     -0.417      0.677      -1.491       0.968
# C(designation)[T.Tenure track faculty  Associate professor]    -0.1865      0.655     -0.285      0.776      -1.470       1.097
# C(designation)[T.Tenure track faculty  Full professor]         -0.6847      0.679     -1.009      0.313      -2.015       0.645
# C(years_at_mines)[T.1-5 years]                                  -0.3280      0.524     -0.626      0.531      -1.354       0.698
# C(years_at_mines)[T.5-10 years]                                 -0.0632      0.607     -0.104      0.917      -1.254       1.127
# C(years_at_mines)[T.10-20 years]                                -0.7452      0.697     -1.069      0.285      -2.111       0.620
# C(years_at_mines)[T.> 20 years]                                 -0.7781      0.862     -0.903      0.367      -2.467       0.911
# ================================================================================================================================
#
# ==== Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.04044
# Time:                        14:05:43   Log-Likelihood:                -144.25
# converged:                       True   LL-Null:                       -150.33
# Covariance Type:            nonrobust   LLR p-value:                    0.5935
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -2.6155      0.619     -4.223      0.000      -3.829      -1.402
# C(designation)[T.Administrative faculty]                        -0.0244      0.672     -0.036      0.971      -1.342       1.293
# C(designation)[T.Other (Please specify)]                       -19.0241   1.44e+04     -0.001      0.999   -2.82e+04    2.82e+04
# C(designation)[T.Postdoctoral staff or research faculty]        -0.4493      1.160     -0.387      0.699      -2.723       1.824
# C(designation)[T.Professor of practice]                        -15.8037   3536.365     -0.004      0.996   -6946.951    6915.344
# C(designation)[T.Teaching faculty  Assistant professor]         0.9841      0.717      1.372      0.170      -0.422       2.390
# C(designation)[T.Teaching faculty  Associate professor]         0.5184      0.740      0.700      0.484      -0.933       1.969
# C(designation)[T.Teaching faculty  Full professor]              0.4188      0.828      0.505      0.613      -1.205       2.042
# C(designation)[T.Tenure track faculty  Assistant professor]     0.5393      0.725      0.744      0.457      -0.882       1.961
# C(designation)[T.Tenure track faculty  Associate professor]    -0.5037      0.941     -0.535      0.592      -2.348       1.341
# C(designation)[T.Tenure track faculty  Full professor]          0.2589      0.747      0.347      0.729      -1.205       1.723
# C(years_at_mines)[T.1-5 years]                                  -0.3205      0.553     -0.580      0.562      -1.404       0.763
# C(years_at_mines)[T.5-10 years]                                 -0.0954      0.614     -0.155      0.876      -1.298       1.108
# C(years_at_mines)[T.10-20 years]                                -0.8799      0.789     -1.115      0.265      -2.427       0.667
# C(years_at_mines)[T.> 20 years]                                 -0.1065      0.835     -0.128      0.899      -1.744       1.531
# ================================================================================================================================
#
# ==== In-person professional development events (e.g., GenAI workshops, roundtables, etc.) ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.01612
# Time:                        14:05:43   Log-Likelihood:                -190.14
# converged:                       True   LL-Null:                       -193.25
# Covariance Type:            nonrobust   LLR p-value:                    0.9604
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -1.9622      0.490     -4.007      0.000      -2.922      -1.002
# C(designation)[T.Administrative faculty]                         0.0522      0.518      0.101      0.920      -0.962       1.067
# C(designation)[T.Other (Please specify)]                        -0.2972      1.133     -0.262      0.793      -2.518       1.924
# C(designation)[T.Postdoctoral staff or research faculty]        -0.1020      0.862     -0.118      0.906      -1.792       1.588
# C(designation)[T.Professor of practice]                         -0.1978      1.139     -0.174      0.862      -2.430       2.035
# C(designation)[T.Teaching faculty  Assistant professor]         0.2128      0.677      0.315      0.753      -1.113       1.539
# C(designation)[T.Teaching faculty  Associate professor]        -0.1140      0.654     -0.174      0.862      -1.396       1.168
# C(designation)[T.Teaching faculty  Full professor]             -0.1022      0.622     -0.164      0.870      -1.322       1.117
# C(designation)[T.Tenure track faculty  Assistant professor]    -0.8160      0.844     -0.967      0.334      -2.471       0.839
# C(designation)[T.Tenure track faculty  Associate professor]    -0.3624      0.664     -0.546      0.585      -1.664       0.939
# C(designation)[T.Tenure track faculty  Full professor]         -0.1922      0.590     -0.326      0.745      -1.349       0.965
# C(years_at_mines)[T.1-5 years]                                  -0.7282      0.484     -1.503      0.133      -1.677       0.221
# C(years_at_mines)[T.5-10 years]                                 -0.1153      0.522     -0.221      0.825      -1.138       0.908
# C(years_at_mines)[T.10-20 years]                                -0.1492      0.570     -0.261      0.794      -1.267       0.969
# C(years_at_mines)[T.> 20 years]                                 -0.1400      0.693     -0.202      0.840      -1.498       1.218
# ================================================================================================================================
#
# ==== Online training resources (e.g., online modules or courses on GenAI best practices) ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.01698
# Time:                        14:05:43   Log-Likelihood:                -170.90
# converged:                       True   LL-Null:                       -173.86
# Covariance Type:            nonrobust   LLR p-value:                    0.9688
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -2.4231      0.563     -4.307      0.000      -3.526      -1.320
# C(designation)[T.Administrative faculty]                         0.0187      0.548      0.034      0.973      -1.056       1.093
# C(designation)[T.Other (Please specify)]                        -0.2549      1.136     -0.224      0.823      -2.482       1.973
# C(designation)[T.Postdoctoral staff or research faculty]        -0.3063      0.870     -0.352      0.725      -2.012       1.400
# C(designation)[T.Professor of practice]                          0.5439      0.899      0.605      0.545      -1.219       2.307
# C(designation)[T.Teaching faculty  Assistant professor]        -1.1614      1.107     -1.049      0.294      -3.332       1.009
# C(designation)[T.Teaching faculty  Associate professor]         0.1058      0.672      0.157      0.875      -1.212       1.423
# C(designation)[T.Teaching faculty  Full professor]              0.1168      0.672      0.174      0.862      -1.201       1.435
# C(designation)[T.Tenure track faculty  Assistant professor]    -0.6027      0.754     -0.799      0.424      -2.081       0.876
# C(designation)[T.Tenure track faculty  Associate professor]     0.2525      0.681      0.371      0.711      -1.081       1.586
# C(designation)[T.Tenure track faculty  Full professor]         -0.6519      0.704     -0.927      0.354      -2.031       0.727
# C(years_at_mines)[T.1-5 years]                                   0.2148      0.523      0.411      0.681      -0.811       1.240
# C(years_at_mines)[T.5-10 years]                                 -0.0952      0.636     -0.150      0.881      -1.342       1.152
# C(years_at_mines)[T.10-20 years]                                -0.0520      0.662     -0.079      0.937      -1.349       1.245
# C(years_at_mines)[T.> 20 years]                                  0.0856      0.821      0.104      0.917      -1.524       1.695
# ================================================================================================================================
#
# ==== Modifiable templates for GenAI lessons, assignments, and assessments ====
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           selected_res   No. Observations:                  651
# Model:                          Logit   Df Residuals:                      636
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 08 Jul 2025   Pseudo R-squ.:                 0.03371
# Time:                        14:05:43   Log-Likelihood:                -160.63
# converged:                       True   LL-Null:                       -166.23
# Covariance Type:            nonrobust   LLR p-value:                    0.6697
# ================================================================================================================================
#                                                                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -2.0108      0.516     -3.897      0.000      -3.022      -0.999
# C(designation)[T.Administrative faculty]                        -0.5713      0.533     -1.073      0.283      -1.615       0.472
# C(designation)[T.Other (Please specify)]                       -17.5099   4388.572     -0.004      0.997   -8618.952    8583.932
# C(designation)[T.Postdoctoral staff or research faculty]       -26.3199   2.48e+05     -0.000      1.000   -4.86e+05    4.86e+05
# C(designation)[T.Professor of practice]                         -0.4848      1.126     -0.430      0.667      -2.692       1.723
# C(designation)[T.Teaching faculty  Assistant professor]        -0.3290      0.720     -0.457      0.648      -1.741       1.083
# C(designation)[T.Teaching faculty  Associate professor]        -0.1258      0.641     -0.196      0.844      -1.382       1.130
# C(designation)[T.Teaching faculty  Full professor]             -0.7074      0.746     -0.948      0.343      -2.169       0.755
# C(designation)[T.Tenure track faculty  Assistant professor]    -0.6797      0.666     -1.021      0.307      -1.985       0.626
# C(designation)[T.Tenure track faculty  Associate professor]    -0.0749      0.680     -0.110      0.912      -1.408       1.258
# C(designation)[T.Tenure track faculty  Full professor]         -0.3290      0.620     -0.531      0.595      -1.543       0.885
# C(years_at_mines)[T.1-5 years]                                   0.2056      0.529      0.389      0.698      -0.831       1.243
# C(years_at_mines)[T.5-10 years]                                 -0.3342      0.623     -0.536      0.592      -1.555       0.887
# C(years_at_mines)[T.10-20 years]                                -0.4302      0.684     -0.629      0.530      -1.771       0.911
# C(years_at_mines)[T.> 20 years]                                 -0.0809      0.783     -0.103      0.918      -1.615       1.453
# ================================================================================================================================

# %%
# Count positive selections by group
ct = pd.crosstab([df_lon['resources_type'], df_lon['designation']], df_lon['selected'])
print(ct)

# Look for groups with 0 positive selections
print(ct[1] == 0)
# Out:
# selected                                                                                       0  \
# resources_type                                     designation
# Custom implementations of internal Mines-owned ... Adjunct faculty                             6
#                                                    Administrative faculty                      9
#                                                    Other (Please specify)                      2
#                                                    Postdoctoral staff or research faculty      4
#                                                    Professor of practice                       2
# ...                                                                                           ..
# Trefny consultations for developing lesson plan... Teaching faculty  Associate professor      3
#                                                    Teaching faculty  Full professor           8
#                                                    Tenure track faculty  Assistant professor  3
#                                                    Tenure track faculty  Associate professor  7
#                                                    Tenure track faculty  Full professor       9
#
# selected                                                                                       1
# resources_type                                     designation
# Custom implementations of internal Mines-owned ... Adjunct faculty                             4
#                                                    Administrative faculty                      7
#                                                    Other (Please specify)                      0
#                                                    Postdoctoral staff or research faculty      0
#                                                    Professor of practice                       0
# ...                                                                                           ..
# Trefny consultations for developing lesson plan... Teaching faculty  Associate professor      5
#                                                    Teaching faculty  Full professor           5
#                                                    Tenure track faculty  Assistant professor  5
#                                                    Tenure track faculty  Associate professor  2
#                                                    Tenure track faculty  Full professor       7
#
# [77 rows x 2 columns]
# resources_type                                                                                                                        designation
# Custom implementations of internal Mines-owned GenAI tools (e.g., new ITS-supported tools that do not share data externally)          Adjunct faculty                               False
#                                                                                                                                       Administrative faculty                        False
#                                                                                                                                       Other (Please specify)                         True
#                                                                                                                                       Postdoctoral staff or research faculty         True
#                                                                                                                                       Professor of practice                          True
#                                                                                                                                                                                     ...
# Trefny consultations for developing lesson plans, assessments, and strategies for integrating GenAI in your curriculum or coursework  Teaching faculty  Associate professor        False
#                                                                                                                                       Teaching faculty  Full professor             False
#                                                                                                                                       Tenure track faculty  Assistant professor    False
#                                                                                                                                       Tenure track faculty  Associate professor    False
#                                                                                                                                       Tenure track faculty  Full professor         False
# Name: 1, Length: 77, dtype: bool

# %%
print(len(df_new['Response ID']))
# Out:
# 95

# %%
len(genai)
# Out:
# 95

# %%
df_new2 = df_new.copy()

# %%
print(len(df_new2['Response ID']))
# Out:
# 95

# %%
dept_cluster = [0] * 95
count = 0
for col in dept_df.columns:
    
    print(col)
    i = 0
    for val in dept_df[col]:
        if val != '0':
            if col == 'ams' or col == 'cs' or col == 'ee':
                dept_cluster[i] = 'CS_EE_AMS'
            elif col == 'me' or col == 'ce':
                dept_cluster[i] = 'Mech_Civil'
            elif col == 'pe' or col == 'mme' or col == 'geop' or col == 'gge' or col == 'mee':
                dept_cluster[i] = 'Met_Geo_Pet'
            elif col == 'phy' or col == 'che' or col == 'cbe':
                dept_cluster[i] = 'Phys_Chem'
            elif col == 'eds' or col == 'eb' or col == 'has':
                dept_cluster[i] = 'Society'
            elif col == 'au' or col == 'af':
                dept_cluster[i] = 'Admin'
            else:
                dept_cluster[i] = 0
                count += 1
        i += 1
# Out:
# ams
# cbe
# che
# ce
# cs
# eb
# ee
# eds
# gge
# geop
# has
# me
# mme
# mee
# pe
# phy
# au
# af
# other

# %%
df_new2['dept cluter'] = dept_cluster

# %%
print(df_new2['dept cluter'])
# Out:
# 8        Phys_Chem
# 9            Admin
# 10               0
# 11       Phys_Chem
# 13      Mech_Civil
#           ...
# 137     Mech_Civil
# 138      CS_EE_AMS
# 139      CS_EE_AMS
# 140    Met_Geo_Pet
# 141      CS_EE_AMS
# Name: dept cluter, Length: 95, dtype: object

# %%
print(count)
# Out:
# 10

# %%
def grouped_bar_graph_horizontal_color2(categories, cluster_1_std, cluster_1_flt, cluster_2_std, cluster_2_flt, 
                                        cluster_3_std, cluster_3_flt, cluster_4_std, cluster_4_flt,
                                        cluster_5_std, cluster_5_flt, title, w, h, legend_position='upper right'):
    # Combine data into a single array for the bars
    values = np.array([cluster_1_std, cluster_1_flt, cluster_2_std, cluster_2_flt, 
                                        cluster_3_std, cluster_3_flt, cluster_4_std, cluster_4_flt,
                                        cluster_5_std, cluster_5_flt])

    # Define legend labels and colors
    legend_val = ['Mech-Civil-Student', 'Mech-Civil-Faculty', 'CS-EE-AMS-Student', 'CS-EE-AMS-Faculty', 
                  'Met-Geo-Pet-Student', 'Met-Geo-Pet-Faculty', 'Phys-Chem-Student', 'Phys-Chem-Faculty', 'Society-Student', 'Society-Faculty']
    colors = ['#1f77b4', '#85b4db', '#ff7f0e', '#ffbb80', '#2ca02c', '#80cc80', '#d62728', '#eb8080', '#9467bd', '#c0a3dd']
    
    # Set bar height and position offsets
    bar_height = 0.17
    index = np.arange(len(categories))

    # Plot
    fig, ax = plt.subplots(figsize=(w, h)) # nor 10 6, 12 5.3 for usecase

    # Create the grouped horizontal bar chart with colors
    for i in range(len(values)):
        bars = ax.barh(index + i * bar_height, values[i], bar_height, color=colors[i], edgecolor='black', label=legend_val[i])

        # Add values at the end of each bar
        for bar in bars:
            width = bar.get_width()  # Get the width of the bar (for horizontal bars)
            ax.text(width + 0.1, bar.get_y() + bar.get_height() / 2,  # Offset to the right of the bar
                    f'{width}', va='center', ha='left', color='black', rotation=0)

    # Adding labels and title
    #ax.set_xlabel('Frequency (Normalized)')
    #ax.set_title(title)
    ax.set_yticks(index + bar_height * 2)  # Move the y-ticks to the center of the group
    ax.set_yticklabels(categories, rotation=0)

    # Adjust the x-axis tick labels
    ax.tick_params(axis='x', labelsize=10)  # Set the font size for x-axis ticks
    
    # Increase the font size and wrap y-tick labels for categories
    ax.set_yticks(index + bar_height * 2)  # Move the y-ticks to the center of the group
    #wrapped_categories = [f'\n'.join(cat.split()) for cat in categories]  # Split and wrap text into multiple lines
    #ax.set_yticklabels(wrapped_categories, fontsize=8)  # Set font size for categories
    ax.set_yticklabels(categories, fontsize=14, fontweight='bold')  # Set font size for categories



    # Adding the legend (reversed order)
    reversed_legend_val = legend_val[::-1]
    reversed_colors = colors[::-1]
    handles = [mpatches.Patch(color=reversed_colors[i], label=reversed_legend_val[i]) for i in range(len(reversed_legend_val))]
    ax.legend(handles=handles, loc=legend_position)

    # Save the plot
    plt.tight_layout()
    add = '/Users/jesanahammed/Desktop/' + title
    plt.savefig(add, dpi=300)
    plt.show()
